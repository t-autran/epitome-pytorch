# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys,os,time

import numpy as np
import skimage.transform
import skimage.measure
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import rasterio

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn.feature_extraction.image import extract_patches_2d

import cProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

def cum_sum(arr, s):
    cumsum = torch.cumsum(torch.cumsum(arr,dim=2),dim=3)
    cumsum = F.pad(cumsum,(1,0,1,0),'constant',0)
    tot = cumsum[:,:,:-s,:-s]-cumsum[:,:,s:,:-s]-cumsum[:,:,:-s,s:]+cumsum[:,:,s:,s:]
    return tot

def to_disp(arr):
    arr_c = arr.cpu().numpy()
    arr_c = np.rollaxis(np.squeeze(arr_c),0,3)
    return arr_c

#learns N x N epitome from T, K x K random patches drawn from input image x.
#Applies NIT iterations of the E-M algorithm at scale sc; T*sc^2 patches are sampled.
#e,ev = initial epitome mean and variance. The mean is initialized
#to the uniform image with some small noise, and the variance is initialized to 1
#p holds an array of probabilities of using each part of the epitome

def epitome(x,K,N,T,NIT,sc):
    xFIN = x #added
    #x = F.max_pool2d(x,int(1/sc[0]))
    x = torch.clamp(F.interpolate(x,scale_factor=sc[0]),min=0,max=1)
    _, numDim, SY, SX = x.shape
    TFIN = T #added
    T = int(np.ceil(T*sc[0]**2))
    NFIN = N
    N = int(np.ceil(sc[0]*N))
    #e = mean of image plus noise
    e = torch.zeros((1,numDim,N,N)).to(device)
    ev = torch.ones((1,numDim,N,N)).to(device)/50
    for i in range(numDim):
        e[:,i,:,:] = x[0,i,:,:].std()*torch.randn(N,N).to(device)/100+x[0,i,:,:].mean()
    p = torch.ones((N,N)).to(device)/N**2
    MINP = 1e-7#1e-8 is acceptable
    MINV = 1e-2#1e-6
    #allocate trace of epitome
    etr = torch.zeros((NIT+1,1,numDim,NFIN,NFIN))
    etr[0,:,:,:,:] = F.interpolate(e,[NFIN,NFIN])
    #e = torch.clamp(e,min=0,max=1)
    #ev = torch.clamp(ev,min=MINV)
    #perform NIT iterations of EM algorithm
    for sci in range(len(sc)):
        if sci != 0:
            N = int(np.ceil(sc[sci]*NFIN))
            e = torch.clamp(F.interpolate(e,[N,N]),min=0,max=1).to(device)
            ev = torch.clamp(F.interpolate(ev,[N,N]),min=MINV).to(device)
            p = torch.ones((N,N)).to(device)/N**2
            #x = F.max_pool2d(xFIN,int(1/sc[sci]))
            x = torch.clamp(F.interpolate(xFIN,scale_factor=sc[sci]),min=0,max=1).to(device)
            T = int(np.ceil(sc[sci]**2*TFIN))
        sumP = torch.zeros((N,N),dtype=torch.float).to(device)
        sumPy = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
        sumPy2 = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
        ewrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
        evwrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
        SY = x.shape[2]
        SX = x.shape[3]
        patchnum = min(T,(SY-K)**2)
        ytemp = np.rollaxis(extract_patches_2d(torch.squeeze(x).permute(1,2,0),(K,K),max_patches=patchnum),3,1)
        y = torch.from_numpy(ytemp).float().to(device)
        for nit in range(NIT):
            #glues together borders of e
            ewrap[:,:N,:N] = e;
            ewrap[:,N:,:] = ewrap[:,:K-1,:]
            ewrap[:,:,N:] = ewrap[:,:,:K-1]
            evwrap[:,:N,:N] = ev
            evwrap[:,N:,:] = evwrap[:,:K-1,:]
            evwrap[:,:,N:] = evwrap[:,:,:K-1]
            evwrapi = 1./evwrap
            print(ewrap.device,evwrap.device,evwrapi.device)
            # E STEP
            sumP[:,:] = 0
            sumPy[:,:,:] = 0
            sumPy2[:,:,:] = 0
            for t in range(patchnum):
                yc = y[t,:,:,:]
                yct = torch.unsqueeze(torch.flip(yc,[1,2]),0)
                print(yct.device)
                #compute posterior over patch location
                lP = torch.log(p).to(device) #added
                tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
                tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrapi,0),yct))
                tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
                tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(torch.log(evwrap),0),K)),dim=0)
                lP -= .5*(tmp4+tmp1-2*tmp2+tmp3)
                P = torch.exp(lP-torch.max(lP))+MINP
                P /= torch.sum(P)
                #update mean and variance
                tmp = P.view(1,1,N,N).to(device)
                tmp = F.pad(tmp,(K-1,K-1,K-1,K-1),'constant',0)
                tmp = torch.squeeze(cum_sum(tmp,K))
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumP += tmp[:N,:N]
                tmpP = F.pad(P.view(1,1,N,N),(K-1,K-1,K-1,K-1),'constant',0)
                #tmpP = torch.unsqueeze(torch.unsqueeze(F.pad(P,(K-1,K-1,K-1,K-1),'constant',0),0),0)
                yctmp = torch.unsqueeze(yc,1)
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp))
                tmp[:,:,:K-1] += tmp[:,:,N:]
                tmp[:,:K-1,:] += tmp[:,N:,:]
                sumPy += tmp[:,:N,:N]
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp**2))
                tmp[:,:,:K-1] += tmp[:,:,N:]
                tmp[:,:K-1,:] += tmp[:,N:,:]
                sumPy2 += tmp[:,:N,:N]
            torch.cuda.empty_cache()
            #M STEP
            #p = sumP/torch.sum(sumP)#commented out
            e[0,:,:,:] = sumPy/sumP
            if nit>10 or sci>0:
                ev[0,:,:,:] = sumPy2/sumP - 2*e[0,:,:,:]*sumPy/sumP+e[0,:,:,:]**2
            ev = torch.clamp(ev,min=MINV)
            etemp = F.interpolate(e,[NFIN,NFIN])
            etr[nit+1,:,:,:] = etemp
            fig=plt.figure(figsize=(15,5))
            fig.add_subplot(131)
            plt.axis('off')
            td = to_disp(etemp[:,:3,:,:])
            plt.imshow(td)
            plt.title(str(N)+'x'+str(N)+' epitome')
            fig.add_subplot(132)
            plt.axis('off')
            plt.imshow(p,cmap='hot',interpolation='nearest')
            plt.title('mixing proportions')
            fig.add_subplot(133)
            plt.axis('off')
            curr_heat = np.sum(np.squeeze(ev.cpu().numpy()),axis=0)
            plt.imshow(curr_heat,cmap='hot',interpolation='nearest')
            plt.title('variances, max='+str(max(curr_heat.flatten())))
            plt.show()
            plt.close()   
    return e,ev,p,etr

# %%
# %%time
p = pd.read_csv("big_lc_paths.csv", header=None)
paths = p[0].tolist()
palette = np.array([[0,0,0],[0,153,51],[0,102,255],[153,102,51],[255,153,0],[255,255,0],[204,102,153]])

tile = 0
naip_tile = rasterio.open("/mnt/blobfuse/esri-naip/"+paths[tile][:-7]+".mrf",'r')
naip = naip_tile.read().astype(float)[:,:1024,:1024]/255.
naip_tile.close()

lc_tile = rasterio.open('/mnt/blobfuse/resampled-lc/'+paths[tile],'r')
lc = np.squeeze(lc_tile.read())[:1024,:1024]
lc_tile.close()
print(np.unique(lc))
lc[lc==1]=10
lc[lc==2]=1
lc[lc==10]=2
lc[lc==4]=0
lc[lc==15]=4
fig=plt.figure(figsize=(15,10))
fig.add_subplot(1,2,1)
plt.axis('off')
plt.imshow(np.rollaxis(naip,0,3)[:,:,:3])
fig.add_subplot(1,2,2)
plt.axis('off')
plt.imshow(lc)
plt.show()
plt.close()

trIM = np.zeros((10,naip.shape[1],naip.shape[2]),dtype=float)
trIM[:4,:,:] = naip
for i in range(6):
    trIM[4+i,:,:] = (lc==(i+1))
trIM = np.expand_dims(trIM,axis=0)
trIMtorch = torch.from_numpy(trIM).float().to(device)
tsIMtorch = trIMtorch
# Out:
# [2 3 4 5 6]
# CPU times: user 2.75 s, sys: 633 ms, total: 3.38 s
# Wall time: 4.09 s

# %%
# %%time
#no longer accepts initializations of e or ev
cProfile.run('e,ev,p,etr=epitome(trIMtorch,9,256,50000,20,[.125,.25,.5,1])',sort='cumtime')
torch.cuda.empty_cache()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides
#          27165442 function calls (27016201 primitive calls) in 363.170 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  363.170  363.170 {built-in method builtins.exec}
#         1    0.000    0.000  363.170  363.170 <string>:1(<module>)
#         1   86.829   86.829  363.170  363.170 <ipython-input-67-379e23d571b4>:20(epitome)
#    374051   38.007    0.000   84.316    0.000 <ipython-input-67-379e23d571b4>:3(cum_sum)
#    124683   74.104    0.001   74.104    0.001 {built-in method max}
#    623416    2.084    0.000   61.195    0.000 functional.py:2112(pad)
#    623416    5.825    0.000   58.710    0.000 {built-in method apply}
#    623416   13.669    0.000   52.885    0.000 padding.py:12(forward)
#    498734   30.875    0.000   30.875    0.000 {built-in method conv2d}
#    374050   13.582    0.000   13.582    0.000 {built-in method sum}
#    124684   12.922    0.000   12.922    0.000 {built-in method flip}
#    748102   11.380    0.000   11.380    0.000 {built-in method cumsum}
#    623416    9.855    0.000    9.855    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#   1745564    9.657    0.000    9.657    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#        43    0.000    0.000    9.629    0.224 pyplot.py:236(show)
#        43    0.001    0.000    9.629    0.224 backend_inline.py:18(show)
#        43    0.001    0.000    9.574    0.223 display.py:129(display)
#        43    0.001    0.000    9.516    0.221 formatters.py:89(format)
#       516    0.001    0.000    9.513    0.018 formatters.py:220(catch_format_error)
#       387    0.000    0.000    9.502    0.025 <decorator-gen-9>:1(__call__)
#       387    0.002    0.000    9.501    0.025 formatters.py:331(__call__)
#        43    0.000    0.000    9.490    0.221 pylabtools.py:238(<lambda>)
#        43    0.001    0.000    9.490    0.221 pylabtools.py:91(print_figure)
#        43    0.012    0.000    9.488    0.221 backend_bases.py:2107(print_figure)
#    623416    8.222    0.000    8.222    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#    623416    7.212    0.000    7.212    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#    872787    6.511    0.000    6.511    0.000 {built-in method squeeze}
#    748103    5.549    0.000    5.549    0.000 {built-in method unsqueeze}
#        86    0.002    0.000    5.297    0.062 backend_agg.py:512(print_png)
#    249368    4.537    0.000    4.537    0.000 {built-in method log}
#        86    3.859    0.045    3.859    0.045 {built-in method matplotlib._png.write_png}
#        43    0.002    0.000    3.857    0.090 figure.py:2179(get_tightbbox)
#       129    0.004    0.000    3.848    0.030 _base.py:4137(get_tightbbox)
#       258    0.007    0.000    3.759    0.015 axis.py:1137(get_tightbbox)
#      3010    0.063    0.000    3.242    0.001 axis.py:74(__init__)
#       516    0.024    0.000    2.823    0.005 axis.py:1020(_update_ticks)
#      4988    0.010    0.000    2.593    0.001 axis.py:967(iter_ticks)
#       129    0.003    0.000    2.199    0.017 figure.py:1145(add_subplot)
#       129    0.002    0.000    2.188    0.017 _subplots.py:25(__init__)
#       129    0.007    0.000    2.153    0.017 _base.py:423(__init__)
#    249366    2.008    0.000    2.008    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#    124683    1.969    0.000    1.969    0.000 {built-in method exp}
#      1505    0.006    0.000    1.885    0.001 axis.py:1787(_get_tick)
#       516    0.007    0.000    1.871    0.004 axis.py:1393(get_major_ticks)
#      9030    0.185    0.000    1.807    0.000 lines.py:290(__init__)
#       129    0.008    0.000    1.727    0.013 _base.py:998(cla)
#   4239234    1.715    0.000    1.715    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        86    0.001    0.000    1.433    0.017 backend_agg.py:421(draw)
#   1462/86    0.006    0.000    1.379    0.016 artist.py:47(draw_wrapper)
#        86    0.002    0.000    1.379    0.016 figure.py:1438(draw)
#      1505    0.008    0.000    1.372    0.001 axis.py:2159(_get_tick)
#    344/86    0.003    0.000    1.348    0.016 image.py:123(_draw_list_compositing_images)
#       258    0.004    0.000    1.346    0.005 _base.py:2528(draw)
#    249406    1.340    0.000    1.340    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#    623416    0.944    0.000    1.310    0.000 padding.py:23(<listcomp>)
#   774/516    0.002    0.000    1.222    0.002 axis.py:670(__get__)
#       258    0.002    0.000    0.969    0.004 axis.py:927(set_clip_path)
#       258    0.004    0.000    0.894    0.003 image.py:569(draw)
#       258    0.003    0.000    0.828    0.003 image.py:832(make_image)
#       258    0.051    0.000    0.818    0.003 image.py:275(_make_image)
#      4730    0.038    0.000    0.789    0.000 text.py:887(get_window_extent)
#       516    0.009    0.000    0.694    0.001 axis.py:1119(_get_tick_bboxes)
#      1505    0.011    0.000    0.671    0.000 axis.py:479(_get_tick2line)
#    623416    0.661    0.000    0.661    0.000 padding.py:18(<listcomp>)
#      3956    0.093    0.000    0.644    0.000 text.py:276(_get_layout)
#       516    0.003    0.000    0.583    0.001 ticker.py:1943(__call__)
#       516    0.002    0.000    0.579    0.001 ticker.py:1947(tick_values)
#       516    0.029    0.000    0.568    0.001 ticker.py:1896(_raw_ticks)
#       129    0.002    0.000    0.562    0.004 axis.py:1896(_update_label_position)
#       129    0.002    0.000    0.553    0.004 axis.py:2265(_update_label_position)
#     16340    0.441    0.000    0.549    0.000 artist.py:854(update)
#      1032    0.006    0.000    0.533    0.001 axis.py:844(set_tick_params)
#       258    0.002    0.000    0.514    0.002 _base.py:2678(grid)
#       129    0.001    0.000    0.514    0.004 axis.py:1877(_get_tick_boxes_siblings)
#       516    0.002    0.000    0.512    0.001 axis.py:1423(grid)
#       129    0.001    0.000    0.507    0.004 axis.py:2246(_get_tick_boxes_siblings)
#     14190    0.017    0.000    0.461    0.000 markers.py:167(__init__)
#     14190    0.046    0.000    0.420    0.000 markers.py:251(set_marker)
#       774    0.013    0.000    0.404    0.001 text.py:691(draw)
#    154854    0.376    0.000    0.387    0.000 {built-in method numpy.core.multiarray.array}
#      1505    0.012    0.000    0.373    0.000 axis.py:494(_get_gridline)
#      1505    0.013    0.000    0.370    0.000 axis.py:618(_get_gridline)
#   1246832    0.366    0.000    0.366    0.000 {built-in method builtins.sum}
#     53965    0.106    0.000    0.362    0.000 fromnumeric.py:64(_wrapreduction)
#       430    0.318    0.001    0.339    0.001 {built-in method matplotlib._image.resample}
#     68423    0.328    0.000    0.328    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      2488    0.014    0.000    0.324    0.000 backend_agg.py:220(get_text_width_height_descent)
#   2583362    0.319    0.000    0.319    0.000 {built-in method builtins.len}
# 378400/312997    0.202    0.000    0.317    0.000 artist.py:230(stale)
#     28380    0.037    0.000    0.311    0.000 markers.py:200(_recache)
#      1720    0.009    0.000    0.310    0.000 axis.py:1357(_copy_tick_props)
#      1505    0.012    0.000    0.305    0.000 axis.py:468(_get_tick1line)
#      2746    0.305    0.000    0.305    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#      6923    0.038    0.000    0.304    0.000 text.py:129(__init__)
#      1505    0.012    0.000    0.296    0.000 axis.py:589(_get_tick1line)
#     10363    0.065    0.000    0.292    0.000 font_manager.py:665(__init__)
#      3010    0.006    0.000    0.282    0.000 lines.py:945(get_path)
#      1505    0.011    0.000    0.277    0.000 axis.py:604(_get_tick2line)
#      2064    0.005    0.000    0.277    0.000 axis.py:770(_set_scale)
#      3010    0.059    0.000    0.276    0.000 lines.py:649(recache)
#      1505    0.012    0.000    0.275    0.000 axis.py:435(_get_text1)
#      2064    0.011    0.000    0.266    0.000 scale.py:68(set_default_locators_and_formatters)
#    626512    0.261    0.000    0.266    0.000 {built-in method builtins.all}
#      1935    0.015    0.000    0.255    0.000 artist.py:650(set_clip_path)
#       258    0.005    0.000    0.251    0.001 axis.py:2121(get_tick_space)
#        43    0.000    0.000    0.249    0.006 __init__.py:354(empty_cache)
#        43    0.249    0.006    0.249    0.006 {built-in method torch._C._cuda_emptyCache}
#       258    0.005    0.000    0.248    0.001 axis.py:2500(get_tick_space)
#      7439    0.020    0.000    0.245    0.000 transforms.py:1429(transform)
#       129    0.002    0.000    0.241    0.002 _base.py:615(_init_axis)
#      1548    0.009    0.000    0.240    0.000 axis.py:801(cla)
#     20511    0.025    0.000    0.237    0.000 fromnumeric.py:1933(any)
#    623416    0.233    0.000    0.233    0.000 padding.py:24(<listcomp>)
#      6536    0.017    0.000    0.233    0.000 transforms.py:1522(transform_point)
#      5160    0.025    0.000    0.214    0.000 lines.py:1233(update_from)
#      2924    0.007    0.000    0.211    0.000 patches.py:194(get_transform)
#     20210    0.129    0.000    0.207    0.000 artist.py:87(__init__)
#    349677    0.205    0.000    0.205    0.000 __init__.py:931(__getitem__)
#     58394    0.043    0.000    0.205    0.000 numeric.py:433(asarray)
#       774    0.002    0.000    0.200    0.000 axis.py:231(set_clip_path)
#      2064    0.004    0.000    0.197    0.000 ticker.py:2484(__init__)
#       903    0.007    0.000    0.194    0.000 transforms.py:740(union)
#      2064    0.007    0.000    0.191    0.000 ticker.py:1794(__init__)
#    623518    0.188    0.000    0.188    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#      7439    0.011    0.000    0.187    0.000 transforms.py:2481(transform_affine)
#    271402    0.084    0.000    0.187    0.000 {built-in method builtins.isinstance}
#      4128    0.015    0.000    0.184    0.000 ticker.py:1870(set_params)
#      2150    0.002    0.000    0.183    0.000 patches.py:736(get_patch_transform)
#      2150    0.014    0.000    0.182    0.000 patches.py:707(_update_patch_transform)
#     10750    0.032    0.000    0.180    0.000 transforms.py:2076(scale)
#      1505    0.012    0.000    0.174    0.000 axis.py:559(_get_text1)
# 13932/7955    0.047    0.000    0.174    0.000 transforms.py:2505(get_affine)
#     20508    0.022    0.000    0.166    0.000 transforms.py:131(invalidate)
#      9030    0.016    0.000    0.166    0.000 lines.py:1165(set_markerfacecolor)
#       258    0.017    0.000    0.166    0.001 cm.py:208(to_rgba)
#       258    0.005    0.000    0.165    0.001 backend_agg.py:190(draw_text)
#      7181    0.116    0.000    0.155    0.000 text.py:178(update)
#      1505    0.009    0.000    0.152    0.000 axis.py:452(_get_text2)
#       258    0.003    0.000    0.151    0.001 axis.py:705(__init__)
#     15348    0.050    0.000    0.147    0.000 transforms.py:771(__init__)
# 55983/20508    0.093    0.000    0.144    0.000 transforms.py:142(_invalidate_internal)
#      1505    0.009    0.000    0.144    0.000 axis.py:574(_get_text2)
#       129    0.001    0.000    0.139    0.001 pyplot.py:3184(imshow)
#       129    0.001    0.000    0.135    0.001 __init__.py:1774(inner)
#       129    0.002    0.000    0.133    0.001 _axes.py:5348(imshow)
#       172    0.027    0.000    0.125    0.001 colors.py:457(__call__)
#     68757    0.054    0.000    0.123    0.000 artist.py:288(pchanged)
#       129    0.001    0.000    0.121    0.001 _base.py:978(_gen_axes_spines)
#       516    0.003    0.000    0.120    0.000 spines.py:485(linear_spine)
#     32376    0.042    0.000    0.117    0.000 transforms.py:1919(__init__)
#      7095    0.010    0.000    0.111    0.000 transforms.py:350(xmin)
#       645    0.012    0.000    0.110    0.000 transforms.py:753(intersection)
#     42656    0.042    0.000    0.110    0.000 artist.py:66(_stale_axes_callback)
#      3913    0.011    0.000    0.103    0.000 path.py:101(__init__)
#     45549    0.061    0.000    0.102    0.000 abc.py:178(__instancecheck__)
#      2746    0.008    0.000    0.099    0.000 backend_agg.py:271(_get_agg_font)
#       645    0.002    0.000    0.099    0.000 patches.py:570(get_window_extent)
#     13158    0.011    0.000    0.099    0.000 transforms.py:1285(__add__)
#       516    0.006    0.000    0.097    0.000 spines.py:42(__init__)
#     14448    0.021    0.000    0.094    0.000 transforms.py:2584(composite_transform_factory)
#     61831    0.045    0.000    0.093    0.000 transforms.py:1774(__init__)
#       688    0.008    0.000    0.092    0.000 patches.py:49(__init__)
#     34440    0.091    0.000    0.091    0.000 {built-in method numpy.core.multiarray.dot}
#      4128    0.024    0.000    0.090    0.000 ticker.py:1862(_staircase)
#      2150    0.006    0.000    0.089    0.000 transforms.py:2050(rotate_deg_around)
#     15996    0.014    0.000    0.088    0.000 fromnumeric.py:2337(amin)
# 6321/5934    0.017    0.000    0.087    0.000 transforms.py:1072(get_points)
#      3440    0.010    0.000    0.087    0.000 text.py:263(update_from)
#       903    0.006    0.000    0.085    0.000 path.py:521(get_extents)
#       516    0.006    0.000    0.085    0.000 ticker.py:655(set_locs)
#      9030    0.011    0.000    0.084    0.000 lines.py:1177(set_markerfacecoloralt)
#      3394    0.020    0.000    0.081    0.000 transforms.py:2030(rotate_deg)
#     20167    0.028    0.000    0.080    0.000 artist.py:612(set_figure)
#     16340    0.013    0.000    0.079    0.000 artist.py:887(<listcomp>)
#       516    0.001    0.000    0.078    0.000 spines.py:164(register_axis)
#      2746    0.004    0.000    0.077    0.000 font_manager.py:1473(findfont)
#      3913    0.031    0.000    0.076    0.000 path.py:198(_update_values)
#      4899    0.012    0.000    0.076    0.000 transforms.py:833(from_extents)
#     17028    0.021    0.000    0.075    0.000 font_manager.py:989(_normalize_font_family)
#       516    0.001    0.000    0.075    0.000 spines.py:176(cla)
#     16125    0.013    0.000    0.074    0.000 fromnumeric.py:2227(amax)
#      2746    0.006    0.000    0.074    0.000 font_manager.py:1255(findfont)
#     74648    0.046    0.000    0.073    0.000 six.py:586(iteritems)
#     96099    0.073    0.000    0.073    0.000 transforms.py:88(__init__)
#      9030    0.028    0.000    0.073    0.000 lines.py:1052(set_linestyle)
#      3698    0.037    0.000    0.072    0.000 transforms.py:711(translated)
#      2365    0.008    0.000    0.070    0.000 markers.py:722(_set_tickdown)
#      3956    0.014    0.000    0.069    0.000 text.py:854(get_prop_tup)
#      2064    0.019    0.000    0.069    0.000 ticker.py:1843(_validate_steps)
#      2365    0.008    0.000    0.068    0.000 markers.py:702(_set_tickleft)
#     14448    0.031    0.000    0.068    0.000 transforms.py:2403(__init__)
#      9546    0.019    0.000    0.066    0.000 artist.py:858(_update_property)
#      2746    0.004    0.000    0.066    0.000 font_manager.py:1019(get)
#      4128    0.006    0.000    0.066    0.000 shape_base.py:236(hstack)
#     17673    0.017    0.000    0.064    0.000 artist.py:303(set_transform)
#     13158    0.014    0.000    0.064    0.000 __init__.py:584(is_numlike)
#     15050    0.011    0.000    0.064    0.000 axis.py:331(_set_artist_props)
#      8600    0.039    0.000    0.063    0.000 artist.py:963(update_from)
#       516    0.003    0.000    0.062    0.000 axis.py:1827(_get_pixel_distance_along_axis)
#    116676    0.056    0.000    0.062    0.000 {built-in method builtins.getattr}
#      3394    0.027    0.000    0.061    0.000 transforms.py:2014(rotate)
#      5762    0.013    0.000    0.061    0.000 colors.py:142(to_rgba)
#     34308    0.059    0.000    0.059    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1096    0.009    0.000    0.057    0.000 core.py:2772(__new__)
#        43    0.001    0.000    0.057    0.001 display.py:79(publish_display_data)
#     29197    0.050    0.000    0.056    0.000 transforms.py:169(set_children)
#      2365    0.007    0.000    0.056    0.000 markers.py:708(_set_tickright)
#       258    0.032    0.000    0.056    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        43    0.001    0.000    0.056    0.001 zmqshell.py:94(publish)
#      2365    0.007    0.000    0.055    0.000 markers.py:716(_set_tickup)
# 12556/12040    0.030    0.000    0.054    0.000 spines.py:436(get_spine_transform)
#     12194    0.036    0.000    0.054    0.000 font_manager.py:711(__hash__)
#       172    0.001    0.000    0.054    0.000 backend_agg.py:442(get_renderer)
#        86    0.000    0.000    0.054    0.001 pyplot.py:638(close)
# 20382/15222    0.011    0.000    0.053    0.000 transforms.py:2434(_invalidate_internal)
#        43    0.001    0.000    0.053    0.001 _pylab_helpers.py:71(destroy_all)
#      8686    0.016    0.000    0.052    0.000 text.py:840(get_unitless_position)
#       172    0.052    0.000    0.052    0.000 {method 'take' of 'numpy.ndarray' objects}
#       387    0.006    0.000    0.052    0.000 _base.py:1511(apply_aspect)
#      2107    0.004    0.000    0.051    0.000 patches.py:301(_set_facecolor)
#      1032    0.002    0.000    0.051    0.000 text.py:225(_get_xy_display)
# 29554/20106    0.014    0.000    0.051    0.000 {built-in method builtins.hash}
#      5074    0.010    0.000    0.051    0.000 transforms.py:2062(translate)
#       516    0.022    0.000    0.051    0.000 ticker.py:736(_set_format)
#    378658    0.050    0.000    0.050    0.000 artist.py:715(get_animated)
#        43    0.050    0.001    0.050    0.001 {built-in method gc.collect}
#      3698    0.005    0.000    0.050    0.000 font_manager.py:924(copy)
#        86    0.044    0.001    0.050    0.001 backend_agg.py:91(__init__)
#      4128    0.006    0.000    0.049    0.000 shape_base.py:283(<listcomp>)
#     11088    0.006    0.000    0.049    0.000 transforms.py:1795(transform)
#       172    0.007    0.000    0.048    0.000 colors.py:927(__call__)
#        86    0.036    0.000    0.048    0.001 image.py:169(_rgb_to_rgba)
#      2491    0.005    0.000    0.048    0.000 transforms.py:823(from_bounds)
#      4042    0.007    0.000    0.048    0.000 transforms.py:2362(get_matrix)
#     10191    0.010    0.000    0.048    0.000 __init__.py:2042(_to_unmasked_float_array)
#      1505    0.002    0.000    0.046    0.000 axis.py:415(_get_text1_transform)
#      3010    0.013    0.000    0.045    0.000 stride_tricks.py:198(broadcast_arrays)
#       752    0.002    0.000    0.045    0.000 core.py:6350(array)
#       903    0.004    0.000    0.045    0.000 transforms.py:747(<listcomp>)
#     18097    0.009    0.000    0.044    0.000 {method 'get' of 'dict' objects}
#       516    0.003    0.000    0.044    0.000 axis.py:2202(_get_pixel_distance_along_axis)
#      9030    0.010    0.000    0.044    0.000 lines.py:715(set_transform)
#     11346    0.016    0.000    0.044    0.000 transforms.py:1875(transform_affine)
#     12384    0.017    0.000    0.043    0.000 shape_base.py:11(atleast_1d)
#      1505    0.009    0.000    0.043    0.000 _base.py:711(get_xaxis_text1_transform)
#      1505    0.002    0.000    0.043    0.000 axis.py:538(_get_text1_transform)
#     18060    0.028    0.000    0.043    0.000 lines.py:1020(_split_drawstyle_linestyle)
#      2085    0.012    0.000    0.043    0.000 core.py:2928(__array_finalize__)
#      9030    0.015    0.000    0.042    0.000 lines.py:632(set_data)
#       516    0.007    0.000    0.042    0.000 axis.py:974(<listcomp>)
#      4470    0.007    0.000    0.042    0.000 fromnumeric.py:49(_wrapfunc)
#     65206    0.042    0.000    0.042    0.000 _weakrefset.py:70(__contains__)
#      6278    0.016    0.000    0.041    0.000 transforms.py:2768(__init__)
#      1505    0.009    0.000    0.041    0.000 _base.py:791(get_yaxis_text1_transform)
#     45792    0.026    0.000    0.041    0.000 six.py:583(itervalues)
#      7095    0.009    0.000    0.040    0.000 transforms.py:364(xmax)
#      3268    0.018    0.000    0.040    0.000 shape_base.py:555(column_stack)
#       129    0.003    0.000    0.040    0.000 image.py:629(set_data)
#        86    0.001    0.000    0.038    0.000 figure.py:470(_set_dpi)
#     16770    0.010    0.000    0.038    0.000 artist.py:184(convert_xunits)
#      7224    0.008    0.000    0.038    0.000 transforms.py:371(ymax)
# 13803/7525    0.013    0.000    0.038    0.000 _base.py:686(get_xaxis_transform)
#       258    0.038    0.000    0.038    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#      7095    0.008    0.000    0.037    0.000 transforms.py:357(ymin)
#      6794    0.035    0.000    0.037    0.000 font_manager.py:839(set_weight)
#      3956    0.004    0.000    0.037    0.000 {method 'all' of 'numpy.ndarray' objects}
#     26064    0.014    0.000    0.037    0.000 numeric.py:504(asanyarray)
#      1505    0.002    0.000    0.036    0.000 axis.py:418(_get_text2_transform)
#      1505    0.003    0.000    0.036    0.000 axis.py:541(_get_text2_transform)
#      3692    0.003    0.000    0.036    0.000 {method 'min' of 'numpy.ndarray' objects}
#      3741    0.009    0.000    0.036    0.000 axis.py:633(update_position)
#      3741    0.009    0.000    0.036    0.000 axis.py:510(update_position)
#       129    0.002    0.000    0.036    0.000 image.py:850(set_extent)
#        43    0.002    0.000    0.035    0.001 pyplot.py:431(figure)
#      4472    0.005    0.000    0.035    0.000 ticker.py:566(__call__)
#      1419    0.001    0.000    0.035    0.000 patches.py:308(set_facecolor)
#      2064    0.004    0.000    0.035    0.000 transforms.py:807(unit)
#      1505    0.006    0.000    0.034    0.000 _base.py:739(get_xaxis_text2_transform)
#       903    0.003    0.000    0.033    0.000 transforms.py:748(<listcomp>)
#      6794    0.024    0.000    0.033    0.000 font_manager.py:875(set_size)
#      3956    0.003    0.000    0.033    0.000 _methods.py:45(_all)
#        43    0.002    0.000    0.033    0.001 tight_bbox.py:13(adjust_bbox)
#       516    0.003    0.000    0.033    0.000 colors.py:896(process_value)
# 13803/7525    0.009    0.000    0.033    0.000 _base.py:766(get_yaxis_transform)
#      1505    0.006    0.000    0.033    0.000 _base.py:818(get_yaxis_text2_transform)
#       903    0.003    0.000    0.033    0.000 transforms.py:749(<listcomp>)
#       258    0.004    0.000    0.033    0.000 _base.py:3043(set_xlim)
#      3692    0.002    0.000    0.033    0.000 _methods.py:30(_amin)
#      4248    0.032    0.000    0.032    0.000 {built-in method numpy.core.multiarray.zeros}
# 2064/1032    0.004    0.000    0.032    0.000 transforms.py:2513(inverted)
#      6665    0.007    0.000    0.032    0.000 font_manager.py:804(set_family)
#       516    0.001    0.000    0.032    0.000 transforms.py:2241(frozen)
#     20210    0.013    0.000    0.032    0.000 <string>:12(__new__)
#       903    0.002    0.000    0.031    0.000 transforms.py:750(<listcomp>)
#    148261    0.031    0.000    0.031    0.000 {built-in method builtins.iter}
#       129    0.001    0.000    0.031    0.000 _subplots.py:131(update_params)
#        86    0.000    0.000    0.031    0.000 transforms.py:2005(clear)
#  1290/645    0.004    0.000    0.031    0.000 transforms.py:2426(frozen)
#      8686    0.031    0.000    0.031    0.000 {built-in method numpy.core.multiarray.concatenate}
#       903    0.008    0.000    0.030    0.000 {built-in method matplotlib._path.get_path_extents}
#       129    0.002    0.000    0.030    0.000 gridspec.py:456(get_position)
#        43    0.001    0.000    0.030    0.001 backend_bases.py:153(new_figure_manager)
#       129    0.001    0.000    0.030    0.000 axis.py:1939(_update_offset_text_position)
#      1763    0.008    0.000    0.029    0.000 transforms.py:436(bounds)
#      3999    0.029    0.000    0.029    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1161    0.002    0.000    0.028    0.000 transforms.py:1882(transform_point)
#      4128    0.004    0.000    0.028    0.000 axis.py:1515(convert_units)
#     17802    0.015    0.000    0.028    0.000 text.py:1159(set_text)
#       258    0.002    0.000    0.027    0.000 _base.py:2848(tick_params)
#      1290    0.003    0.000    0.027    0.000 shape_base.py:182(vstack)
#       129    0.001    0.000    0.027    0.000 __init__.py:1363(safe_masked_invalid)
#    148565    0.026    0.000    0.026    0.000 {method 'items' of 'dict' objects}
#      1290    0.013    0.000    0.026    0.000 cycler.py:349(by_key)
#     20081    0.014    0.000    0.026    0.000 lines.py:62(_scale_dashes)
#     16770    0.008    0.000    0.026    0.000 artist.py:193(convert_yunits)
#     22747    0.012    0.000    0.026    0.000 figure.py:58(_stale_figure_callback)
#      4958    0.003    0.000    0.026    0.000 {method 'max' of 'numpy.ndarray' objects}
#        86    0.003    0.000    0.026    0.000 patches.py:507(draw)
#      1290    0.007    0.000    0.025    0.000 transforms.py:1790(__eq__)
#      6536    0.007    0.000    0.025    0.000 artist.py:924(set_zorder)
#     14190    0.016    0.000    0.025    0.000 markers.py:226(set_fillstyle)
#       172    0.001    0.000    0.025    0.000 patches.py:664(__init__)
#        43    0.005    0.000    0.025    0.001 figure.py:286(__init__)
# 8084/7826    0.005    0.000    0.024    0.000 transforms.py:2687(get_matrix)
#       344    0.002    0.000    0.024    0.000 core.py:5551(min)
#      4472    0.004    0.000    0.024    0.000 axis.py:311(set_label1)
#      4128    0.004    0.000    0.024    0.000 units.py:118(is_numlike)
#         3    0.018    0.006    0.024    0.008 image.py:299(extract_patches_2d)
#      1806    0.016    0.000    0.024    0.000 axis.py:338(_apply_params)
#    162927    0.024    0.000    0.024    0.000 artist.py:202(axes)
#      4472    0.004    0.000    0.024    0.000 axis.py:322(set_label2)
#       688    0.001    0.000    0.024    0.000 patches.py:417(set_fill)
#        43    0.001    0.000    0.023    0.001 session.py:657(send)
#       129    0.000    0.000    0.023    0.000 pyplot.py:1385(title)
#      9030    0.013    0.000    0.023    0.000 lines.py:1005(set_linewidth)
#       258    0.000    0.000    0.023    0.000 transforms.py:286(__array__)
#     16730    0.023    0.000    0.023    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      2746    0.002    0.000    0.023    0.000 font_manager.py:721(__eq__)
#      2900    0.002    0.000    0.023    0.000 fromnumeric.py:2803(round_)
#       129    0.001    0.000    0.022    0.000 _axes.py:141(set_title)
#      4958    0.002    0.000    0.022    0.000 _methods.py:26(_amax)
#       731    0.001    0.000    0.022    0.000 transforms.py:1778(__array__)
#      2746    0.006    0.000    0.022    0.000 font_manager.py:1015(make_rcparams_key)
#        43    0.001    0.000    0.022    0.001 tight_bbox.py:40(restore_bbox)
#      2085    0.013    0.000    0.022    0.000 core.py:2902(_update_from)
#     12507    0.021    0.000    0.021    0.000 {built-in method matplotlib._path.affine_transform}
#       129    0.004    0.000    0.021    0.000 gridspec.py:84(get_grid_positions)
#       516    0.010    0.000    0.021    0.000 ticker.py:668(_compute_offset)
#      2900    0.003    0.000    0.021    0.000 fromnumeric.py:2734(around)
#      9030    0.013    0.000    0.021    0.000 lines.py:1376(set_dash_capstyle)
#      3741    0.005    0.000    0.021    0.000 transforms.py:1847(frozen)
#        43    0.000    0.000    0.021    0.000 session.py:598(serialize)
#     13158    0.012    0.000    0.020    0.000 lines.py:1200(set_xdata)
#        43    0.000    0.000    0.020    0.000 zmqshell.py:77(_flush_streams)
#     23521    0.014    0.000    0.020    0.000 __init__.py:518(iterable)
#        86    0.001    0.000    0.020    0.000 iostream.py:327(flush)
#       258    0.003    0.000    0.020    0.000 _base.py:1166(_set_title_offset_trans)
#      3698    0.003    0.000    0.020    0.000 transforms.py:2285(get_affine)
#      1290    0.002    0.000    0.020    0.000 shape_base.py:234(<listcomp>)
#      2064    0.010    0.000    0.019    0.000 ticker.py:501(__init__)
#       258    0.003    0.000    0.019    0.000 _base.py:3363(set_ylim)
#      7439    0.007    0.000    0.019    0.000 transforms.py:2485(transform_non_affine)
#      2064    0.017    0.000    0.019    0.000 function_base.py:1079(diff)
#      3096    0.003    0.000    0.019    0.000 transforms.py:1902(inverted)
#       129    0.000    0.000    0.019    0.000 cm.py:356(autoscale_None)
#       430    0.000    0.000    0.019    0.000 transforms.py:1423(__array__)
#       132    0.019    0.000    0.019    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#       129    0.000    0.000    0.019    0.000 _base.py:962(_gen_axes_patch)
#      5762    0.005    0.000    0.019    0.000 colors.py:107(_is_nth_color)
#       129    0.002    0.000    0.018    0.000 axis.py:2166(_get_label)
#     13060    0.018    0.000    0.018    0.000 {built-in method builtins.max}
#     20640    0.018    0.000    0.018    0.000 {built-in method __new__ of type object at 0x56147a1cd560}
#      3010    0.018    0.000    0.018    0.000 stride_tricks.py:179(_broadcast_shape)
#      6665    0.015    0.000    0.018    0.000 font_manager.py:857(set_stretch)
# 13072/12040    0.005    0.000    0.018    0.000 spines.py:158(_ensure_position_is_set)
#       796    0.001    0.000    0.018    0.000 fromnumeric.py:1764(clip)
#      9030    0.012    0.000    0.018    0.000 lines.py:1337(set_dash_joinstyle)
#     22151    0.017    0.000    0.018    0.000 {built-in method builtins.hasattr}
#       301    0.001    0.000    0.018    0.000 colors.py:987(autoscale_None)
#       344    0.002    0.000    0.017    0.000 core.py:5672(max)
#      1548    0.002    0.000    0.017    0.000 transforms.py:2379(blended_transform_factory)
#      3873    0.008    0.000    0.017    0.000 shape_base.py:63(atleast_2d)
#      4472    0.017    0.000    0.017    0.000 ticker.py:771(pprint_val)
#       129    0.002    0.000    0.017    0.000 axis.py:1794(_get_label)
#     13158    0.009    0.000    0.017    0.000 lines.py:1210(set_ydata)
#        17    0.017    0.001    0.017    0.001 {built-in method zeros}
#      9030    0.009    0.000    0.017    0.000 lines.py:1153(set_markeredgewidth)
# 2257/1569    0.005    0.000    0.016    0.000 {method 'view' of 'numpy.generic' objects}
#      1505    0.005    0.000    0.016    0.000 axis.py:421(apply_tickdir)
#      2666    0.006    0.000    0.016    0.000 transforms.py:1039(__init__)
#       258    0.001    0.000    0.016    0.000 _base.py:846(_update_transScale)
#       129    0.001    0.000    0.016    0.000 _base.py:625(set_figure)
#      1244    0.015    0.000    0.016    0.000 __init__.py:1160(__setitem__)
#      1505    0.005    0.000    0.016    0.000 axis.py:544(apply_tickdir)
#      1032    0.012    0.000    0.016    0.000 transforms.py:2909(nonsingular)
#      2746    0.008    0.000    0.015    0.000 font_manager.py:1017(<listcomp>)
#      6923    0.007    0.000    0.015    0.000 text.py:1209(set_usetex)
#     90300    0.015    0.000    0.015    0.000 {method 'startswith' of 'str' objects}
#      9718    0.011    0.000    0.015    0.000 lines.py:34(_get_dash_pattern)
#      1290    0.002    0.000    0.014    0.000 fromnumeric.py:2016(all)
#       387    0.002    0.000    0.014    0.000 _base.py:903(_set_position)
#      9030    0.010    0.000    0.014    0.000 lines.py:1189(set_markersize)
#       258    0.000    0.000    0.014    0.000 transforms.py:1535(transform_path)
#      9030    0.008    0.000    0.014    0.000 lines.py:1390(set_solid_capstyle)
#      4730    0.007    0.000    0.014    0.000 ticker.py:557(fix_minus)
#       387    0.009    0.000    0.014    0.000 linalg.py:468(inv)
# 19737/11438    0.012    0.000    0.014    0.000 transforms.py:2465(_get_is_affine)
#      9030    0.007    0.000    0.014    0.000 lines.py:962(set_antialiased)
#      2064    0.006    0.000    0.014    0.000 axis.py:1588(set_major_locator)
#      9030    0.008    0.000    0.014    0.000 lines.py:984(set_drawstyle)
#      1290    0.004    0.000    0.014    0.000 transforms.py:2312(__init__)
#        86    0.000    0.000    0.014    0.000 threading.py:531(wait)
#       516    0.002    0.000    0.013    0.000 spines.py:392(set_position)
#      2107    0.004    0.000    0.013    0.000 patches.py:273(_set_edgecolor)
#      9030    0.008    0.000    0.013    0.000 lines.py:1350(set_solid_joinstyle)
#       172    0.000    0.000    0.013    0.000 session.py:102(<lambda>)
#     17028    0.013    0.000    0.013    0.000 font_manager.py:993(<listcomp>)
#        84    0.001    0.000    0.013    0.000 threading.py:261(wait)
#       172    0.001    0.000    0.013    0.000 jsonapi.py:31(dumps)
#      6923    0.007    0.000    0.013    0.000 text.py:949(set_color)
#      9030    0.010    0.000    0.013    0.000 lines.py:619(axes)
#      3139    0.003    0.000    0.013    0.000 artist.py:814(set_alpha)
#      2322    0.004    0.000    0.012    0.000 transforms.py:2667(__init__)
#       639    0.012    0.000    0.012    0.000 {method 'acquire' of '_thread.lock' objects}
#      5418    0.004    0.000    0.012    0.000 re.py:160(match)
#       172    0.001    0.000    0.012    0.000 __init__.py:182(dumps)
#      2746    0.008    0.000    0.012    0.000 backend_agg.py:55(get_hinting_flag)
#      2150    0.004    0.000    0.012    0.000 patches.py:726(_convert_units)
#      4472    0.006    0.000    0.012    0.000 transforms.py:2782(get_matrix)
#      1032    0.003    0.000    0.012    0.000 _base.py:3024(_validate_converted_limits)
#        43    0.001    0.000    0.011    0.000 <ipython-input-67-379e23d571b4>:9(to_disp)
#       129    0.001    0.000    0.011    0.000 axis.py:1812(_get_offset_text)
#       903    0.002    0.000    0.011    0.000 transforms.py:282(frozen)
#       602    0.001    0.000    0.011    0.000 backend_bases.py:787(new_gc)
#       172    0.000    0.000    0.011    0.000 encoder.py:181(encode)
#       129    0.001    0.000    0.011    0.000 axis.py:2186(_get_offset_text)
#      9030    0.006    0.000    0.011    0.000 lines.py:1140(set_markeredgecolor)
#       172    0.009    0.000    0.011    0.000 encoder.py:203(iterencode)
#     55599    0.011    0.000    0.011    0.000 {method 'append' of 'list' objects}
#       129    0.006    0.000    0.010    0.000 core.py:2328(masked_invalid)
#       602    0.003    0.000    0.010    0.000 backend_bases.py:849(__init__)
#      9030    0.005    0.000    0.010    0.000 lines.py:975(set_color)
#      1419    0.001    0.000    0.010    0.000 patches.py:288(set_edgecolor)
#      1502    0.001    0.000    0.010    0.000 text.py:236(get_rotation)
#       796    0.010    0.000    0.010    0.000 {method 'clip' of 'numpy.ndarray' objects}
#     41839    0.010    0.000    0.010    0.000 transforms.py:991(get_points)
#       774    0.003    0.000    0.010    0.000 fromnumeric.py:36(_wrapit)
#     24725    0.010    0.000    0.010    0.000 artist.py:210(axes)
#      2881    0.001    0.000    0.009    0.000 transforms.py:2746(get_matrix)
#      3440    0.003    0.000    0.009    0.000 transforms.py:2233(_get_is_affine)
#       430    0.003    0.000    0.009    0.000 __init__.py:333(connect)
#      6794    0.004    0.000    0.009    0.000 font_manager.py:1102(get_default_size)
#       258    0.002    0.000    0.009    0.000 _base.py:604(get_window_extent)
#       473    0.001    0.000    0.009    0.000 formatters.py:374(lookup)
#      1502    0.003    0.000    0.009    0.000 text.py:1170(is_math_text)
#      8428    0.007    0.000    0.009    0.000 artist.py:317(get_transform)
#       258    0.008    0.000    0.009    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       258    0.001    0.000    0.009    0.000 transforms.py:1734(set)
#      1502    0.008    0.000    0.009    0.000 text.py:56(get_rotation)
#     53922    0.009    0.000    0.009    0.000 {method 'lower' of 'str' objects}
#       129    0.001    0.000    0.009    0.000 _base.py:2108(update_datalim)
#      1548    0.004    0.000    0.009    0.000 axis.py:1529(set_units)
#      2064    0.003    0.000    0.009    0.000 axis.py:1566(set_major_formatter)
#       258    0.004    0.000    0.009    0.000 transforms.py:564(anchored)
#      1352    0.009    0.000    0.009    0.000 {method 'round' of 'numpy.ndarray' objects}
#      6665    0.005    0.000    0.009    0.000 font_manager.py:817(set_style)
#       258    0.001    0.000    0.008    0.000 _base.py:2130(_process_unit_info)
#       387    0.002    0.000    0.008    0.000 transforms.py:1009(set)
#      4445    0.003    0.000    0.008    0.000 <frozen importlib._bootstrap>:995(_handle_fromlist)
#      1032    0.004    0.000    0.008    0.000 numeric.py:2491(seterr)
#      5203    0.006    0.000    0.008    0.000 transforms.py:409(width)
#     15843    0.008    0.000    0.008    0.000 {method 'update' of 'dict' objects}
#       258    0.000    0.000    0.008    0.000 transforms.py:1546(transform_path_affine)
#        43    0.000    0.000    0.008    0.000 <decorator-gen-10>:1(__call__)
#      2064    0.002    0.000    0.008    0.000 axis.py:1599(set_minor_locator)
#       129    0.002    0.000    0.008    0.000 _base.py:647(_set_lim_and_transforms)
#      6923    0.004    0.000    0.008    0.000 text.py:240(set_rotation_mode)
#        43    0.001    0.000    0.008    0.000 formatters.py:689(__call__)
#       516    0.002    0.000    0.008    0.000 fromnumeric.py:2159(ptp)
#       129    0.000    0.000    0.008    0.000 image.py:827(get_window_extent)
#       258    0.001    0.000    0.008    0.000 transforms.py:1812(transform_path_affine)
#      2064    0.002    0.000    0.008    0.000 axis.py:1577(set_minor_formatter)
#     32373    0.008    0.000    0.008    0.000 transforms.py:1957(get_matrix)
#       258    0.001    0.000    0.008    0.000 axis.py:1456(update_units)
#      2064    0.007    0.000    0.008    0.000 axis.py:824(reset_ticks)
#       129    0.001    0.000    0.007    0.000 image.py:787(__init__)
#       519    0.001    0.000    0.007    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       258    0.003    0.000    0.007    0.000 transforms.py:611(shrunk_to_aspect)
#       129    0.001    0.000    0.007    0.000 transforms.py:905(update_from_data_xy)
#   516/258    0.003    0.000    0.007    0.000 units.py:141(get_converter)
#       688    0.001    0.000    0.007    0.000 core.py:294(_extremum_fill_value)
#       473    0.002    0.000    0.007    0.000 formatters.py:397(lookup_by_type)
#       172    0.000    0.000    0.007    0.000 core.py:7763(asarray)
#        44    0.003    0.000    0.007    0.000 tensor.py:324(__rdiv__)
#     52540    0.007    0.000    0.007    0.000 {built-in method builtins.id}
#       860    0.001    0.000    0.007    0.000 core.py:3659(filled)
#      1161    0.004    0.000    0.007    0.000 __init__.py:1564(get_siblings)
#       519    0.000    0.000    0.007    0.000 _methods.py:34(_sum)
#     45147    0.007    0.000    0.007    0.000 {method 'values' of 'dict' objects}
#        43    0.000    0.000    0.007    0.000 session.py:583(sign)
#    258/43    0.002    0.000    0.007    0.000 jsonutil.py:109(json_clean)
#       129    0.001    0.000    0.007    0.000 image.py:204(__init__)
#      2841    0.006    0.000    0.006    0.000 {built-in method builtins.min}
#      3010    0.005    0.000    0.006    0.000 stride_tricks.py:250(<listcomp>)
#      6665    0.004    0.000    0.006    0.000 font_manager.py:829(set_variant)
#      1032    0.004    0.000    0.006    0.000 axis.py:875(_translate_tick_kw)
#      1548    0.006    0.000    0.006    0.000 {method 'round' of 'numpy.generic' objects}
#       516    0.003    0.000    0.006    0.000 _methods.py:151(_ptp)
#       387    0.001    0.000    0.006    0.000 _base.py:857(get_position)
#     14394    0.006    0.000    0.006    0.000 cycler.py:227(<genexpr>)
#      3010    0.005    0.000    0.006    0.000 axis.py:192(_set_labelrotation)
#       258    0.000    0.000    0.006    0.000 fromnumeric.py:2092(cumsum)
#      1333    0.003    0.000    0.006    0.000 patches.py:351(set_linewidth)
#       129    0.001    0.000    0.006    0.000 transforms.py:537(transformed)
#      2746    0.004    0.000    0.006    0.000 font_manager.py:1383(get_font)
#       258    0.001    0.000    0.006    0.000 transforms.py:1558(transform_path_non_affine)
#       516    0.003    0.000    0.006    0.000 _base.py:4081(get_children)
#       129    0.001    0.000    0.006    0.000 gridspec.py:266(get_subplot_params)
#        43    0.001    0.000    0.006    0.000 pretty.py:359(pretty)
#        46    0.000    0.000    0.006    0.000 tensor.py:395(__array__)
#       516    0.001    0.000    0.006    0.000 numeric.py:2891(__enter__)
#      1290    0.003    0.000    0.006    0.000 transforms.py:2529(__init__)
#      5504    0.003    0.000    0.006    0.000 traitlets.py:545(__get__)
#      2064    0.005    0.000    0.006    0.000 scale.py:560(scale_factory)
#       774    0.001    0.000    0.006    0.000 text.py:532(set_clip_box)
#       172    0.000    0.000    0.005    0.000 hmac.py:90(update)
#       516    0.001    0.000    0.005    0.000 ticker.py:1699(le)
#       215    0.005    0.000    0.005    0.000 {method 'update' of '_hashlib.HASH' objects}
#      4257    0.003    0.000    0.005    0.000 text.py:1114(set_x)
#      1502    0.003    0.000    0.005    0.000 __init__.py:2026(is_math_text)
#      1290    0.002    0.000    0.005    0.000 transforms.py:2573(get_matrix)
#      1032    0.002    0.000    0.005    0.000 ticker.py:201(_divmod)
#         3    0.000    0.000    0.005    0.002 validation.py:310(check_array)
#      1806    0.005    0.000    0.005    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       217    0.004    0.000    0.005    0.000 iostream.py:195(schedule)
#       516    0.001    0.000    0.005    0.000 _base.py:952(_set_artist_props)
#       645    0.003    0.000    0.005    0.000 _base.py:3006(get_xlim)
#       344    0.000    0.000    0.005    0.000 core.py:309(minimum_fill_value)
#      5418    0.005    0.000    0.005    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#       258    0.002    0.000    0.005    0.000 axis.py:1165(<listcomp>)
#        43    0.000    0.000    0.005    0.000 backend_bases.py:163(new_figure_manager_given_figure)
#     34658    0.005    0.000    0.005    0.000 artist.py:940(sticky_edges)
#       688    0.002    0.000    0.005    0.000 patches.py:373(set_linestyle)
#       129    0.001    0.000    0.005    0.000 _base.py:1903(add_image)
#        86    0.000    0.000    0.005    0.000 backend_agg.py:142(draw_path)
#       516    0.004    0.000    0.005    0.000 ticker.py:1772(scale_range)
#       516    0.001    0.000    0.005    0.000 numeric.py:2896(__exit__)
#       301    0.000    0.000    0.004    0.000 {method 'any' of 'numpy.ndarray' objects}
#       860    0.001    0.000    0.004    0.000 core.py:214(_recursive_fill_value)
#        44    0.004    0.000    0.004    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#      4257    0.002    0.000    0.004    0.000 text.py:1123(set_y)
#      1032    0.004    0.000    0.004    0.000 {built-in method builtins.sorted}
#       516    0.003    0.000    0.004    0.000 ticker.py:710(_set_orderOfMagnitude)
#        51    0.001    0.000    0.004    0.000 functional.py:1894(interpolate)
#       172    0.000    0.000    0.004    0.000 backend_bases.py:2337(mpl_connect)
#       129    0.000    0.000    0.004    0.000 pyplot.py:1432(axis)
#        43    0.000    0.000    0.004    0.000 pretty.py:502(_default_pprint)
#       258    0.001    0.000    0.004    0.000 _base.py:1483(get_data_ratio)
#      2746    0.004    0.000    0.004    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#       473    0.001    0.000    0.004    0.000 {method 'view' of 'numpy.ndarray' objects}
#       301    0.000    0.000    0.004    0.000 _methods.py:42(_any)
#        43    0.000    0.000    0.004    0.000 pretty.py:698(_repr_pprint)
#        86    0.003    0.000    0.004    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      4042    0.004    0.000    0.004    0.000 axis.py:215(get_tick_padding)
#      6922    0.004    0.000    0.004    0.000 core.py:3345(dtype)
#      2746    0.004    0.000    0.004    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       344    0.002    0.000    0.004    0.000 transforms.py:427(size)
#      9030    0.004    0.000    0.004    0.000 stride_tricks.py:254(<genexpr>)
#       774    0.002    0.000    0.004    0.000 spines.py:148(get_patch_transform)
#       559    0.000    0.000    0.004    0.000 {built-in method builtins.repr}
#       387    0.001    0.000    0.004    0.000 _base.py:1290(set_aspect)
#       688    0.003    0.000    0.004    0.000 core.py:3158(__getitem__)
#      5418    0.004    0.000    0.004    0.000 re.py:278(_compile)
#       258    0.002    0.000    0.004    0.000 path.py:164(_fast_from_codes_and_verts)
#       129    0.001    0.000    0.004    0.000 axis.py:2307(_update_offset_text_position)
#      1548    0.003    0.000    0.004    0.000 cycler.py:225(__iter__)
#        43    0.001    0.000    0.003    0.000 backend_bases.py:1770(__init__)
#        43    0.000    0.000    0.003    0.000 figure.py:279(__repr__)
#       516    0.001    0.000    0.003    0.000 __init__.py:2346(safe_first_element)
#      6020    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      9030    0.003    0.000    0.003    0.000 lines.py:537(set_markevery)
#       129    0.001    0.000    0.003    0.000 transforms.py:869(update_from_path)
#     21457    0.003    0.000    0.003    0.000 {method 'pop' of 'dict' objects}
#      1677    0.003    0.000    0.003    0.000 transforms.py:392(intervalx)
#       258    0.001    0.000    0.003    0.000 transforms.py:961(intervalx)
#      1032    0.001    0.000    0.003    0.000 axis.py:2062(get_view_interval)
#        43    0.000    0.000    0.003    0.000 session.py:564(msg)
#      1032    0.001    0.000    0.003    0.000 axis.py:2440(get_view_interval)
#       774    0.001    0.000    0.003    0.000 artist.py:637(set_clip_box)
#       688    0.001    0.000    0.003    0.000 core.py:296(_scalar_fill_value)
#      1204    0.001    0.000    0.003    0.000 patches.py:440(set_capstyle)
#       516    0.001    0.000    0.003    0.000 pyplot.py:966(gca)
#       516    0.001    0.000    0.003    0.000 ticker.py:1715(ge)
#        43    0.000    0.000    0.003    0.000 figure.py:2169(get_default_bbox_extra_artists)
#      1204    0.001    0.000    0.003    0.000 transforms.py:296(x0)
#       258    0.000    0.000    0.003    0.000 artist.py:243(get_window_extent)
#       344    0.000    0.000    0.003    0.000 core.py:360(maximum_fill_value)
#      1032    0.003    0.000    0.003    0.000 numeric.py:2592(geterr)
#       516    0.002    0.000    0.003    0.000 spines.py:318(_calc_offset_transform)
#       602    0.001    0.000    0.003    0.000 numerictypes.py:687(issubdtype)
#      1419    0.001    0.000    0.003    0.000 core.py:596(filled)
#       129    0.001    0.000    0.003    0.000 copy.py:67(copy)
#        86    0.001    0.000    0.003    0.000 figure.py:873(set_size_inches)
#       645    0.002    0.000    0.003    0.000 _base.py:3345(get_ylim)
#       129    0.001    0.000    0.003    0.000 _base.py:1662(axis)
#      1096    0.001    0.000    0.003    0.000 core.py:1326(make_mask_descr)
#       129    0.001    0.000    0.003    0.000 figure.py:122(add)
#       258    0.001    0.000    0.003    0.000 transforms.py:966(intervaly)
#       516    0.002    0.000    0.003    0.000 axis.py:1172(get_tick_padding)
#        43    0.000    0.000    0.003    0.000 session.py:561(msg_header)
#     13029    0.003    0.000    0.003    0.000 artist.py:711(get_visible)
#       860    0.002    0.000    0.003    0.000 __init__.py:161(__init__)
#       129    0.001    0.000    0.003    0.000 __init__.py:68(process_projection_requirements)
#       430    0.001    0.000    0.003    0.000 figure.py:462(_get_axes)
#      1290    0.001    0.000    0.003    0.000 formatters.py:550(_in_deferred_types)
#      2193    0.003    0.000    0.003    0.000 __init__.py:313(__init__)
#      7052    0.003    0.000    0.003    0.000 transforms.py:1754(_get_is_affine)
#      5504    0.003    0.000    0.003    0.000 traitlets.py:526(get)
#     14940    0.003    0.000    0.003    0.000 font_manager.py:784(get_file)
#       516    0.001    0.000    0.003    0.000 text.py:1105(set_position)
#       559    0.002    0.000    0.003    0.000 figure.py:82(as_list)
#      1677    0.002    0.000    0.003    0.000 transforms.py:400(intervaly)
#      3117    0.001    0.000    0.003    0.000 core.py:1359(getmask)
#       258    0.000    0.000    0.003    0.000 transforms.py:1662(__init__)
#      1032    0.002    0.000    0.003    0.000 transforms.py:1851(_get_is_separable)
#        43    0.000    0.000    0.003    0.000 <decorator-gen-11>:1(__call__)
#       172    0.001    0.000    0.003    0.000 figure.py:208(update)
#      1419    0.002    0.000    0.003    0.000 __init__.py:1491(clean)
#        43    0.000    0.000    0.003    0.000 backend_bases.py:2391(mpl_disconnect)
#        43    0.003    0.000    0.003    0.000 {built-in method binascii.b2a_base64}
#     15456    0.002    0.000    0.002    0.000 font_manager.py:781(get_size_in_points)
#      1032    0.002    0.000    0.002    0.000 getlimits.py:376(__new__)
#       129    0.000    0.000    0.002    0.000 transforms.py:1514(get_matrix)
#       516    0.000    0.000    0.002    0.000 transforms.py:1713(frozen)
#       516    0.001    0.000    0.002    0.000 axis.py:779(limit_range_for_scale)
#     12194    0.002    0.000    0.002    0.000 font_manager.py:730(get_family)
#       516    0.000    0.000    0.002    0.000 artist.py:828(set_visible)
#      6318    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#       344    0.001    0.000    0.002    0.000 figure.py:913(get_size_inches)
#       516    0.002    0.000    0.002    0.000 {built-in method numpy.core.multiarray.arange}
#       129    0.000    0.000    0.002    0.000 core.py:3531(shrink_mask)
#        43    0.001    0.000    0.002    0.000 __init__.py:362(disconnect)
#      3504    0.002    0.000    0.002    0.000 core.py:3361(shape)
#     19092    0.002    0.000    0.002    0.000 transforms.py:1821(get_affine)
#      1096    0.002    0.000    0.002    0.000 core.py:1312(_replace_dtype_fields)
#       688    0.001    0.000    0.002    0.000 numerictypes.py:759(__getitem__)
#      2322    0.002    0.000    0.002    0.000 transforms.py:418(height)
#        51    0.002    0.000    0.002    0.000 {built-in method torch._C._nn.upsample_nearest2d}
#      8256    0.002    0.000    0.002    0.000 ticker.py:242(set_axis)
#        43    0.000    0.000    0.002    0.000 formatters.py:903(__call__)
#       172    0.001    0.000    0.002    0.000 core.py:3582(get_fill_value)
#       129    0.000    0.000    0.002    0.000 core.py:1546(_shrink_mask)
#       860    0.001    0.000    0.002    0.000 core.py:229(_get_dtype_of)
#        86    0.000    0.000    0.002    0.000 backend_bases.py:263(__init__)
#       258    0.000    0.000    0.002    0.000 ticker.py:623(get_offset)
#     10704    0.002    0.000    0.002    0.000 text.py:872(get_text)
#       129    0.000    0.000    0.002    0.000 figure.py:1819(sca)
#      2408    0.002    0.000    0.002    0.000 {method 'item' of 'numpy.generic' objects}
#        43    0.000    0.000    0.002    0.000 fromnumeric.py:1821(sum)
#     12194    0.002    0.000    0.002    0.000 font_manager.py:743(get_style)
#      6923    0.002    0.000    0.002    0.000 text.py:584(set_wrap)
#       516    0.000    0.000    0.002    0.000 fromnumeric.py:1577(nonzero)
#       946    0.001    0.000    0.002    0.000 {built-in method builtins.next}
#       129    0.001    0.000    0.002    0.000 cm.py:178(__init__)
#       258    0.001    0.000    0.002    0.000 artist.py:901(set_label)
#       129    0.000    0.000    0.002    0.000 text.py:1069(set_fontsize)
#     12194    0.002    0.000    0.002    0.000 font_manager.py:758(get_weight)
#       774    0.001    0.000    0.002    0.000 patches.py:208(get_patch_transform)
#     12194    0.002    0.000    0.002    0.000 font_manager.py:751(get_variant)
#       129    0.000    0.000    0.002    0.000 transforms.py:815(null)
#      2128    0.002    0.000    0.002    0.000 core.py:3560(_get_data)
#       516    0.001    0.000    0.002    0.000 core.py:669(getdata)
#      2064    0.001    0.000    0.002    0.000 function_base.py:241(iterable)
#       430    0.001    0.000    0.002    0.000 dir2.py:53(get_real_method)
#         3    0.000    0.000    0.002    0.001 validation.py:33(_assert_all_finite)
#       516    0.000    0.000    0.002    0.000 axis.py:962(_set_artist_props)
#       129    0.000    0.000    0.002    0.000 _base.py:4133(get_default_bbox_extra_artists)
#       258    0.000    0.000    0.002    0.000 _base.py:155(__init__)
#       129    0.001    0.000    0.002    0.000 _base.py:4185(<listcomp>)
#      2322    0.001    0.000    0.002    0.000 __init__.py:637(_string_to_bool)
#      3004    0.002    0.000    0.002    0.000 {method 'count' of 'str' objects}
#       129    0.000    0.000    0.002    0.000 text.py:1058(set_size)
#       129    0.000    0.000    0.002    0.000 figure.py:115(bubble)
#      1204    0.001    0.000    0.002    0.000 numerictypes.py:619(issubclass_)
#       344    0.001    0.000    0.002    0.000 contextlib.py:135(helper)
#       387    0.001    0.000    0.002    0.000 _base.py:1365(set_adjustable)
#       258    0.001    0.000    0.002    0.000 transforms.py:1673(_init)
#        86    0.001    0.000    0.002    0.000 textpath.py:35(__init__)
#       258    0.000    0.000    0.002    0.000 _base.py:2968(get_xbound)
#       344    0.000    0.000    0.002    0.000 contextlib.py:57(__enter__)
#       516    0.000    0.000    0.002    0.000 axis.py:764(get_transform)
#       172    0.002    0.000    0.002    0.000 {built-in method numpy.core.multiarray.copyto}
#       387    0.001    0.000    0.002    0.000 linalg.py:141(_commonType)
#       129    0.000    0.000    0.002    0.000 figure.py:1012(_make_key)
#       516    0.002    0.000    0.002    0.000 transforms.py:1717(_set)
#       387    0.001    0.000    0.002    0.000 __init__.py:1206(push)
#      4472    0.002    0.000    0.002    0.000 transforms.py:2963(interval_contains)
#     12194    0.002    0.000    0.002    0.000 font_manager.py:767(get_stretch)
#       989    0.002    0.000    0.002    0.000 {method 'format' of 'str' objects}
#        50    0.002    0.000    0.002    0.000 {built-in method clamp}
#      6665    0.002    0.000    0.002    0.000 font_manager.py:900(set_file)
#       430    0.001    0.000    0.002    0.000 __init__.py:183(add_destroy_callback)
#       344    0.001    0.000    0.002    0.000 contextlib.py:63(__exit__)
#       129    0.000    0.000    0.002    0.000 pyplot.py:338(sci)
#      5676    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#      1548    0.002    0.000    0.002    0.000 {built-in method math.log10}
#       645    0.001    0.000    0.002    0.000 _base.py:3150(get_xscale)
#      4730    0.002    0.000    0.002    0.000 markers.py:292(_set_nothing)
#       172    0.000    0.000    0.002    0.000 core.py:443(_check_fill_value)
#       129    0.000    0.000    0.002    0.000 image.py:266(changed)
#        43    0.000    0.000    0.002    0.000 session.py:509(msg_id)
#      1032    0.001    0.000    0.001    0.000 transforms.py:2127(_get_is_separable)
#      9976    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
#        43    0.000    0.000    0.001    0.000 figure.py:176(__init__)
#        43    0.000    0.000    0.001    0.000 <decorator-gen-12>:1(__call__)
#       258    0.001    0.000    0.001    0.000 _base.py:168(set_prop_cycle)
#       129    0.001    0.000    0.001    0.000 copy.py:269(_reconstruct)
#      1032    0.001    0.000    0.001    0.000 ticker.py:1678(closeto)
#       516    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.empty}
#        86    0.000    0.000    0.001    0.000 jsonutil.py:87(date_default)
#        86    0.000    0.000    0.001    0.000 figure.py:961(set_facecolor)
#       516    0.001    0.000    0.001    0.000 pyplot.py:595(gcf)
#        43    0.000    0.000    0.001    0.000 session.py:121(new_id)
#       946    0.001    0.000    0.001    0.000 backend_bases.py:1077(set_foreground)
#       129    0.000    0.000    0.001    0.000 text.py:1085(set_fontweight)
#       258    0.000    0.000    0.001    0.000 __init__.py:1789(<genexpr>)
#      2488    0.001    0.000    0.001    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#      5160    0.001    0.000    0.001    0.000 markers.py:248(get_marker)
#       129    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.unravel_index}
#       108    0.001    0.000    0.001    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      1032    0.001    0.000    0.001    0.000 figure.py:247(_update_this)
#       430    0.001    0.000    0.001    0.000 weakref.py:354(__init__)
#       129    0.001    0.000    0.001    0.000 {built-in method matplotlib._path.update_path_extents}
#      5719    0.001    0.000    0.001    0.000 figure.py:467(_get_dpi)
#       129    0.000    0.000    0.001    0.000 cm.py:383(changed)
#       516    0.000    0.000    0.001    0.000 scale.py:82(get_transform)
#       387    0.001    0.000    0.001    0.000 _base.py:930(set_axes_locator)
#      3913    0.001    0.000    0.001    0.000 __init__.py:378(process)
#       129    0.000    0.000    0.001    0.000 text.py:1073(set_weight)
#       129    0.000    0.000    0.001    0.000 image.py:256(set_alpha)
#        43    0.000    0.000    0.001    0.000 figure.py:1765(_set_artist_props)
#       129    0.001    0.000    0.001    0.000 gridspec.py:175(__init__)
#       258    0.001    0.000    0.001    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#       129    0.000    0.000    0.001    0.000 __init__.py:1231(bubble)
#      2580    0.001    0.000    0.001    0.000 cycler.py:371(<genexpr>)
#      1806    0.001    0.000    0.001    0.000 axis.py:340(<listcomp>)
#       688    0.001    0.000    0.001    0.000 numerictypes.py:565(obj2sctype)
#      1032    0.001    0.000    0.001    0.000 {built-in method numpy.core.umath.seterrobj}
#        10    0.001    0.000    0.001    0.000 {method 'std' of 'torch._C._TensorBase' objects}
#      6192    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#       688    0.001    0.000    0.001    0.000 patches.py:457(set_joinstyle)
#        43    0.000    0.000    0.001    0.000 formatters.py:949(__call__)
#      2064    0.001    0.000    0.001    0.000 ticker.py:525(set_useOffset)
#      1548    0.001    0.000    0.001    0.000 cycler.py:138(keys)
#       129    0.000    0.000    0.001    0.000 __init__.py:2362(sanitize_sequence)
#       344    0.001    0.000    0.001    0.000 contextlib.py:37(__init__)
#        43    0.001    0.000    0.001    0.000 figure.py:1401(clf)
#        43    0.000    0.000    0.001    0.000 iostream.py:260(send_multipart)
#      5676    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#       387    0.001    0.000    0.001    0.000 linalg.py:108(_makearray)
#       303    0.001    0.000    0.001    0.000 threading.py:1102(is_alive)
#      1333    0.001    0.000    0.001    0.000 transforms.py:305(y0)
#       602    0.001    0.000    0.001    0.000 artist.py:759(_set_gc_clip)
#       258    0.001    0.000    0.001    0.000 weakref.py:438(items)
#      1244    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      3010    0.001    0.000    0.001    0.000 axis.py:172(<dictcomp>)
#       129    0.000    0.000    0.001    0.000 figure.py:1031(fixlist)
#       516    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.min_scalar_type}
#       258    0.000    0.000    0.001    0.000 transforms.py:2193(__init__)
#       258    0.000    0.000    0.001    0.000 _base.py:3308(get_ybound)
#      3096    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#      5160    0.001    0.000    0.001    0.000 markers.py:223(get_fillstyle)
#        43    0.000    0.000    0.001    0.000 iostream.py:207(send_multipart)
#        43    0.000    0.000    0.001    0.000 pretty.py:342(__init__)
#      1032    0.001    0.000    0.001    0.000 ticker.py:1687(__init__)
#        43    0.000    0.000    0.001    0.000 backend_bases.py:2669(__init__)
#       774    0.001    0.000    0.001    0.000 text.py:524(_update_clip_properties)
#       344    0.001    0.000    0.001    0.000 transforms.py:341(p1)
#       172    0.001    0.000    0.001    0.000 mathtext.py:3245(__init__)
#        86    0.000    0.000    0.001    0.000 patches.py:795(set_bounds)
#       129    0.001    0.000    0.001    0.000 gridspec.py:138(__getitem__)
#        86    0.001    0.000    0.001    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       516    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       516    0.001    0.000    0.001    0.000 figure.py:1771(gca)
#       172    0.000    0.000    0.001    0.000 core.py:239(default_fill_value)
#        86    0.000    0.000    0.001    0.000 threading.py:496(__init__)
#       602    0.001    0.000    0.001    0.000 backend_bases.py:1003(set_alpha)
#       731    0.000    0.000    0.001    0.000 patches.py:255(set_antialiased)
#        86    0.000    0.000    0.001    0.000 transforms.py:956(p1)
#       258    0.001    0.000    0.001    0.000 figure.py:896(<genexpr>)
#       516    0.001    0.000    0.001    0.000 axis.py:1408(get_minor_ticks)
#      2110    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#       516    0.001    0.000    0.001    0.000 numeric.py:2887(__init__)
#      1161    0.001    0.000    0.001    0.000 __init__.py:1571(<listcomp>)
#       258    0.001    0.000    0.001    0.000 figure.py:90(get)
#       172    0.000    0.000    0.001

# %%
#Replaces the epitome (e,ev) of an image by another epitome image (emod)
#keeping the mapping intact. The routine can be used to edit images or to
#preprocess by coloring the image accoring to the image (see the segmentation
#part of the web page for more info). K specifies the patch size to use in 
#mapping inference and SPC defines the patch spacing.

def reconstruct(x,K,e,ev,emod,SPC):
    _,NoCh1,Ny,Nx = x.shape
    NoCh2 = emod.shape[0]
    #print(NoCh1,NoCh2)
    if NoCh1 == 1:
        x = torch.stack((x,x,x),dim=0)
        print(x.shape)
    NoCh1,N,Ny = e.shape
    SY = x.shape[2]
    SX = x.shape[3]
    ewrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    evwrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    MINP = 1e-8
    MINV = 1e-2
    ewrap[:,:N,:N] = e
    ewrap[:,N:,:] = ewrap[:,:K-1,:]
    ewrap[:,:,N:] = ewrap[:,:,:K-1]
    evwrap[:,:N,:N] = ev
    evwrap[:,N:,:] = evwrap[:,:K-1,:]
    evwrap[:,:,N:] = evwrap[:,:,:K-1]
    evwrapi = 1./evwrap
    tmp3 = torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K))
    tmp4 = torch.squeeze(cum_sum(torch.unsqueeze(torch.log(evwrap),0),K))
    #print(tmp3.shape,tmp4.shape)
    emodwrap = torch.zeros((NoCh2,N+K-1,N+K-1)).to(device)
    emodwrap[:,:N,:N] = emod
    emodwrap[:,N:,:] = emodwrap[:,:K-1,:]
    emodwrap[:,:,N:] = emodwrap[:,:,:K-1]
    z = torch.zeros((NoCh2,SY,SX)).to(device)
    cnt = torch.zeros((SY,SX)).to(device)
    ixt = 0
    iyt = 0
    #for each patch of the input, find the distribution over the epitome positions,
    #and reconstruct the patch in the input image, using the modified epitome.
    for iy in range(0,SY-K+1,SPC):
        print('y index = '+str(iy))
        for ix in range(0,SX-K+1,SPC):
            #watch for indexing errors
            yc = x[:,:,iy:iy+K,ix:ix+K]
            yct = torch.flip(yc,[2,3])
            lP = torch.zeros(tmp4.shape).to(device)#[:,:] = 0
            #print(evwrapi.shape,ewrap.shape,evwrap.shape,yct.shape)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrap,0),yct))
            lP += -.5*(tmp4+tmp1-2*tmp2+tmp3)
            lP = torch.sum(lP,dim=0)
            P = torch.exp(lP-torch.max(lP))+MINP
            P /= torch.sum(P)
            argmax = torch.argmax(P)
            mxpi = argmax//P.shape[0]
            mxpj = argmax - mxpi*P.shape[0]
            #watch for indexing errors
            newp = emodwrap[:,mxpi:mxpi+K,mxpj:mxpj+K]
            z[:,iy:iy+K,ix:ix+K] += newp 
            cnt[iy:iy+K,ix:ix+K] += 1
            ixt = ix
            iyt = iy
    z = z[:,:iyt+K,:ixt+K]
    cnt = cnt[:iyt+K,:ixt+K]
    z /= cnt
    return z

# %%
# %%time
xcut = 1000
ycut = 1000
cProfile.run('z2=reconstruct(tsIMtorch[:,:4,:xcut,:ycut],17,e[0,:4,:xcut,:ycut],ev[0,:4,:xcut,:ycut],e[0,4:,:xcut,:ycut],3)')
torch.cuda.empty_cache()
# Out:
# y index = 0
# y index = 3
# y index = 6
# y index = 9
# y index = 12
# y index = 15
# y index = 18
# y index = 21
# y index = 24
# y index = 27
# y index = 30
# y index = 33
# y index = 36
# y index = 39
# y index = 42
# y index = 45
# y index = 48
# y index = 51
# y index = 54
# y index = 57
# y index = 60
# y index = 63
# y index = 66
# y index = 69
# y index = 72
# y index = 75
# y index = 78
# y index = 81
# y index = 84
# y index = 87
# y index = 90
# y index = 93
# y index = 96
# y index = 99
# y index = 102
# y index = 105
# y index = 108
# y index = 111
# y index = 114
# y index = 117
# y index = 120
# y index = 123
# y index = 126
# y index = 129
# y index = 132
# y index = 135
# y index = 138
# y index = 141
# y index = 144
# y index = 147
# y index = 150
# y index = 153
# y index = 156
# y index = 159
# y index = 162
# y index = 165
# y index = 168
# y index = 171
# y index = 174
# y index = 177
# y index = 180
# y index = 183
# y index = 186
# y index = 189
# y index = 192
# y index = 195
# y index = 198
# y index = 201
# y index = 204
# y index = 207
# y index = 210
# y index = 213
# y index = 216
# y index = 219
# y index = 222
# y index = 225
# y index = 228
# y index = 231
# y index = 234
# y index = 237
# y index = 240
# y index = 243
# y index = 246
# y index = 249
# y index = 252
# y index = 255
# y index = 258
# y index = 261
# y index = 264
# y index = 267
# y index = 270
# y index = 273
# y index = 276
# y index = 279
# y index = 282
# y index = 285
# y index = 288
# y index = 291
# y index = 294
# y index = 297
# y index = 300
# y index = 303
# y index = 306
# y index = 309
# y index = 312
# y index = 315
# y index = 318
# y index = 321
# y index = 324
# y index = 327
# y index = 330
# y index = 333
# y index = 336
# y index = 339
# y index = 342
# y index = 345
# y index = 348
# y index = 351
# y index = 354
# y index = 357
# y index = 360
# y index = 363
# y index = 366
# y index = 369
# y index = 372
# y index = 375
# y index = 378
# y index = 381
# y index = 384
# y index = 387
# y index = 390
# y index = 393
# y index = 396
# y index = 399
# y index = 402
# y index = 405
# y index = 408
# y index = 411
# y index = 414
# y index = 417
# y index = 420
# y index = 423
# y index = 426
# y index = 429
# y index = 432
# y index = 435
# y index = 438
# y index = 441
# y index = 444
# y index = 447
# y index = 450
# y index = 453
# y index = 456
# y index = 459
# y index = 462
# y index = 465
# y index = 468
# y index = 471
# y index = 474
# y index = 477
# y index = 480
# y index = 483
# y index = 486
# y index = 489
# y index = 492
# y index = 495
# y index = 498
# y index = 501
# y index = 504
# y index = 507
# y index = 510
# y index = 513
# y index = 516
# y index = 519
# y index = 522
# y index = 525
# y index = 528
# y index = 531
# y index = 534
# y index = 537
# y index = 540
# y index = 543
# y index = 546
# y index = 549
# y index = 552
# y index = 555
# y index = 558
# y index = 561
# y index = 564
# y index = 567
# y index = 570
# y index = 573
# y index = 576
# y index = 579
# y index = 582
# y index = 585
# y index = 588
# y index = 591
# y index = 594
# y index = 597
# y index = 600
# y index = 603
# y index = 606
# y index = 609
# y index = 612
# y index = 615
# y index = 618
# y index = 621
# y index = 624
# y index = 627
# y index = 630
# y index = 633
# y index = 636
# y index = 639
# y index = 642
# y index = 645
# y index = 648
# y index = 651
# y index = 654
# y index = 657
# y index = 660
# y index = 663
# y index = 666
# y index = 669
# y index = 672
# y index = 675
# y index = 678
# y index = 681
# y index = 684
# y index = 687
# y index = 690
# y index = 693
# y index = 696
# y index = 699
# y index = 702
# y index = 705
# y index = 708
# y index = 711
# y index = 714
# y index = 717
# y index = 720
# y index = 723
# y index = 726
# y index = 729
# y index = 732
# y index = 735
# y index = 738
# y index = 741
# y index = 744
# y index = 747
# y index = 750
# y index = 753
# y index = 756
# y index = 759
# y index = 762
# y index = 765
# y index = 768
# y index = 771
# y index = 774
# y index = 777
# y index = 780
# y index = 783
# y index = 786
# y index = 789
# y index = 792
# y index = 795
# y index = 798
# y index = 801
# y index = 804
# y index = 807
# y index = 810
# y index = 813
# y index = 816
# y index = 819
# y index = 822
# y index = 825
# y index = 828
# y index = 831
# y index = 834
# y index = 837
# y index = 840
# y index = 843
# y index = 846
# y index = 849
# y index = 852
# y index = 855
# y index = 858
# y index = 861
# y index = 864
# y index = 867
# y index = 870
# y index = 873
# y index = 876
# y index = 879
# y index = 882
# y index = 885
# y index = 888
# y index = 891
# y index = 894
# y index = 897
# y index = 900
# y index = 903
# y index = 906
# y index = 909
# y index = 912
# y index = 915
# y index = 918
# y index = 921
# y index = 924
# y index = 927
# y index = 930
# y index = 933
# y index = 936
# y index = 939
# y index = 942
# y index = 945
# y index = 948
# y index = 951
# y index = 954
# y index = 957
# y index = 960
# y index = 963
# y index = 966
# y index = 969
# y index = 972
# y index = 975
# y index = 978
# y index = 981
#          1947085 function calls in 176.572 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.001    0.000 <ipython-input-15-041d1d0d4f02>:3(cum_sum)
#         1   63.728   63.728  176.572  176.572 <ipython-input-17-b45cf52b9fd4>:7(reconstruct)
#         1    0.000    0.000  176.572  176.572 <string>:1(<module>)
#         2    0.000    0.000    0.001    0.000 functional.py:2112(pad)
#    107584    0.482    0.000    4.509    0.000 functional.py:346(argmax)
#       984    0.019    0.000    0.027    0.000 iostream.py:195(schedule)
#       656    0.002    0.000    0.002    0.000 iostream.py:300(_is_master_process)
#       656    0.001    0.000    0.004    0.000 iostream.py:313(_schedule_flush)
#       656    0.005    0.000    0.036    0.000 iostream.py:366(write)
#       984    0.002    0.000    0.002    0.000 iostream.py:93(_event_pipe)
#         2    0.000    0.000    0.001    0.000 padding.py:12(forward)
#         2    0.000    0.000    0.000    0.000 padding.py:18(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:23(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:24(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tensor.py:324(__rdiv__)
#    107584    2.287    0.000    2.287    0.000 tensor.py:346(__floordiv__)
#       984    0.002    0.000    0.003    0.000 threading.py:1060(_wait_for_tstate_lock)
#       984    0.003    0.000    0.006    0.000 threading.py:1102(is_alive)
#       984    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#    107584    2.980    0.000    2.980    0.000 {built-in method _argmax}
#         2    0.000    0.000    0.001    0.000 {built-in method apply}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000  176.572  176.572 {built-in method builtins.exec}
#       656    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       328    0.004    0.000    0.040    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#    215168   14.053    0.000   14.053    0.000 {built-in method conv2d}
#         4    0.000    0.000    0.000    0.000 {built-in method cumsum}
#    107584    1.884    0.000    1.884    0.000 {built-in method exp}
#    107584   11.889    0.000   11.889    0.000 {built-in method flip}
#         1    0.000    0.000    0.000    0.000 {built-in method log}
#    107584   58.343    0.001   58.343    0.001 {built-in method max}
#       656    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#    215170    1.935    0.000    1.935    0.000 {built-in method squeeze}
#    215168    9.302    0.000    9.302    0.000 {built-in method sum}
#    215170    2.104    0.000    2.104    0.000 {built-in method unsqueeze}
#    107589    1.612    0.000    1.612    0.000 {built-in method zeros}
#       984    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.lock' objects}
#       984    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    107584    0.064    0.000    0.064    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#        12    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#    107589    4.884    0.000    4.884    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#    107584    0.983    0.000    0.983    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#
#
# CPU times: user 2min 26s, sys: 31.1 s, total: 2min 57s
# Wall time: 2min 56s

# %%
zcpu = z2.cpu().numpy()

# %%
zcpu[2]
# Out:
# array([[5.6266290e-01, 3.6496034e-01, 3.2357943e-01, ..., 3.7111086e-01,
#         3.2528037e-01, 3.5642204e-01],
#        [4.9423051e-01, 3.5515985e-01, 3.2683662e-01, ..., 3.7862059e-01,
#         3.3762014e-01, 3.5861814e-01],
#        [5.4583234e-01, 4.9684644e-01, 3.7305754e-01, ..., 3.6206889e-01,
#         2.7590576e-01, 3.1901205e-01],
#        ...,
#        [6.7989095e-05, 2.8569824e-01, 3.3331475e-01, ..., 4.6982032e-01,
#         5.5363774e-01, 3.8039201e-01],
#        [7.5131356e-05, 2.8569448e-01, 4.2102322e-01, ..., 4.2538005e-01,
#         4.8518157e-01, 2.7485648e-01],
#        [6.6735193e-02, 7.6997533e-02, 2.7778441e-01, ..., 4.9282637e-01,
#         4.8700866e-01, 2.3994902e-01]], dtype=float32)

# %%
np.savez_compressed('reconstruction2',a=zcpu)

# %%
zmax = np.argmax(np.reshape(zcpu,(6,-1)),axis=0)
zre = np.reshape(zmax,(zcpu.shape[1],-1))
zre.shape
# Out:
# (998, 998)

# %%
plt.figure()
plt.imshow(zre)
plt.axis('off')
plt.show()
plt.close()
plt.figure()
plt.imshow(lc[:300,:300])
plt.axis('off')
plt.show()
plt.close()

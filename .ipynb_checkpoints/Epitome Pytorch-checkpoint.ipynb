# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys,os,time
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import rasterio
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn.feature_extraction.image import extract_patches_2d
import cProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
p = pd.read_csv("big_lc_paths.csv", header=None)
paths = p[0].tolist()
palette = np.array([[0,0,0],[0,153,51],[0,102,255],[153,102,51],[255,153,0],[255,255,0],[204,102,153]])
palette_torch = torch.from_numpy(palette[1:,:]).float().to(device)

#efficiently calculate cumulative sums
def cum_sum(arr, s):
    cumsum = torch.cumsum(torch.cumsum(arr,dim=2),dim=3)
    cumsum = F.pad(cumsum,(1,0,1,0),'constant',0)
    return cumsum[:,:,:-s,:-s]-cumsum[:,:,s:,:-s]-cumsum[:,:,:-s,s:]+cumsum[:,:,s:,s:]

#create a 10 channel structure from tile t at (x,y) of size... size
def t_load(t,x,y,size):
    naip_tile = rasterio.open('/mnt/blobfuse/esri-naip/'+paths[t][:-7]+'.mrf','r')
    naip = naip_tile.read().astype(float)/255.
    naip_tile.close()
    lc_tile = rasterio.open('/mnt/blobfuse/resampled-lc/'+paths[t],'r')
    lc = np.squeeze(lc_tile.read())
    lc_tile.close()
    lc[lc==1]=10
    lc[lc==2]=1
    lc[lc==10]=2
    lc[lc==4]=0
    lc[lc==15]=4
    temp = naip[:,x:x+size,y:y+size]
    t = np.zeros((10,temp.shape[1],temp.shape[2]),dtype=float)
    t[:4,:,:] = temp
    query_lc = lc[x:x+size,y:y+size]
    for i in range(6):
        t[4+i,:,:] = (query_lc==(i+1))
    t = np.expand_dims(t,axis=0)
    return torch.from_numpy(t).float().to(device)

def t_load_full(t):
    return t_load(t,0,0,10000)

#display 10 channel structure
def disp_10(t):
    fig=plt.figure(figsize=(14,10))
    fig.add_subplot(121)
    plt.axis('off')
    plt.imshow(t[0,:3,:,:].permute(1,2,0))
    fig.add_subplot(122)
    plt.axis('off')
    plt.imshow(palette_torch[get_labels(t)].int())
    plt.show()
    plt.close()
    
def get_labels(t):
    return torch.argmax(t[0,4:,:,:],dim=0)

#learns N x N epitome from T, K x K random patches drawn from input image x.
#Applies NIT iterations of the E-M algorithm at scales sc; T*sc^2 patches are sampled.
#no longer accepts initializations of e or ev
#e,ev = initial epitome mean and variance. The mean is initialized
#to the uniform image with some small noise, and the variance is initialized to 1
#p holds an array of probabilities of using each part of the epitome

def epitome(x,K,N,T,NIT,sc):
    xFIN = x
    x = F.interpolate(x,scale_factor=sc[0])
    _, numDim, SY, SX = x.shape
    TFIN = T
    T = int(np.ceil(T*sc[0]**2))
    NFIN = N
    N = int(np.ceil(sc[0]*N))
    e = torch.zeros((1,numDim,N,N)).to(device)#mean of image plus noise
    ev = torch.ones((1,numDim,N,N)).to(device)/50
    for i in range(numDim):
        e[:,i,:,:] = x[0,i,:,:].std()*torch.randn(N,N).to(device)/100+x[0,i,:,:].mean()
    p = torch.ones((N,N)).to(device)/N**2
    MINP = 1e-8#1e-8 is acceptable
    MINV = 5e-2#1e-6
    #etr = torch.zeros((NIT+1,1,numDim,NFIN,NFIN))
    #etr[0,:,:,:,:] = F.interpolate(e,[NFIN,NFIN])
    #perform NIT iterations of EM algorithm
    for sci in range(len(sc)):
        if sci != 0:
            N = int(np.ceil(sc[sci]*NFIN))
            e = F.interpolate(e,[N,N]).to(device)
            ev = F.interpolate(ev,[N,N]).to(device)
            p = torch.ones((N,N)).to(device)/N**2
            x = F.interpolate(xFIN,scale_factor=sc[sci]).to(device)
            T = int(np.ceil(sc[sci]**2*TFIN))
        sumP = torch.zeros((N,N),dtype=torch.float).to(device)
        sumPy = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
        sumPy2 = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
        ewrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
        evwrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
        SY = x.shape[2]
        SX = x.shape[3]
        patchnum = min(T,(SY-K)**2)
        ytemp = np.rollaxis(extract_patches_2d(torch.squeeze(x).permute(1,2,0),(K,K),max_patches=patchnum),3,1)
        y = torch.from_numpy(ytemp).float().to(device)
        for nit in range(NIT):
            ewrap[:,:N,:N] = e;
            ewrap[:,N:,:] = ewrap[:,:K-1,:]
            ewrap[:,:,N:] = ewrap[:,:,:K-1]
            evwrap[:,:N,:N] = ev
            evwrap[:,N:,:] = evwrap[:,:K-1,:]
            evwrap[:,:,N:] = evwrap[:,:,:K-1]
            # E STEP
            sumP[:,:] = 0
            sumPy[:,:,:] = 0
            sumPy2[:,:,:] = 0
            yt = torch.flip(y,[2,3])
            tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2/evwrap,0),K)),dim=0)
            tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(torch.log(evwrap),0),K)),dim=0)
            idxp = 0
            #batch size is independent of input size
            batch_size = 8000
            while idxp*batch_size<patchnum:
                ytc = yt[idxp*batch_size:idxp*batch_size+batch_size,:,:,:]
                tmp1full = torch.squeeze(F.conv2d(torch.unsqueeze(1/evwrap,0),ytc**2))
                tmp2full = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap/evwrap,0),ytc))
                for tx in range(tmp1full.shape[0]):
                    lP = torch.log(p)-.5*(tmp4+tmp1full[tx,:,:]-2*tmp2full[tx,:,:]+tmp3)
                    P = torch.exp(lP-torch.max(lP))+MINP
                    P /= torch.sum(P)
                    tmp = F.pad(P.view(1,1,N,N),(K-1,K-1,K-1,K-1),'constant',0).to(device)
                    tmp_sumP = torch.squeeze(cum_sum(tmp,K))
                    tmp_sumP[:,:K-1] += tmp_sumP[:,N:]
                    tmp_sumP[:K-1,:] += tmp_sumP[N:,:]
                    sumP += tmp_sumP[:N,:N]
                    yctmp = torch.unsqueeze(y[batch_size*idxp+tx,:,:,:],1)
                    tmp_sumPy = torch.squeeze(F.conv2d(tmp,yctmp))
                    tmp_sumPy[:,:,:K-1] += tmp_sumPy[:,:,N:]
                    tmp_sumPy[:,:K-1,:] += tmp_sumPy[:,N:,:]
                    sumPy += tmp_sumPy[:,:N,:N]
                    tmp_sumPy2 = torch.squeeze(F.conv2d(tmp,yctmp**2))
                    tmp_sumPy2[:,:,:K-1] += tmp_sumPy2[:,:,N:]
                    tmp_sumPy2[:,:K-1,:] += tmp_sumPy2[:,N:,:]
                    sumPy2 += tmp_sumPy2[:,:N,:N]
                torch.cuda.empty_cache()
                idxp += 1
            #M STEP
            #p = sumP/torch.sum(sumP)#commented out
            e[0,:,:,:] = sumPy/sumP
            if nit>10 or sci>0:
                ev[0,:,:,:] = sumPy2/sumP - 2*e[0,:,:,:]*sumPy/sumP+e[0,:,:,:]**2
            ev = torch.clamp(ev,min=MINV)
            etemp = F.interpolate(e,[NFIN,NFIN])
            #etr[nit+1,:,:,:] = etemp
            fig=plt.figure(figsize=(20,7))
            fig.add_subplot(131)
            plt.axis('off')
            #print(torch.max(etemp[0,:3,:,:]))
            plt.imshow(etemp[0,:3,:,:].permute(1,2,0))
            plt.title('%i^2 epitome, iteration %i' % (N,nit+1))
            e_colors = e[0,4:,:,:].permute(1,2,0).view(-1,6)
            fig.add_subplot(132)
            plt.axis('off')
            #print(torch.max(torch.matmul(e_colors,palette_torch).view(N,N,3)/256))
            plt.imshow(torch.matmul(e_colors,palette_torch).view(N,N,3)/256)
            plt.title('labeled epitome')
            fig.add_subplot(133)
            plt.axis('off')
            #print(torch.max(torch.sum(torch.squeeze(ev),dim=0)))
            plt.imshow(torch.sum(torch.squeeze(ev),dim=0),cmap='hot',interpolation='nearest')
            plt.title('variances')
            plt.show()
            plt.close()   
    return e,ev,p#,etr

#here, e,ev, and emod should be lists of e and ev for multiple epitomes

def reconstructplural(x,K,e,ev,emod,SPC):
    _,NoCh1,SY,SX = x.shape
    NoCh2 = emod[0].shape[0]
    N = e[0].shape[2]
    nume = len(e)
    elist = torch.zeros((nume,NoCh1,N+K-1,N+K-1)).to(device)
    evlist = torch.zeros((nume,NoCh1,N+K-1,N+K-1)).to(device)
    emodlist = torch.zeros((nume,NoCh2,N+K-1,N+K-1)).to(device)
    tmp3list = torch.zeros((nume,N,N)).to(device)
    tmp4list = torch.zeros((nume,N,N)).to(device)
    for i in range(nume):
        elist[i,:,:N,:N] = e[i]
        elist[i,:,N:,:] = elist[i,:,:K-1,:]
        elist[i,:,:,N:] = elist[i,:,:,:K-1]
        evlist[i,:,:N,:N] = ev[i]
        evlist[i,:,N:,:] = evlist[i,:,:K-1,:]
        evlist[i,:,:,N:] = evlist[i,:,:,:K-1]
        #print(torch.unsqueeze(elist[i]**2/evlist[i],0).shape)
        tmp3list[i] = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(elist[i]**2/evlist[i],0),K)),dim=0)
        tmp4list[i] = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(torch.log(evlist[i]),0),K)),dim=0)
        emodlist[i,:,:N,:N] = emod[i]
        emodlist[i,:,N:,:] = emodlist[i,:,:K-1,:]
        emodlist[i,:,:,N:] = emodlist[i,:,:,:K-1]
    z = torch.zeros((NoCh2,SY,SX)).to(device)
    cnt = torch.zeros((SY,SX)).to(device)
    ixt = 0
    iyt = 0
    lplist = torch.zeros((nume,N,N)).to(device)
    for iy in range(0,SY-K+1,SPC):
        print(str(iy)+' ',end='')
        if ((iy//SPC)%25==24):
            print('')
        for ix in range(0,SX-K+1,SPC):
            yct = x[:,:,iy:iy+K,ix:ix+K]
            for i in range(nume):
                tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(1/evlist[i],0),yct**2))
                tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(elist[i]/evlist[i],0),yct))
                lP = -.5*(tmp4list[i]+tmp1-2*tmp2+tmp3list[i])
                lplist[i] = lP
            argmax = torch.argmax(lplist)
            #print(argmax)
            ef = argmax//N**2
            mxpi = (argmax%N**2)//lplist.shape[1]
            mxpj = argmax%N**2 - mxpi*lplist.shape[1]
            #print(ef,mxpi,mxpj)
            z[:,iy:iy+K,ix:ix+K] += emodlist[ef,:,mxpi:mxpi+K,mxpj:mxpj+K]
            cnt[iy:iy+K,ix:ix+K] += 1
            ixt = ix
        iyt = iy
    #z = z[:,:iyt+K,:ixt+K]
    #cnt = cnt[:iyt+K,:ixt+K]
    z /= cnt
    print('')
    return z

#Replaces the epitome (e,ev) of an image by another epitome image emod
#keeping the mapping intact. The routine can be used to edit images or to
#preprocess by coloring the image accoring to the image.
#K is the patch size in mapping inference and SPC is the patch spacing.

def reconstruct(x,K,e,ev,emod,SPC):
    _,NoCh1,SY,SX = x.shape
    NoCh2 = emod.shape[0]
    #if NoCh1 == 1:
        #x = torch.stack((x,x,x),dim=0)
    N = e.shape[2]
    ewrap = torch.zeros((1,NoCh1,N+K-1,N+K-1)).to(device)
    evwrap = torch.zeros((1,NoCh1,N+K-1,N+K-1)).to(device)
    ewrap[0,:,:N,:N] = e
    ewrap[:,:,N:,:] = ewrap[:,:,:K-1,:]
    ewrap[:,:,:,N:] = ewrap[:,:,:,:K-1]
    evwrap[0,:,:N,:N] = ev
    evwrap[:,:,N:,:] = evwrap[:,:,:K-1,:]
    evwrap[:,:,:,N:] = evwrap[:,:,:,:K-1]
    tmp3 = torch.sum(torch.squeeze(cum_sum(ewrap**2/evwrap,K)),dim=0)
    tmp4 = torch.sum(torch.squeeze(cum_sum(torch.log(evwrap),K)),dim=0)
    emodwrap = torch.zeros((NoCh2,N+K-1,N+K-1)).to(device)
    emodwrap[:,:N,:N] = emod
    emodwrap[:,N:,:] = emodwrap[:,:K-1,:]
    emodwrap[:,:,N:] = emodwrap[:,:,:K-1]
    z = torch.zeros((NoCh2,SY,SX)).to(device)
    cnt = torch.zeros((SY,SX)).to(device)
    ixt = 0
    iyt = 0
    #MINP = 1e-8
    #for each patch of the input, find the distribution over the epitome positions,
    #and reconstruct the patch in the input image, using the modified epitome.
    #xflip = torch.flip(x,[2,3])
    for iy in range(0,SY-K+1,SPC):
        print(str(iy)+' ',end='')
        if ((iy//SPC)%25==24):
            print('')
        for ix in range(0,SX-K+1,SPC):
            #watch for indexing errors
            #flip necessary?
            yct = x[:,:,iy:iy+K,ix:ix+K]
            #yct = xflip[:,:,SY-iy-K:SY-iy,SX-ix-K:SX-ix]
            tmp1 = torch.squeeze(F.conv2d(1/evwrap,yct**2))
            tmp2 = torch.squeeze(F.conv2d(ewrap/evwrap,yct))
            lP = -.5*(tmp4+tmp1-2*tmp2+tmp3)#N x N
            #P = torch.exp(lP-torch.max(lP))#+MINP
            #P /= torch.sum(P)
            argmax = torch.argmax(lP)#argmax = torch.argmax(P)
            mxpi = argmax//lP.shape[0]
            mxpj = argmax - mxpi*lP.shape[0]
            #watch for indexing errors
            z[:,iy:iy+K,ix:ix+K] += emodwrap[:,mxpi:mxpi+K,mxpj:mxpj+K]
            cnt[iy:iy+K,ix:ix+K] += 1
            ixt = ix
        iyt = iy
    #z = z[:,:iyt+K,:ixt+K]
    #cnt = cnt[:iyt+K,:ixt+K]
    z /= cnt
    print('')
    return z

# %%
tr = t_load(1,0,0,256)
disp_10(tr)
ts = t_load(2,0,0,256)
disp_10(ts)
#tfull = t_load_full(1)
#disp_10(tfull)

# %%
#cProfile.run('e,ev,p,etr=epitome(trIMtorch,9,256,40000,10,[.125,.25,.5,1])',sort='cumtime')
cProfile.run('e,ev,p=epitome(tr,8,128,50000,10,[.125,.25,.5,1])',sort='cumtime')
torch.cuda.empty_cache()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides
#          51373333 function calls (51232973 primitive calls) in 876.202 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  876.202  876.202 {built-in method builtins.exec}
#         1    0.000    0.000  876.202  876.202 <string>:1(<module>)
#         1  398.257  398.257  876.201  876.201 <ipython-input-52-667aad2cef09>:60(epitome)
#    664150   68.543    0.000  149.571    0.000 <ipython-input-52-667aad2cef09>:8(cum_sum)
#   1328220    4.678    0.000  131.200    0.000 functional.py:2112(pad)
#   1328220   12.404    0.000  125.709    0.000 {built-in method apply}
#   1328220   29.679    0.000  113.305    0.000 padding.py:12(forward)
#   1328360   83.936    0.000   83.936    0.000 {built-in method conv2d}
#    664070   58.846    0.000   58.846    0.000 {built-in method max}
#    664190   43.473    0.000   43.473    0.000 {built-in method sum}
#   1328300   22.069    0.000   22.069    0.000 {built-in method cumsum}
#   1328220   21.075    0.000   21.075    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#   3984580   20.846    0.000   20.846    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#   1328220   17.711    0.000   17.711    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#   1992554   14.877    0.000   14.877    0.000 {built-in method squeeze}
#   1328220   14.856    0.000   14.856    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#        40    0.000    0.000   11.982    0.300 pyplot.py:236(show)
#        40    0.001    0.000   11.982    0.300 backend_inline.py:18(show)
#        40    0.001    0.000   11.935    0.298 display.py:129(display)
#        40    0.001    0.000   11.875    0.297 formatters.py:89(format)
#       480    0.001    0.000   11.873    0.025 formatters.py:220(catch_format_error)
#       360    0.000    0.000   11.863    0.033 <decorator-gen-9>:1(__call__)
#       360    0.001    0.000   11.862    0.033 formatters.py:331(__call__)
#        40    0.000    0.000   11.853    0.296 pylabtools.py:238(<lambda>)
#        40    0.001    0.000   11.853    0.296 pylabtools.py:91(print_figure)
#        40    0.011    0.000   11.851    0.296 backend_bases.py:2107(print_figure)
#    664110   11.604    0.000   11.604    0.000 {built-in method log}
#    664070   10.464    0.000   10.464    0.000 {built-in method exp}
#        80    0.002    0.000    7.885    0.099 backend_agg.py:512(print_png)
#        80    6.441    0.081    6.441    0.081 {built-in method matplotlib._png.write_png}
#    664150    5.859    0.000    5.859    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#    664370    4.211    0.000    4.211    0.000 {built-in method unsqueeze}
#   9297468    3.789    0.000    3.789    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        40    0.001    0.000    3.656    0.091 figure.py:2179(get_tightbbox)
#       120    0.005    0.000    3.648    0.030 _base.py:4137(get_tightbbox)
#       240    0.006    0.000    3.563    0.015 axis.py:1137(get_tightbbox)
#    664119    3.260    0.000    3.260    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#       110    0.976    0.009    3.176    0.029 tensor.py:324(__rdiv__)
#      2920    0.058    0.000    2.890    0.001 axis.py:74(__init__)
#   1328220    1.924    0.000    2.750    0.000 padding.py:23(<listcomp>)
#       480    0.022    0.000    2.698    0.006 axis.py:1020(_update_ticks)
#      4880    0.009    0.000    2.466    0.001 axis.py:967(iter_ticks)
#       110    0.001    0.000    2.309    0.021 __init__.py:354(empty_cache)
#       110    2.308    0.021    2.308    0.021 {built-in method torch._C._cuda_emptyCache}
#       110    2.200    0.020    2.200    0.020 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#       120    0.002    0.000    1.824    0.015 figure.py:1145(add_subplot)
#       120    0.002    0.000    1.815    0.015 _subplots.py:25(__init__)
#       480    0.007    0.000    1.806    0.004 axis.py:1393(get_major_ticks)
#       120    0.006    0.000    1.785    0.015 _base.py:423(__init__)
#      8760    0.171    0.000    1.648    0.000 lines.py:290(__init__)
#      1460    0.006    0.000    1.600    0.001 axis.py:1787(_get_tick)
#        80    0.001    0.000    1.440    0.018 backend_agg.py:421(draw)
#       120    0.007    0.000    1.418    0.012 _base.py:998(cla)
#   1328220    1.373    0.000    1.373    0.000 padding.py:18(<listcomp>)
#   1360/80    0.005    0.000    1.358    0.017 artist.py:47(draw_wrapper)
#        80    0.001    0.000    1.357    0.017 figure.py:1438(draw)
#    320/80    0.003    0.000    1.331    0.017 image.py:123(_draw_list_compositing_images)
#       240    0.004    0.000    1.329    0.006 _base.py:2528(draw)
#      1460    0.006    0.000    1.302    0.001 axis.py:2159(_get_tick)
#   720/480    0.002    0.000    0.966    0.002 axis.py:670(__get__)
#       240    0.004    0.000    0.957    0.004 image.py:569(draw)
#       240    0.002    0.000    0.878    0.004 image.py:832(make_image)
#       240    0.038    0.000    0.870    0.004 image.py:275(_make_image)
#   2656440    0.825    0.000    0.825    0.000 {built-in method builtins.sum}
#       240    0.001    0.000    0.729    0.003 axis.py:927(set_clip_path)
#      4640    0.038    0.000    0.714    0.000 text.py:887(get_window_extent)
#   5398079    0.645    0.000    0.645    0.000 {built-in method builtins.len}
#       480    0.008    0.000    0.625    0.001 axis.py:1119(_get_tick_bboxes)
#      1460    0.010    0.000    0.565    0.000 axis.py:479(_get_tick2line)
#      3920    0.080    0.000    0.545    0.000 text.py:276(_get_layout)
#       480    0.002    0.000    0.537    0.001 ticker.py:1943(__call__)
#       480    0.002    0.000    0.534    0.001 ticker.py:1947(tick_values)
#   1331220    0.519    0.000    0.523    0.000 {built-in method builtins.all}
#       480    0.027    0.000    0.523    0.001 ticker.py:1896(_raw_ticks)
#   1328220    0.520    0.000    0.520    0.000 padding.py:24(<listcomp>)
#       120    0.002    0.000    0.507    0.004 axis.py:2265(_update_label_position)
#       120    0.002    0.000    0.499    0.004 axis.py:1896(_update_label_position)
#       960    0.005    0.000    0.478    0.000 axis.py:844(set_tick_params)
#       240    0.001    0.000    0.468    0.002 _base.py:2678(grid)
#       480    0.002    0.000    0.466    0.001 axis.py:1423(grid)
#       120    0.001    0.000    0.460    0.004 axis.py:2246(_get_tick_boxes_siblings)
#     15800    0.354    0.000    0.453    0.000 artist.py:854(update)
#       120    0.001    0.000    0.451    0.004 axis.py:1877(_get_tick_boxes_siblings)
#       320    0.427    0.001    0.444    0.001 {built-in method matplotlib._image.resample}
#     13920    0.017    0.000    0.435    0.000 markers.py:167(__init__)
#     13920    0.044    0.000    0.396    0.000 markers.py:251(set_marker)
#    145696    0.344    0.000    0.384    0.000 {built-in method numpy.core.multiarray.array}
#   1328320    0.371    0.000    0.371    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#     52080    0.100    0.000    0.359    0.000 fromnumeric.py:64(_wrapreduction)
#      1460    0.011    0.000    0.356    0.000 axis.py:618(_get_gridline)
#      1460    0.011    0.000    0.350    0.000 axis.py:494(_get_gridline)
#     65284    0.332    0.000    0.332    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       720    0.011    0.000    0.330    0.000 text.py:691(draw)
#      1720    0.008    0.000    0.305    0.000 axis.py:1357(_copy_tick_props)
# 365320/302560    0.191    0.000    0.296    0.000 artist.py:230(stale)
#     27840    0.036    0.000    0.293    0.000 markers.py:200(_recache)
#      1460    0.010    0.000    0.287    0.000 axis.py:468(_get_tick1line)
#     10120    0.062    0.000    0.281    0.000 font_manager.py:665(__init__)
#      1460    0.010    0.000    0.279    0.000 axis.py:589(_get_tick1line)
#      2200    0.012    0.000    0.267    0.000 backend_agg.py:220(get_text_width_height_descent)
#      2920    0.006    0.000    0.265    0.000 lines.py:945(get_path)
#      1460    0.010    0.000    0.263    0.000 axis.py:604(_get_tick2line)
#      2920    0.056    0.000    0.259    0.000 lines.py:649(recache)
#      1920    0.004    0.000    0.249    0.000 axis.py:770(_set_scale)
#      2440    0.243    0.000    0.243    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#      1920    0.010    0.000    0.240    0.000 scale.py:68(set_default_locators_and_formatters)
#     19800    0.024    0.000    0.232    0.000 fromnumeric.py:1933(any)
#       240    0.005    0.000    0.232    0.001 axis.py:2121(get_tick_space)
#      7160    0.019    0.000    0.230    0.000 transforms.py:1429(transform)
#       240    0.004    0.000    0.227    0.001 axis.py:2500(get_tick_space)
#      1800    0.013    0.000    0.224    0.000 artist.py:650(set_clip_path)
#      6320    0.016    0.000    0.221    0.000 transforms.py:1522(transform_point)
#      1440    0.008    0.000    0.215    0.000 axis.py:801(cla)
#      5160    0.024    0.000    0.213    0.000 lines.py:1233(update_from)
#       120    0.001    0.000    0.212    0.002 _base.py:615(_init_axis)
#       840    0.006    0.000    0.197    0.000 transforms.py:740(union)
#     55544    0.042    0.000    0.194    0.000 numeric.py:433(asarray)
#      2720    0.007    0.000    0.192    0.000 patches.py:194(get_transform)
#      6680    0.037    0.000    0.188    0.000 text.py:129(__init__)
#       240    0.035    0.000    0.186    0.001 cm.py:208(to_rgba)
#    336200    0.184    0.000    0.184    0.000 __init__.py:931(__getitem__)
#     19520    0.118    0.000    0.183    0.000 artist.py:87(__init__)
#      1920    0.004    0.000    0.179    0.000 ticker.py:2484(__init__)
#       720    0.001    0.000    0.177    0.000 axis.py:231(set_clip_path)
#    255153    0.079    0.000    0.175    0.000 {built-in method builtins.isinstance}
#      7160    0.011    0.000    0.175    0.000 transforms.py:2481(transform_affine)
#      1920    0.006    0.000    0.174    0.000 ticker.py:1794(__init__)
#      3840    0.014    0.000    0.168    0.000 ticker.py:1870(set_params)
#     10480    0.029    0.000    0.167    0.000 transforms.py:2076(scale)
#      1460    0.010    0.000    0.165    0.000 axis.py:559(_get_text1)
#      2000    0.002    0.000    0.164    0.000 patches.py:736(get_patch_transform)
#      1460    0.010    0.000    0.162    0.000 axis.py:435(_get_text1)
#      2000    0.012    0.000    0.162    0.000 patches.py:707(_update_patch_transform)
#      8760    0.015    0.000    0.160    0.000 lines.py:1165(set_markerfacecolor)
# 12720/7560    0.041    0.000    0.158    0.000 transforms.py:2505(get_affine)
#     19500    0.021    0.000    0.155    0.000 transforms.py:131(invalidate)
#      1460    0.008    0.000    0.141    0.000 axis.py:574(_get_text2)
#      1460    0.008    0.000    0.139    0.000 axis.py:452(_get_text2)
#     14460    0.047    0.000    0.139    0.000 transforms.py:771(__init__)
# 52500/19500    0.084    0.000    0.134    0.000 transforms.py:142(_invalidate_internal)
#       240    0.002    0.000    0.132    0.001 axis.py:705(__init__)
#       240    0.004    0.000    0.128    0.001 backend_agg.py:190(draw_text)
#       120    0.001    0.000    0.125    0.001 pyplot.py:3184(imshow)
#       120    0.001    0.000    0.122    0.001 __init__.py:1774(inner)
#       120    0.002    0.000    0.119    0.001 _axes.py:5348(imshow)
#     66600    0.052    0.000    0.117    0.000 artist.py:288(pchanged)
#         4    0.073    0.018    0.108    0.027 image.py:299(extract_patches_2d)
#     30300    0.038    0.000    0.107    0.000 transforms.py:1919(__init__)
#      6900    0.010    0.000    0.107    0.000 transforms.py:350(xmin)
#       120    0.001    0.000    0.106    0.001 _base.py:978(_gen_axes_spines)
#       480    0.003    0.000    0.105    0.000 spines.py:485(linear_spine)
#       600    0.012    0.000    0.105    0.000 transforms.py:753(intersection)
#        80    0.020    0.000    0.097    0.001 colors.py:457(__call__)
#     44176    0.058    0.000    0.097    0.000 abc.py:178(__instancecheck__)
#     40640    0.037    0.000    0.096    0.000 artist.py:66(_stale_axes_callback)
#      3760    0.011    0.000    0.093    0.000 path.py:101(__init__)
#     12480    0.010    0.000    0.092    0.000 transforms.py:1285(__add__)
#       600    0.002    0.000    0.091    0.000 patches.py:570(get_window_extent)
#     15480    0.014    0.000    0.089    0.000 fromnumeric.py:2337(amin)
#     58660    0.044    0.000    0.089    0.000 transforms.py:1774(__init__)
#      8760    0.012    0.000    0.088    0.000 lines.py:1177(set_markerfacecoloralt)
#     13680    0.021    0.000    0.086    0.000 transforms.py:2584(composite_transform_factory)
#       480    0.005    0.000    0.086    0.000 spines.py:42(__init__)
#      2440    0.006    0.000    0.085    0.000 backend_agg.py:271(_get_agg_font)
#      3440    0.010    0.000    0.083    0.000 text.py:263(update_from)
#      3840    0.022    0.000    0.083    0.000 ticker.py:1862(_staircase)
#       160    0.001    0.000    0.082    0.001 backend_agg.py:442(get_renderer)
#       640    0.007    0.000    0.082    0.000 patches.py:49(__init__)
#     32220    0.082    0.000    0.082    0.000 {built-in method numpy.core.multiarray.dot}
# 5880/5520    0.015    0.000    0.081    0.000 transforms.py:1072(get_points)
#      2000    0.005    0.000    0.080    0.000 transforms.py:2050(rotate_deg_around)
#       840    0.005    0.000    0.079    0.000 path.py:521(get_extents)
#        80    0.072    0.001    0.078    0.001 backend_agg.py:91(__init__)
#     15600    0.013    0.000    0.077    0.000 fromnumeric.py:2227(amax)
#     15800    0.013    0.000    0.076    0.000 artist.py:887(<listcomp>)
#      3680    0.039    0.000    0.076    0.000 transforms.py:711(translated)
#     16560    0.022    0.000    0.075    0.000 font_manager.py:989(_normalize_font_family)
#       480    0.003    0.000    0.073    0.000 axis.py:1827(_get_pixel_distance_along_axis)
#      3100    0.017    0.000    0.073    0.000 transforms.py:2030(rotate_deg)
#       480    0.006    0.000    0.071    0.000 ticker.py:655(set_locs)
#     19480    0.023    0.000    0.071    0.000 artist.py:612(set_figure)
#       480    0.001    0.000    0.071    0.000 spines.py:164(register_axis)
#      8600    0.045    0.000    0.070    0.000 artist.py:963(update_from)
#       240    0.047    0.000    0.069    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     72080    0.045    0.000    0.069    0.000 six.py:586(iteritems)
#      4500    0.011    0.000    0.069    0.000 transforms.py:833(from_extents)
#      8760    0.026    0.000    0.068    0.000 lines.py:1052(set_linestyle)
#      3760    0.027    0.000    0.067    0.000 path.py:198(_update_values)
#       480    0.000    0.000    0.067    0.000 spines.py:176(cla)
#     90960    0.067    0.000    0.067    0.000 transforms.py:88(__init__)
#      2440    0.003    0.000    0.066    0.000 font_manager.py:1473(findfont)
#      3920    0.012    0.000    0.065    0.000 text.py:854(get_prop_tup)
#      9240    0.018    0.000    0.064    0.000 artist.py:858(_update_property)
#      2320    0.007    0.000    0.063    0.000 markers.py:702(_set_tickleft)
#      2440    0.006    0.000    0.063    0.000 font_manager.py:1255(findfont)
#     17040    0.017    0.000    0.062    0.000 artist.py:303(set_transform)
#      1920    0.017    0.000    0.062    0.000 ticker.py:1843(_validate_steps)
#      2320    0.007    0.000    0.062    0.000 markers.py:722(_set_tickdown)
#     13680    0.028    0.000    0.062    0.000 transforms.py:2403(__init__)
#      3840    0.005    0.000    0.060    0.000 shape_base.py:236(hstack)
#     14600    0.010    0.000    0.059    0.000 axis.py:331(_set_artist_props)
#        40    0.001    0.000    0.059    0.001 display.py:79(publish_display_data)
#        40    0.001    0.000    0.058    0.001 zmqshell.py:94(publish)
#      2440    0.004    0.000    0.057    0.000 font_manager.py:1019(get)
#     12600    0.011    0.000    0.057    0.000 __init__.py:584(is_numlike)
#    104204    0.051    0.000    0.057    0.000 {built-in method builtins.getattr}
#     32440    0.056    0.000    0.056    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      3100    0.025    0.000    0.056    0.000 transforms.py:2014(rotate)
#      5360    0.011    0.000    0.054    0.000 colors.py:142(to_rgba)
#      2320    0.006    0.000    0.052    0.000 markers.py:716(_set_tickup)
#      6920    0.019    0.000    0.052    0.000 text.py:178(update)
#      3680    0.052    0.000    0.052    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      2320    0.006    0.000    0.052    0.000 markers.py:708(_set_tickright)
#     11240    0.032    0.000    0.050    0.000 font_manager.py:711(__hash__)
#     27640    0.044    0.000    0.049    0.000 transforms.py:169(set_children)
# 18960/14160    0.010    0.000    0.049    0.000 transforms.py:2434(_invalidate_internal)
#      8560    0.015    0.000    0.049    0.000 text.py:840(get_unitless_position)
#      3680    0.005    0.000    0.049    0.000 font_manager.py:924(copy)
#       360    0.006    0.000    0.048    0.000 _base.py:1511(apply_aspect)
# 12160/11680    0.027    0.000    0.047    0.000 spines.py:436(get_spine_transform)
#    365560    0.047    0.000    0.047    0.000 artist.py:715(get_animated)
# 27640/18840    0.012    0.000    0.047    0.000 {built-in method builtins.hash}
#       960    0.002    0.000    0.047    0.000 text.py:225(_get_xy_display)
#        80    0.000    0.000    0.047    0.001 pyplot.py:638(close)
#        40    0.001    0.000    0.046    0.001 _pylab_helpers.py:71(destroy_all)
#  1920/960    0.004    0.000    0.046    0.000 transforms.py:2513(inverted)
#     10440    0.006    0.000    0.046    0.000 transforms.py:1795(transform)
#      4720    0.009    0.000    0.046    0.000 transforms.py:2062(translate)
#      1960    0.003    0.000    0.045    0.000 patches.py:301(_set_facecolor)
#       840    0.003    0.000    0.045    0.000 transforms.py:747(<listcomp>)
#      3840    0.005    0.000    0.045    0.000 shape_base.py:283(<listcomp>)
#        80    0.045    0.001    0.045    0.001 {method 'take' of 'numpy.ndarray' objects}
#      9840    0.009    0.000    0.044    0.000 __init__.py:2042(_to_unmasked_float_array)
#        40    0.044    0.001    0.044    0.001 {built-in method gc.collect}
#      3680    0.006    0.000    0.043    0.000 transforms.py:2362(get_matrix)
#      8760    0.010    0.000    0.043    0.000 lines.py:715(set_transform)
#      2260    0.004    0.000    0.042    0.000 transforms.py:823(from_bounds)
#      2920    0.012    0.000    0.042    0.000 stride_tricks.py:198(broadcast_arrays)
#      6900    0.009    0.000    0.042    0.000 transforms.py:364(xmax)
#       480    0.006    0.000    0.041    0.000 axis.py:974(<listcomp>)
#      1460    0.002    0.000    0.041    0.000 axis.py:538(_get_text1_transform)
#     43020    0.027    0.000    0.041    0.000 six.py:583(itervalues)
#       480    0.002    0.000    0.041    0.000 axis.py:2202(_get_pixel_distance_along_axis)
#     10680    0.016    0.000    0.041    0.000 transforms.py:1875(transform_affine)
#     17520    0.026    0.000    0.041    0.000 lines.py:1020(_split_drawstyle_linestyle)
#      8760    0.013    0.000    0.040    0.000 lines.py:632(set_data)
#     11520    0.015    0.000    0.040    0.000 shape_base.py:11(atleast_1d)
#       480    0.013    0.000    0.040    0.000 ticker.py:736(_set_format)
#      3360    0.003    0.000    0.040    0.000 {method 'min' of 'numpy.ndarray' objects}
#      7020    0.008    0.000    0.040    0.000 transforms.py:371(ymax)
#      1460    0.002    0.000    0.039    0.000 axis.py:415(_get_text1_transform)
#     63304    0.039    0.000    0.039    0.000 _weakrefset.py:70(__contains__)
#      1460    0.008    0.000    0.039    0.000 _base.py:791(get_yaxis_text1_transform)
#     17000    0.007    0.000    0.039    0.000 {method 'get' of 'dict' objects}
#       120    0.003    0.000    0.039    0.000 image.py:629(set_data)
#      3160    0.018    0.000    0.038    0.000 shape_base.py:555(column_stack)
#      6900    0.008    0.000    0.038    0.000 transforms.py:357(ymin)
#       124    0.000    0.000    0.037    0.000 tensor.py:395(__array__)
#      3360    0.002    0.000    0.037    0.000 _methods.py:30(_amin)
#      1460    0.008    0.000    0.037    0.000 _base.py:711(get_xaxis_text1_transform)
#      3780    0.037    0.000    0.037    0.000 {built-in method numpy.core.multiarray.zeros}
#      6080    0.013    0.000    0.036    0.000 transforms.py:2768(__init__)
#       124    0.036    0.000    0.036    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#      3940    0.005    0.000    0.036    0.000 fromnumeric.py:49(_wrapfunc)
#       840    0.003    0.000    0.036    0.000 transforms.py:748(<listcomp>)
#      4400    0.005    0.000    0.036    0.000 ticker.py:566(__call__)
#      6560    0.033    0.000    0.035    0.000 font_manager.py:839(set_weight)
#        80    0.001    0.000    0.035    0.000 figure.py:470(_set_dpi)
#     16200    0.009    0.000    0.035    0.000 artist.py:184(convert_xunits)
#      1460    0.002    0.000    0.034    0.000 axis.py:541(_get_text2_transform)
#     24408    0.014    0.000    0.034    0.000 numeric.py:504(asanyarray)
#      3800    0.004    0.000    0.034    0.000 {method 'all' of 'numpy.ndarray' objects}
#      1460    0.002    0.000    0.034    0.000 axis.py:418(_get_text2_transform)
#      2880    0.002    0.000    0.034    0.000 transforms.py:1902(inverted)
#       540    0.005    0.000    0.033    0.000 core.py:2772(__new__)
#       840    0.002    0.000    0.033    0.000 transforms.py:749(<listcomp>)
#         4    0.000    0.000    0.033    0.008 validation.py:310(check_array)
#       840    0.002    0.000    0.033    0.000 transforms.py:750(<listcomp>)
#      3660    0.008    0.000    0.033    0.000 axis.py:633(update_position)
# 13380/7300    0.010    0.000    0.033    0.000 _base.py:686(get_xaxis_transform)
#      1460    0.006    0.000    0.032    0.000 _base.py:818(get_yaxis_text2_transform)
# 13380/7300    0.010    0.000    0.032    0.000 _base.py:766(get_yaxis_transform)
#      1460    0.005    0.000    0.032    0.000 _base.py:739(get_xaxis_text2_transform)
#       120    0.001    0.000    0.032    0.000 image.py:850(set_extent)
#      3660    0.008    0.000    0.031    0.000 axis.py:510(update_position)
#       120    0.001    0.000    0.031    0.000 axis.py:1939(_update_offset_text_position)
#      6440    0.007    0.000    0.031    0.000 font_manager.py:804(set_family)
#      3800    0.002    0.000    0.030    0.000 _methods.py:45(_all)
#        40    0.001    0.000    0.030    0.001 tight_bbox.py:13(adjust_bbox)
#      6560    0.023    0.000    0.030    0.000 font_manager.py:875(set_size)
#       360    0.026    0.000    0.030    0.000 linalg.py:468(inv)
#        80    0.007    0.000    0.030    0.000 colors.py:927(__call__)
#  1200/600    0.003    0.000    0.029    0.000 transforms.py:2426(frozen)
#      1320    0.001    0.000    0.029    0.000 patches.py:308(set_facecolor)
#       480    0.001    0.000    0.029    0.000 transforms.py:2241(frozen)
#        80    0.000    0.000    0.029    0.000 transforms.py:2005(clear)
#    141380    0.028    0.000    0.028    0.000 {built-in method builtins.iter}
#      1920    0.004    0.000    0.028    0.000 transforms.py:807(unit)
#        40    0.001    0.000    0.028    0.001 session.py:657(send)
#      8200    0.028    0.000    0.028    0.000 {built-in method numpy.core.multiarray.concatenate}
#       240    0.028    0.000    0.028    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#       380    0.001    0.000    0.028    0.000 core.py:6350(array)
#       240    0.003    0.000    0.028    0.000 _base.py:3043(set_xlim)
#        40    0.001    0.000    0.027    0.001 pyplot.py:431(figure)
#     17280    0.015    0.000    0.027    0.000 text.py:1159(set_text)
#       840    0.007    0.000    0.027    0.000 {built-in method matplotlib._path.get_path_extents}
#      1640    0.007    0.000    0.027    0.000 transforms.py:436(bounds)
#      1300    0.007    0.000    0.026    0.000 core.py:2928(__array_finalize__)
#        40    0.000    0.000    0.026    0.001 session.py:598(serialize)
#       120    0.001    0.000    0.026    0.000 _subplots.py:131(update_params)
#      1080    0.002    0.000    0.025    0.000 transforms.py:1882(transform_point)
#       120    0.001    0.000    0.025    0.000 gridspec.py:456(get_position)
#      6320    0.007    0.000    0.025    0.000 artist.py:924(set_zorder)
#      3840    0.003    0.000    0.024    0.000 axis.py:1515(convert_units)
#     19520    0.012    0.000    0.024    0.000 <string>:12(__new__)
#     16200    0.007    0.000    0.024    0.000 artist.py:193(convert_yunits)
#      1200    0.002    0.000    0.024    0.000 shape_base.py:182(vstack)
#      4400    0.004    0.000    0.024    0.000 axis.py:311(set_label1)
#     22120    0.011    0.000    0.024    0.000 figure.py:58(_stale_figure_callback)
#        40    0.001    0.000    0.024    0.001 backend_bases.py:153(new_figure_manager)
#      1200    0.013    0.000    0.024    0.000 cycler.py:349(by_key)
#       120    0.001    0.000    0.023    0.000 __init__.py:1363(safe_masked_invalid)
#      4400    0.004    0.000    0.023    0.000 axis.py:322(set_label2)
#       640    0.001    0.000    0.023    0.000 patches.py:417(set_fill)
#     19400    0.014    0.000    0.023    0.000 lines.py:62(_scale_dashes)
#      1200    0.006    0.000    0.023    0.000 transforms.py:1790(__eq__)
#     13920    0.015    0.000    0.023    0.000 markers.py:226(set_fillstyle)
#        80    0.003    0.000    0.022    0.000 patches.py:507(draw)
#    156000    0.022    0.000    0.022    0.000 artist.py:202(axes)
#       160    0.001    0.000    0.022    0.000 patches.py:664(__init__)
#      4400    0.003    0.000    0.022    0.000 {method 'max' of 'numpy.ndarray' objects}
#       240    0.000    0.000    0.022    0.000 transforms.py:286(__array__)
# 7440/7200    0.004    0.000    0.022    0.000 transforms.py:2687(get_matrix)
#      2640    0.002    0.000    0.022    0.000 fromnumeric.py:2803(round_)
#      3840    0.003    0.000    0.021    0.000 units.py:118(is_numlike)
#     15748    0.021    0.000    0.021    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     12780    0.013    0.000    0.021    0.000 lines.py:1200(set_xdata)
#      8760    0.012    0.000    0.021    0.000 lines.py:1005(set_linewidth)
#       120    0.000    0.000    0.021    0.000 pyplot.py:1385(title)
#        40    0.001    0.000    0.020    0.001 tight_bbox.py:40(restore_bbox)
#      8760    0.013    0.000    0.020    0.000 lines.py:1376(set_dash_capstyle)
#    143440    0.020    0.000    0.020    0.000 {method 'items' of 'dict' objects}
#       480    0.010    0.000    0.020    0.000 ticker.py:668(_compute_offset)
#      2640    0.003    0.000    0.020    0.000 fromnumeric.py:2734(around)
#       680    0.000    0.000    0.020    0.000 transforms.py:1778(__array__)
#      3480    0.004    0.000    0.020    0.000 transforms.py:1847(frozen)
#      2440    0.002    0.000    0.020    0.000 font_manager.py:721(__eq__)
#       120    0.001    0.000    0.020    0.000 _axes.py:141(set_title)
#        40    0.004    0.000    0.019    0.000 figure.py:286(__init__)
#      4400    0.002    0.000    0.019    0.000 _methods.py:26(_amax)
#     11760    0.019    0.000    0.019    0.000 {built-in method matplotlib._path.affine_transform}
#      6440    0.015    0.000    0.018    0.000 font_manager.py:857(set_stretch)
#       240    0.003    0.000    0.018    0.000 _base.py:1166(_set_title_offset_trans)
#     22280    0.013    0.000    0.018    0.000 __init__.py:518(iterable)
#      3680    0.003    0.000    0.018    0.000 transforms.py:2285(get_affine)
#       280    0.002    0.000    0.018    0.000 core.py:5551(min)
#      2440    0.005    0.000    0.018    0.000 font_manager.py:1015(make_rcparams_key)
#       240    0.002    0.000    0.018    0.000 colors.py:896(process_value)
#        40    0.000    0.000    0.018    0.000 zmqshell.py:77(_flush_streams)
#      4400    0.018    0.000    0.018    0.000 ticker.py:771(pprint_val)
#       120    0.000    0.000    0.018    0.000 _base.py:962(_gen_axes_patch)
#       120    0.004    0.000    0.018    0.000 gridspec.py:84(get_grid_positions)
#      1200    0.002    0.000    0.017    0.000 shape_base.py:234(<listcomp>)
#        80    0.001    0.000    0.017    0.000 iostream.py:327(flush)
#      1920    0.015    0.000    0.017    0.000 function_base.py:1079(diff)
#       240    0.002    0.000    0.017    0.000 _base.py:2848(tick_params)
#       240    0.002    0.000    0.017    0.000 _base.py:3363(set_ylim)
#      7160    0.006    0.000    0.017    0.000 transforms.py:2485(transform_non_affine)
#       160    0.013    0.000    0.017    0.000 image.py:169(_rgb_to_rgba)
#      5360    0.004    0.000    0.017    0.000 colors.py:107(_is_nth_color)
#     20416    0.016    0.000    0.017    0.000 {built-in method builtins.hasattr}
#      2920    0.016    0.000    0.017    0.000 stride_tricks.py:179(_broadcast_shape)
#      1920    0.009    0.000    0.017    0.000 ticker.py:501(__init__)
# 12640/11680    0.005    0.000    0.016    0.000 spines.py:158(_ensure_position_is_set)
#       160    0.000    0.000    0.016    0.000 session.py:102(<lambda>)
#      8760    0.009    0.000    0.016    0.000 lines.py:1153(set_markeredgewidth)
#       160    0.000    0.000    0.016    0.000 jsonapi.py:31(dumps)
#      8760    0.010    0.000    0.016    0.000 lines.py:1337(set_dash_joinstyle)
#      3604    0.007    0.000    0.015    0.000 shape_base.py:63(atleast_2d)
#     12780    0.008    0.000    0.015    0.000 lines.py:1210(set_ydata)
#       120    0.000    0.000    0.015    0.000 cm.py:356(autoscale_None)
#       320    0.000    0.000    0.015    0.000 transforms.py:1423(__array__)
#      1680    0.008    0.000    0.015    0.000 axis.py:338(_apply_params)
#       160    0.001    0.000    0.015    0.000 __init__.py:182(dumps)
#      1440    0.002    0.000    0.015    0.000 transforms.py:2379(blended_transform_factory)
#      8760    0.009    0.000    0.015    0.000 lines.py:1350(set_solid_joinstyle)
#       120    0.002    0.000    0.015    0.000 axis.py:1794(_get_label)
#       960    0.011    0.000    0.014    0.000 transforms.py:2909(nonsingular)
#     16560    0.014    0.000    0.014    0.000 font_manager.py:993(<listcomp>)
#       160    0.000    0.000    0.014    0.000 encoder.py:181(encode)
#      1460    0.005    0.000    0.014    0.000 axis.py:421(apply_tickdir)
#       580    0.001    0.000    0.014    0.000 fromnumeric.py:1764(clip)
#     87600    0.014    0.000    0.014    0.000 {method 'startswith' of 'str' objects}
#       200    0.001    0.000    0.014    0.000 colors.py:987(autoscale_None)
#      8760    0.008    0.000    0.014    0.000 lines.py:1390(set_solid_capstyle)
#       160    0.013    0.000    0.014    0.000 encoder.py:203(iterencode)
#      6680    0.007    0.000    0.014    0.000 text.py:1209(set_usetex)
#      4640    0.006    0.000    0.014    0.000 ticker.py:557(fix_minus)
#      1460    0.005    0.000    0.014    0.000 axis.py:544(apply_tickdir)
#      8760    0.009    0.000    0.014    0.000 lines.py:1189(set_markersize)
#      9400    0.011    0.000    0.014    0.000 lines.py:34(_get_dash_pattern)
#      1300    0.008    0.000    0.014    0.000 core.py:2902(_update_from)
#       280    0.001    0.000    0.014    0.000 core.py:5672(max)
#       360    0.002    0.000    0.014    0.000 _base.py:903(_set_position)
#       120    0.001    0.000    0.013    0.000 _base.py:625(set_figure)
#      1200    0.002    0.000    0.013    0.000 fromnumeric.py:2016(all)
#       240    0.001    0.000    0.013    0.000 _base.py:846(_update_transScale)
# 1620/1060    0.004    0.000    0.013    0.000 {method 'view' of 'numpy.generic' objects}
#       240    0.000    0.000    0.013    0.000 transforms.py:1535(transform_path)
#      8760    0.007    0.000    0.013    0.000 lines.py:962(set_antialiased)
#      8760    0.008    0.000    0.013    0.000 lines.py:984(set_drawstyle)
#      2440    0.007    0.000    0.013    0.000 font_manager.py:1017(<listcomp>)
#      1960    0.004    0.000    0.013    0.000 patches.py:273(_set_edgecolor)
#       120    0.001    0.000    0.012    0.000 axis.py:2166(_get_label)
#      6680    0.007    0.000    0.012    0.000 text.py:949(set_color)
#     19920    0.012    0.000    0.012    0.000 {built-in method __new__ of type object at 0x55e007073560}
#       120    0.001    0.000    0.012    0.000 axis.py:2186(_get_offset_text)
#        50    0.001    0.000    0.012    0.000 functional.py:1894(interpolate)
#      1920    0.005    0.000    0.012    0.000 axis.py:1588(set_major_locator)
#        80    0.000    0.000    0.012    0.000 threading.py:531(wait)
#       480    0.002    0.000    0.012    0.000 spines.py:392(set_position)
#      1100    0.011    0.000    0.012    0.000 __init__.py:1160(__setitem__)
# 17880/10560    0.010    0.000    0.012    0.000 transforms.py:2465(_get_is_affine)
#      1200    0.004    0.000    0.012    0.000 transforms.py:2312(__init__)
#        77    0.000    0.000    0.012    0.000 threading.py:261(wait)
#      5040    0.004    0.000    0.011    0.000 re.py:160(match)
#      3040    0.003    0.000    0.011    0.000 artist.py:814(set_alpha)
#       484    0.001    0.000    0.011    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      2480    0.005    0.000    0.011    0.000 transforms.py:1039(__init__)
#       590    0.011    0.000    0.011    0.000 {method 'acquire' of '_thread.lock' objects}
#      8760    0.008    0.000    0.011    0.000 lines.py:619(axes)
#      2000    0.004    0.000    0.011    0.000 patches.py:726(_convert_units)
#      2160    0.004    0.000    0.011    0.000 transforms.py:2667(__init__)
#       484    0.000    0.000    0.011    0.000 _methods.py:34(_sum)
#       960    0.002    0.000    0.011    0.000 _base.py:3024(_validate_converted_limits)
#       840    0.002    0.000    0.011    0.000 transforms.py:282(frozen)
#        50    0.010    0.000    0.010    0.000 {built-in method torch._C._nn.upsample_nearest2d}
#      4400    0.005    0.000    0.010    0.000 transforms.py:2782(get_matrix)
#      8760    0.006    0.000    0.010    0.000 lines.py:1140(set_markeredgecolor)
#       120    0.001    0.000    0.010    0.000 axis.py:1812(_get_offset_text)
#      2440    0.006    0.000    0.010    0.000 backend_agg.py:55(get_hinting_flag)
#       560    0.001    0.000    0.009    0.000 backend_bases.py:787(new_gc)
#     52504    0.009    0.000    0.009    0.000 {method 'append' of 'list' objects}
#      1320    0.001    0.000    0.009    0.000 patches.py:288(set_edgecolor)
#     40240    0.009    0.000    0.009    0.000 transforms.py:991(get_points)
#        40    0.000    0.000    0.009    0.000 session.py:583(sign)
#      8760    0.005    0.000    0.009    0.000 lines.py:975(set_color)
#     23840    0.009    0.000    0.009    0.000 artist.py:210(axes)
#      3440    0.003    0.000    0.009    0.000 transforms.py:2233(_get_is_affine)
#       560    0.003    0.000    0.009    0.000 backend_bases.py:849(__init__)
#     11880    0.009    0.000    0.009    0.000 {built-in method builtins.max}
#      1340    0.001    0.000    0.008    0.000 text.py:236(get_rotation)
#       240    0.002    0.000    0.008    0.000 _base.py:604(get_window_extent)
#     52080    0.008    0.000    0.008    0.000 {method 'lower' of 'str' objects}
#      2600    0.001    0.000    0.008    0.000 transforms.py:2746(get_matrix)
#       720    0.002    0.000    0.008    0.000 fromnumeric.py:36(_wrapit)
#       240    0.004    0.000    0.008    0.000 transforms.py:564(anchored)
#       160    0.000    0.000    0.008    0.000 hmac.py:90(update)
#      6440    0.005    0.000    0.008    0.000 font_manager.py:817(set_style)
#      1920    0.003    0.000    0.008    0.000 axis.py:1566(set_major_formatter)
#       200    0.008    0.000    0.008    0.000 {method 'update' of '_hashlib.HASH' objects}
#      1200    0.008    0.000    0.008    0.000 {method 'round' of 'numpy.ndarray' objects}
#       360    0.002    0.000    0.008    0.000 transforms.py:1009(set)
#      4140    0.003    0.000    0.008    0.000 <frozen importlib._bootstrap>:995(_handle_fromlist)
#       400    0.003    0.000    0.008    0.000 __init__.py:333(connect)
#       580    0.008    0.000    0.008    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      1440    0.003    0.000    0.008    0.000 axis.py:1529(set_units)
#      8080    0.006    0.000    0.008    0.000 artist.py:317(get_transform)
#      6680    0.004    0.000    0.008    0.000 text.py:240(set_rotation_mode)
#       120    0.001    0.000    0.008    0.000 _base.py:2108(update_datalim)
#       440    0.001    0.000    0.008    0.000 formatters.py:374(lookup)
#      4960    0.005    0.000    0.008    0.000 transforms.py:409(width)
#        40    0.008    0.000    0.008    0.000 {built-in method flip}
#       120    0.001    0.000    0.008    0.000 image.py:827(get_window_extent)
#       240    0.000    0.000    0.008    0.000 transforms.py:1546(transform_path_affine)
#       240    0.001    0.000    0.007    0.000 transforms.py:1734(set)
#    240/40    0.002    0.000    0.007    0.000 jsonutil.py:109(json_clean)
#      6560    0.004    0.000    0.007    0.000 font_manager.py:1102(get_default_size)
#       480    0.001    0.000    0.007    0.000 fromnumeric.py:2159(ptp)
#     29680    0.007    0.000    0.007    0.000 transforms.py:1957(get_matrix)
#       240    0.007    0.000    0.007    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       240    0.001    0.000    0.007    0.000 _base.py:2130(_process_unit_info)
#      1340    0.007    0.000    0.007    0.000 text.py:56(get_rotation)
#      1920    0.002    0.000    0.007    0.000 axis.py:1599(set_minor_locator)
#      1340    0.002    0.000    0.007    0.000 text.py:1170(is_math_text)
#       240    0.001    0.000    0.007    0.000 transforms.py:1812(transform_path_affine)
#       960    0.003    0.000    0.007    0.000 numeric.py:2491(seterr)
#        40    0.000    0.000    0.007    0.000 <decorator-gen-10>:1(__call__)
#      1920    0.007    0.000    0.007    0.000 axis.py:824(reset_ticks)
#      1920    0.002    0.000    0.007    0.000 axis.py:1577(set_minor_formatter)
#       240    0.003    0.000    0.007    0.000 transforms.py:611(shrunk_to_aspect)
#        40    0.001    0.000    0.007    0.000 formatters.py:689(__call__)
#       120    0.001    0.000    0.007    0.000 _base.py:647(_set_lim_and_transforms)
#     12020    0.007    0.000    0.007    0.000 {method 'update' of 'dict' objects}
#       240    0.000    0.000    0.007    0.000 axis.py:1456(update_units)
#       120    0.001    0.000    0.006    0.000 image.py:787(__init__)
#       120    0.000    0.000    0.006    0.000 transforms.py:905(update_from_data_xy)
#      2644    0.006    0.000    0.006    0.000 {built-in method builtins.min}
#       120    0.003    0.000    0.006    0.000 core.py:2328(masked_invalid)
#         4    0.000    0.000    0.006    0.002 validation.py:33(_assert_all_finite)
#      6440    0.004    0.000    0.006    0.000 font_manager.py:829(set_variant)
#     42420    0.006    0.000    0.006    0.000 {method 'values' of 'dict' objects}
#   480/240    0.002    0.000    0.006    0.000 units.py:141(get_converter)
#      1440    0.006    0.000    0.006    0.000 {method 'round' of 'numpy.generic' objects}
#      2920    0.005    0.000    0.006    0.000 stride_tricks.py:250(<listcomp>)
#       480    0.003    0.000    0.006    0.000 _methods.py:151(_ptp)
#       440    0.002    0.000    0.006    0.000 formatters.py:397(lookup_by_type)
#     49480    0.006    0.000    0.006    0.000 {built-in method builtins.id}
#       120    0.001    0.000    0.006    0.000 image.py:204(__init__)
#      1080    0.003    0.000    0.006    0.000 __init__.py:1564(get_siblings)
#      2920    0.004    0.000    0.006    0.000 axis.py:192(_set_labelrotation)
#       360    0.001    0.000    0.006    0.000 _base.py:857(get_position)
#       120    0.001    0.000    0.006    0.000 transforms.py:537(transformed)
#       560    0.001    0.000    0.006    0.000 core.py:294(_extremum_fill_value)
#       960    0.004    0.000    0.005    0.000 axis.py:875(_translate_tick_kw)
#     13392    0.005    0.000    0.005    0.000 cycler.py:227(<genexpr>)
#       720    0.001    0.000    0.005    0.000 text.py:532(set_clip_box)
#       240    0.001    0.000    0.005    0.000 transforms.py:1558(transform_path_non_affine)
#      1200    0.002    0.000    0.005    0.000 transforms.py:2529(__init__)
#       480    0.001    0.000    0.005    0.000 ticker.py:1699(le)
#       480    0.003    0.000    0.005    0.000 _base.py:4081(get_children)
#       960    0.003    0.000    0.005    0.000 ticker.py:201(_divmod)
#      1240    0.002    0.000    0.005    0.000 patches.py:351(set_linewidth)
#        40    0.001    0.000    0.005    0.000 pretty.py:359(pretty)
#       120    0.001    0.000    0.005    0.000 gridspec.py:266(get_subplot_params)
#      4140    0.002    0.000    0.005    0.000 text.py:1114(set_x)
#      1920    0.004    0.000    0.005    0.000 scale.py:560(scale_factory)
#     34640    0.005    0.000    0.005    0.000 artist.py:940(sticky_edges)
#       480    0.001    0.000    0.005    0.000 numeric.py:2891(__enter__)
#      5040    0.005    0.000    0.005    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#      2440    0.003    0.000    0.005    0.000 font_manager.py:1383(get_font)
#      1200    0.002    0.000    0.005    0.000 transforms.py:2573(get_matrix)
#      5120    0.002    0.000    0.005    0.000 traitlets.py:545(__get__)
#       640    0.002    0.000    0.005    0.000 patches.py:373(set_linestyle)
#       240    0.000    0.000    0.005    0.000 fromnumeric.py:2092(cumsum)
#       202    0.004    0.000    0.004    0.000 iostream.py:195(schedule)
#      1340    0.003    0.000    0.004    0.000 __init__.py:2026(is_math_text)
#      4140    0.002    0.000    0.004    0.000 text.py:1123(set_y)
#       120    0.001    0.000    0.004    0.000 _base.py:1903(add_image)
#       600    0.003    0.000    0.004    0.000 _base.py:3006(get_xlim)
#       240    0.002    0.000    0.004    0.000 axis.py:1165(<listcomp>)
#       480    0.001    0.000    0.004    0.000 _base.py:952(_set_artist_props)
#      1640    0.004    0.000    0.004    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       480    0.003    0.000    0.004    0.000 ticker.py:1772(scale_range)
#       640    0.001    0.000    0.004    0.000 core.py:3659(filled)
#      3880    0.004    0.000    0.004    0.000 axis.py:215(get_tick_padding)
#       240    0.001    0.000    0.004    0.000 _base.py:1483(get_data_ratio)
#       480    0.001    0.000    0.004    0.000 numeric.py:2896(__exit__)
#       960    0.003    0.000    0.004    0.000 {built-in method builtins.sorted}
#        40    0.000    0.000    0.004    0.000 backend_bases.py:163(new_figure_manager_given_figure)
#      2440    0.004    0.000    0.004    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       120    0.000    0.000    0.004    0.000 pyplot.py:1432(axis)
#        40    0.000    0.000    0.004    0.000 pretty.py:502(_default_pprint)
#       480    0.003    0.000    0.004    0.000 ticker.py:710(_set_orderOfMagnitude)
#       280    0.000    0.000    0.004    0.000 core.py:309(minimum_fill_value)
#        80    0.000    0.000    0.004    0.000 backend_agg.py:142(draw_path)
#        40    0.004    0.000    0.004    0.000 {built-in method binascii.b2a_base64}
#       280    0.000    0.000    0.004    0.000 {method 'view' of 'numpy.ndarray' objects}
#      8760    0.004    0.000    0.004    0.000 stride_tricks.py:254(<genexpr>)
#        40    0.000    0.000    0.004    0.000 pretty.py:698(_repr_pprint)
#       320    0.002    0.000    0.003    0.000 transforms.py:427(size)
#       160    0.000    0.000    0.003    0.000 backend_bases.py:2337(mpl_connect)
#       640    0.001    0.000    0.003    0.000 core.py:214(_recursive_fill_value)
#      8760    0.003    0.000    0.003    0.000 lines.py:537(set_markevery)
#       720    0.001    0.000    0.003    0.000 spines.py:148(get_patch_transform)
#       520    0.000    0.000    0.003    0.000 {built-in method builtins.repr}
#      1320    0.001    0.000    0.003    0.000 core.py:596(filled)
#       240    0.001    0.000    0.003    0.000 path.py:164(_fast_from_codes_and_verts)
#       480    0.001    0.000    0.003    0.000 ticker.py:1715(ge)
#      5840    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1120    0.002    0.000    0.003    0.000 patches.py:440(set_capstyle)
#      2440    0.003    0.000    0.003    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#     20320    0.003    0.000    0.003    0.000 {method 'pop' of 'dict' objects}
#       120    0.001    0.000    0.003    0.000 axis.py:2307(_update_offset_text_position)
#      5040    0.003    0.000    0.003    0.000 re.py:278(_compile)
#       720    0.001    0.000    0.003    0.000 artist.py:637(set_clip_box)
#       360    0.001    0.000    0.003    0.000 _base.py:1290(set_aspect)
#       240    0.001    0.000    0.003    0.000 transforms.py:961(intervalx)
#        80    0.003    0.000    0.003    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        40    0.000    0.000    0.003    0.000 figure.py:279(__repr__)
#        80    0.000    0.000    0.003    0.000 core.py:7763(asarray)
#        40    0.000    0.000    0.003    0.000 figure.py:2169(get_default_bbox_extra_artists)
#        40    0.000    0.000    0.003    0.000 session.py:564(msg)
#       120    0.001    0.000    0.003    0.000 transforms.py:869(update_from_path)
#       480    0.001    0.000    0.003    0.000 __init__.py:2346(safe_first_element)
#       200    0.000    0.000    0.003    0.000 {method 'any' of 'numpy.ndarray' objects}
#       960    0.001    0.000    0.003    0.000 axis.py:2062(get_view_interval)
#       960    0.001    0.000    0.003    0.000 axis.py:2440(get_view_interval)
#       240    0.000    0.000    0.003    0.000 artist.py:243(get_window_extent)
#      1560    0.002    0.000    0.003    0.000 transforms.py:392(intervalx)
#      1120    0.001    0.000    0.003    0.000 transforms.py:296(x0)
#       480    0.002    0.000    0.003    0.000 axis.py:1172(get_tick_padding)
#       480    0.002    0.000    0.003    0.000 spines.py:318(_calc_offset_transform)
#        40    0.000    0.000    0.003    0.000 backend_bases.py:1770(__init__)
#       200    0.000    0.000    0.003    0.000 _methods.py:42(_any)
#       480    0.001    0.000    0.003    0.000 pyplot.py:966(gca)
#        80    0.001    0.000    0.003    0.000 figure.py:873(set_size_inches)
#       600    0.002    0.000    0.003    0.000 _base.py:3345(get_ylim)
#       160    0.002    0.000    0.003    0.000 mathtext.py:3245(__init__)
#       120    0.001    0.000    0.003    0.000 _base.py:1662(axis)
#       240    0.001    0.000    0.003    0.000 transforms.py:966(intervaly)
#       560    0.001    0.000    0.003    0.000 core.py:296(_scalar_fill_value)
#       280    0.000    0.000    0.003    0.000 core.py:360(maximum_fill_value)
#        40    0.000    0.000    0.003    0.000 session.py:561(msg_header)
#       120    0.001    0.000    0.003    0.000 copy.py:67(copy)
#       800    0.002    0.000    0.003    0.000 __init__.py:161(__init__)
#       960    0.002    0.000    0.002    0.000 numeric.py:2592(geterr)
#       480    0.001    0.000    0.002    0.000 text.py:1105(set_position)
#       400    0.001    0.000    0.002    0.000 figure.py:462(_get_axes)
#      6060    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#     14160    0.002    0.000    0.002    0.000 font_manager.py:781(get_size_in_points)
#      4480    0.002    0.000    0.002    0.000 core.py:3345(dtype)
#       120    0.001    0.000    0.002    0.000 __init__.py:68(process_projection_requirements)
#       960    0.002    0.000    0.002    0.000 getlimits.py:376(__new__)
#     10380    0.002    0.000    0.002    0.000 text.py:872(get_text)
#     12600    0.002    0.000    0.002    0.000 artist.py:711(get_visible)
#     11240    0.002    0.000    0.002    0.000 font_manager.py:730(get_family)
#      1560    0.002    0.000    0.002    0.000 transforms.py:400(intervaly)
# ...
#       560    0.000    0.000    0.000    0.000 backend_bases.py:920(get_clip_path)
#       120    0.000    0.000    0.000    0.000 image.py:747(set_filternorm)
#       320    0.000    0.000    0.000    0.000 figure.py:1450(<genexpr>)
#       120    0.000    0.000    0.000    0.000 _base.py:2952(set_axis_on)
#       440    0.000    0.000    0.000    0.000 formatters.py:359(_check_return)
#       800    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        50    0.000    0.000    0.000    0.000 functional.py:1944(_output_size)
#       120    0.000    0.000    0.000    0.000 transforms.py:2449(__eq__)
#       520    0.000    0.000    0.000    0.000 figure.py:88(<listcomp>)
#       560    0.000    0.000    0.000    0.000 image.py:688(get_interpolation)
#        80    0.000    0.000    0.000    0.000 core.py:284(_scalar_fill_value)
#       160    0.000    0.000    0.000    0.000 py3compat.py:188(iteritems)
#       360    0.000    0.000    0.000    0.000 pretty.py:100(_safe_getattr)
#        40    0.000    0.000    0.000    0.000 _pylab_helpers.py:115(set_active)
#      1040    0.000    0.000    0.000    0.000 path.py:241(simplify_threshold)
#       240    0.000    0.000    0.000    0.000 transforms.py:314(x1)
#        80    0.000    0.000    0.000    0.000 artist.py:505(get_snap)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:930(get_dashes)
#       240    0.000    0.000    0.000    0.000 transforms.py:323(y1)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1120(set_url)
#       202    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       480    0.000    0.000    0.000    0.000 type_check.py:147(imag)
#       120    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1166(get_hatch_color)
#       120    0.000    0.000    0.000    0.000 gridspec.py:391(__init__)
#       480    0.000    0.000    0.000    0.000 _base.py:946(get_axes_locator)
#        40    0.000    0.000    0.000    0.000 tz.py:174(utcoffset)
#       120    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#        40    0.000    0.000    0.000    0.000 figure.py:493(set_tight_layout)
#       720    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        40    0.000    0.000    0.000    0.000 session.py:242(extract_header)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1045(set_clip_path)
#       240    0.000    0.000    0.000    0.000 transforms.py:983(minposx)
#       240    0.000    0.000    0.000    0.000 backend_agg.py:267(get_canvas_width_height)
#        40    0.000    0.000    0.000    0.000 figure.py:2170(<listcomp>)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:990(get_snap)
#       800    0.000    0.000    0.000    0.000 __init__.py:249(__hash__)
#        40    0.000    0.000    0.000    0.000 __init__.py:1176(__init__)
#        80    0.000    0.000    0.000    0.000 figure.py:933(get_facecolor)
#        40    0.000    0.000    0.000    0.000 pretty.py:211(text)
#       240    0.000    0.000    0.000    0.000 transforms.py:987(minposy)
#         4    0.000    0.000    0.000    0.000 stride_tricks.py:38(as_strided)
#       120    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#       240    0.000    0.000    0.000    0.000 text.py:580(get_wrap)
#       240    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       200    0.000    0.000    0.000    0.000 __init__.py:1226(clear)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1151(get_hatch)
#        40    0.000    0.000    0.000    0.000 patches.py:269(set_aa)
#       120    0.000    0.000    0.000    0.000 gridspec.py:143(_normalize)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1178(get_hatch_linewidth)
#       160    0.000    0.000    0.000    0.000 core.py:3175(_scalar_heuristic)
#       480    0.000    0.000    0.000    0.000 axis.py:1439(<dictcomp>)
#        40    0.000    0.000    0.000    0.000 session.py:739(<listcomp>)
#       200    0.000    0.000    0.000    0.000 path.py:626(unit_rectangle)
#       240    0.000    0.000    0.000    0.000 {built-in method math.sin}
#       480    0.000    0.000    0.000    0.000 _base.py:1287(get_aspect)
#       240    0.000    0.000    0.000    0.000 axis.py:1512(have_units)
#       560    0.000    0.000    0.000    0.000 artist.py:490(get_gid)
#       120    0.000    0.000    0.000    0.000 _subplots.py:201(subplot_class_factory)
#       480    0.000    0.000    0.000    0.000 ticker.py:1593(tick_values)
#       640    0.000    0.000    0.000    0.000 backend_bases.py:267(open_group)
#       560    0.000    0.000    0.000    0.000 backend_bases.py:1184(get_sketch_params)
#        80    0.000    0.000    0.000    0.000 __init__.py:1433(is_interactive)
#        80    0.000    0.000    0.000    0.000 pretty.py:465(__init__)
#       480    0.000    0.000    0.000    0.000 axis.py:980(<listcomp>)
#       120    0.000    0.000    0.000    0.000 weakref.py:371(_commit_removals)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1404(__init__)
#       480    0.000    0.000    0.000    0.000 scale.py:47(limit_range_for_scale)
#       480    0.000    0.000    0.000    0.000 {built-in method math.radians}
#       120    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#         5    0.000    0.000    0.000    0.000 {built-in method ones}
#       560    0.000    0.000    0.000    0.000 backend_bases.py:890(restore)
#        10    0.000    0.000    0.000    0.000 {built-in method randn}
#        80    0.000    0.000    0.000    0.000 transforms.py:2495(transform_path_non_affine)
#        80    0.000    0.000    0.000    0.000 figure.py:929(get_edgecolor)
#       360    0.000    0.000    0.000    0.000 gridspec.py:51(get_geometry)
#       480    0.000    0.000    0.000    0.000 artist.py:1049(mouseover)
#       240    0.000    0.000    0.000    0.000 _base.py:1412(get_anchor)
#        40    0.000    0.000    0.000    0.000 backend_bases.py:2087(_get_output_canvas)
#       240    0.000    0.000    0.000    0.000 artist.py:920(get_zorder)
#       240    0.000    0.000    0.000    0.000 cm.py:290(get_array)
#        40    0.000    0.000    0.000    0.000 _pylab_helpers.py:35(get_fig_manager)
#       240    0.000    0.000    0.000    0.000 backend_bases.py:1793(is_saving)
#        77    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#        40    0.000    0.000    0.000    0.000 formatters.py:940(_check_return)
#       240    0.000    0.000    0.000    0.000 _base.py:2523(_get_axis_list)
#        40    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#        40    0.000    0.000    0.000    0.000 pretty.py:300(flush)
#        80    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#       320    0.000    0.000    0.000    0.000 artist.py:605(get_path_effects)
#       320    0.000    0.000    0.000    0.000 image.py:778(get_filterrad)
#       240    0.000    0.000    0.000    0.000 backend_bases.py:1039(set_clip_rectangle)
#        40    0.000    0.000    0.000    0.000 __init__.py:1419(get_backend)
#       120    0.000    0.000    0.000    0.000 figure.py:108(<dictcomp>)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1103(set_linewidth)
#        40    0.000    0.000    0.000    0.000 py3compat.py:19(encode)
#       120    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       640    0.000    0.000    0.000    0.000 backend_bases.py:274(close_group)
#       240    0.000    0.000    0.000    0.000 text.py:761(get_color)
#       120    0.000    0.000    0.000    0.000 gridspec.py:75(set_height_ratios)
#       240    0.000    0.000    0.000    0.000 figure.py:516(get_constrained_layout)
#        40    0.000    0.000    0.000    0.000 weakref.py:356(remove)
#        80    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#        40    0.000    0.000    0.000    0.000 displaypub.py:38(_validate_data)
#       220    0.000    0.000    0.000    0.000 core.py:3444(_get_mask)
#       320    0.000    0.000    0.000    0.000 backend_agg.py:303(option_image_nocomposite)
#         1    0.000    0.000    0.000    0.000 warnings.py:10(showwarning)
#       320    0.000    0.000    0.000    0.000 image.py:761(get_filternorm)
#        80    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_hex}
#       240    0.000    0.000    0.000    0.000 path.py:267(should_simplify)
#       360    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#       240    0.000    0.000    0.000    0.000 path.py:249(simplify_threshold)
#         4    0.000    0.000    0.000    0.000 numeric.py:1407(rollaxis)
#        80    0.000    0.000    0.000    0.000 __init__.py:1483(__init__)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1030(set_capstyle)
#       240    0.000    0.000    0.000    0.000 artist.py:608(get_figure)
#       240    0.000    0.000    0.000    0.000 image.py:743(get_resample)
#        80    0.000    0.000    0.000    0.000 jsonutil.py:34(_ensure_tzinfo)
#        40    0.000    0.000    0.000    0.000 pretty.py:495(remove)
#        40    0.000    0.000    0.000    0.000 tz.py:218(_isdst)
#        40    0.000    0.000    0.000    0.000 jsonutil.py:49(encode_images)
#       480    0.000    0.000    0.000    0.000 artist.py:296(is_transform_set)
#        77    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#       120    0.000    0.000    0.000    0.000 figure.py:1015(fixitems)
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        80    0.000    0.000    0.000    0.000 patches.py:720(_update_x1)
#        77    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#       282    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#        40    0.000    0.000    0.000    0.000 figure.py:415(_repr_html_)
#       240    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       240    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 validation.py:125(_shape_repr)
#         4    0.000    0.000    0.000    0.000 {built-in method from_numpy}
#         1    0.000    0.000    0.000    0.000 iostream.py:366(write)
#       240    0.000    0.000    0.000    0.000 backend_bases.py:563(get_image_magnification)
#       240    0.000    0.000    0.000    0.000 artist.py:475(get_url)
#        40    0.000    0.000    0.000    0.000 configurable.py:426(initialized)
#        80    0.000    0.000    0.000    0.000 patches.py:723(_update_y1)
#       120    0.000    0.000    0.000    0.000 gridspec.py:66(set_width_ratios)
#       279    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       240    0.000    0.000    0.000    0.000 backend_bases.py:766(flipy)
#       120    0.000    0.000    0.000    0.000 _base.py:3716(set_navigate)
#       157    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        80    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       120    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1094(set_joinstyle)
#        80    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       240    0.000    0.000    0.000    0.000 backend_bases.py:1126(set_gid)
#         4    0.000    0.000    0.000    0.000 utils.py:6(parse)
#       120    0.000    0.000    0.000    0.000 artist.py:479(set_url)
#         4    0.000    0.000    0.000    0.000 functional.py:1950(<listcomp>)
#        40    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#       120    0.000    0.000    0.000    0.000 _base.py:3734(set_navigate_mode)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1056(set_dashes)
#       120    0.000    0.000    0.000    0.000 gridspec.py:428(get_gridspec)
#       240    0.000    0.000    0.000    0.000 colors.py:97(_sanitize_extrema)
#        40    0.000    0.000    0.000    0.000 widgets.py:37(__init__)
#        40    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        41    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        40    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#       120    0.000    0.000    0.000    0.000 artist.py:897(get_label)
#        80    0.000    0.000    0.000    0.000 figure.py:759(set_canvas)
#       120    0.000    0.000    0.000    0.000 _subplots.py:123(get_subplotspec)
#        50    0.000    0.000    0.000    0.000 functional.py:1934(_check_size_scale_factor)
#        80    0.000    0.000    0.000    0.000 patches.py:233(get_facecolor)
#        80    0.000    0.000    0.000    0.000 patches.py:226(get_edgecolor)
#        80    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       120    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        80    0.000    0.000    0.000    0.000 artist.py:544(get_sketch_params)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1019(set_antialiased)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:2046(draw)
#       120    0.000    0.000    0.000    0.000 tight_bbox.py:35(_l)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:1132(set_snap)
#        80    0.000    0.000    0.000    0.000 figure.py:487(get_tight_layout)
#         4    0.000    0.000    0.000    0.000 image.py:204(_compute_n_patches)
#         4    0.000    0.000    0.000    0.000 validation.py:104(_num_samples)
#        40    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#        80    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        40    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 warnings.py:22(formatwarning)
#        80    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 backend_bases.py:2689(destroy)
#        77    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        80    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#        40    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        16    0.000    0.000    0.000    0.000 validation.py:152(<genexpr>)
#        40    0.000    0.000    0.000    0.000 formatters.py:824(_check_return)
#         1    0.000    0.000    0.000    0.000 iostream.py:313(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 validation.py:617(check_random_state)
#         4    0.000    0.000    0.000    0.000 image.py:286(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 stride_tricks.py:20(__init__)
#         4    0.000    0.000    0.000    0.000 base.py:1202(isspmatrix)
#         4    0.000    0.000    0.000    0.000 __init__.py:29(get_config)
#         1    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:300(_is_master_process)
#         4    0.000    0.000    0.000    0.000 utils.py:5(_ntuple)
#         1    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#         4    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
#cProfile.run('z=reconstruct(tr[:,:4,:,:],8,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:,:,:],4)',sort='cumtime')
tempe = tr[0,:,:128,128:]
tempe2 = tr[0,:,128:256,128:256]
glom = torch.zeros((2,10,128,128)).to(device)
glom[0] = tempe
glom[1] = tempe2
cProfile.run('z=reconstruct(tr[:,:4,:,:],8,tempe[:4,:,:],torch.ones(4,128,128)/50,tempe[4:,:,:],4)',sort='cumtime')
#cProfile.run('z=reconstructplural(tr[:,:4,:,:],8,glom[:,:4,:,:],torch.ones(2,4,128,128)/50,glom[:,4:,:,:],8)',sort='cumtime')
torch.cuda.empty_cache()
# Out:
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
#          45539 function calls in 4.966 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    4.966    4.966 {built-in method builtins.exec}
#         1    0.000    0.000    4.966    4.966 <string>:1(<module>)
#         1    3.953    3.953    4.966    4.966 <ipython-input-4-714a933696db>:228(reconstruct)
#      7938    0.549    0.000    0.549    0.000 {built-in method conv2d}
#      3969    0.084    0.000    0.163    0.000 tensor.py:324(__rdiv__)
#      3969    0.014    0.000    0.150    0.000 functional.py:346(argmax)
#      3969    0.102    0.000    0.102    0.000 {built-in method _argmax}
#      3969    0.080    0.000    0.080    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#      3969    0.075    0.000    0.075    0.000 tensor.py:346(__floordiv__)
#      7940    0.065    0.000    0.065    0.000 {built-in method squeeze}
#      3969    0.031    0.000    0.031    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#         5    0.004    0.001    0.004    0.001 {built-in method zeros}
#        66    0.000    0.000    0.004    0.000 {built-in method builtins.print}
#       132    0.001    0.000    0.004    0.000 iostream.py:366(write)
#       154    0.002    0.000    0.003    0.000 iostream.py:195(schedule)
#      3969    0.002    0.000    0.002    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#         5    0.001    0.000    0.001    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#       154    0.000    0.000    0.001    0.000 threading.py:1102(is_alive)
#         2    0.000    0.000    0.001    0.000 <ipython-input-4-714a933696db>:8(cum_sum)
#       132    0.000    0.000    0.000    0.000 iostream.py:300(_is_master_process)
#         2    0.000    0.000    0.000    0.000 functional.py:2112(pad)
#       154    0.000    0.000    0.000    0.000 threading.py:1060(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 {built-in method apply}
#       132    0.000    0.000    0.000    0.000 iostream.py:313(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 padding.py:12(forward)
#       154    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#       154    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       132    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {built-in method cumsum}
#         2    0.000    0.000    0.000    0.000 {built-in method sum}
#         1    0.000    0.000    0.000    0.000 {built-in method ones}
#       132    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       154    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#         2    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method log}
#       154    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        12    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 padding.py:23(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 padding.py:18(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:24(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
#np.savez_compressed('reconstruction',a=z)
zmax = torch.argmax(z,dim=0)
z2 = z.permute(1,2,0)
labels = torch.matmul(z2,palette_torch)/256
fig=plt.figure(figsize=(21,14))
fig.add_subplot(131)
plt.axis('off')
plt.title('soft labels')
plt.imshow(labels)
fig.add_subplot(132)
plt.axis('off')
plt.title('argmax labels')
plt.imshow(palette_torch[zmax].int())
fig.add_subplot(133)
plt.axis('off')
plt.title('ground truth labels')
plt.imshow(palette_torch[get_labels(tr)].int())
plt.show()
plt.close()
error=zmax.cpu().numpy()-get_labels(tr)[:zmax.shape[0],:zmax.shape[1]]
print(torch.sum(error==0).float()/zmax.shape[0]**2)
plt.figure(figsize=(8,8))
temp = (error==0)
plt.imshow(temp,cmap='hot',interpolation='nearest')
plt.axis('off')
plt.show()
plt.close()
# Out:
# tensor(0.7136)

# %%
def learnnaive(p,esize,asize,rate):
    size = p.shape[2]
    glom = torch.zeros((2,10,esize,esize)).to(device)
    glom[0] = p[0,:,:esize,esize:]#unstable, careful
    step = esize//asize
    for i in range(step):
        for j in range(step):
            print(str(i)+' '+str(j))
            z = reconstructplural(p[:,:4,:,:],asize,glom[:,:4,:,:],torch.ones(2,4,128,128)/50,glom[:,4:,:,:],rate)
            torch.cuda.empty_cache()
            #argmax = torch.argmax(z)
            zmax = torch.argmax(z,dim=0)
            error = zmax-get_labels(p)[:size,:size]
            cumerror = cum_sum(error.view(1,1,size,size),asize)
            maxerror = torch.argmax(cumerror)
            #print(maxerror)
            mi = maxerror//size
            mj = maxerror - mi*size
            #print(mi,mj)
            glom[1,:,i*asize:(i+1)*asize,j*asize:(j+1)*asize] = tr[0,:,mi:mi+asize,mj:mj+asize]
            #print(glom[1,:,:,:])
    return glom

# %%
cProfile.run('glom = learnnaive(tr,128,8,4)',sort='cumtime')
print(glom.shape)
z=reconstructplural(tr[:,:4,:,:],8,glom[:,:4,:,:],torch.ones(2,4,128,128)/50,glom[:,4:,:,:],2)
torch.cuda.empty_cache()
zmax = torch.argmax(z,dim=0)
z2 = z.permute(1,2,0)
labels = torch.matmul(z2,palette_torch)/256
fig=plt.figure(figsize=(21,14))
fig.add_subplot(131)
plt.axis('off')
plt.title('soft labels')
plt.imshow(labels)
fig.add_subplot(132)
plt.axis('off')
plt.title('argmax labels')
plt.imshow(palette_torch[zmax].int())
fig.add_subplot(133)
plt.axis('off')
plt.title('ground truth labels')
plt.imshow(palette_torch[get_labels(tr)].int())
plt.show()
plt.close()
error=zmax.cpu().numpy()-get_labels(tr)[:zmax.shape[0],:zmax.shape[1]]
print(torch.sum(error==0).float()/zmax.shape[0]**2)
plt.figure(figsize=(8,8))
temp = (error==0)
plt.imshow(temp,cmap='hot',interpolation='nearest')
plt.axis('off')
plt.show()
plt.close()
disp_10(glom)
# Out:
# 0 0
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 1
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 2
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 3
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 4
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 5
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 6
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 7
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 8
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 9
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 10
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 11
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 12
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 13
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 14
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 0 15
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 0
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 1
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 2
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 3
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 4
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 5
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 6
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 7
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 8
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 9
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 10
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 11
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 12
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 13
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 14
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 1 15
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 0
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 1
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 2
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 3
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 4
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 5
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 6
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 7
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 8
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212 216 220 224 228 232 236 240 244 248
# 2 9
# 0 4 8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92 96
# 100 104 108 112 116 120 124 128 132 136 140 144 148 152 156 160 164 168 172 176 180 184 188 192 196
# 200 204 208 212

# %%
from annoy import AnnoyIndex
idx = 8
print(e.shape,ev.shape,p.shape)
ewrap = torch.squeeze(e).permute(1,2,0)[:,:,:4]
evwrap = torch.squeeze(ev).permute(1,2,0)[:,:,:4]
epatches = extract_patches_2d(ewrap,(idx,idx))
evpatches = extract_patches_2d(evwrap,(idx,idx))
ppatches = extract_patches_2d(p,(idx,idx))
print(epatches.shape,evpatches.shape,ppatches.shape)
# %%time
ai = AnnoyIndex(4*idx**2)
for i,p in enumerate(epatches):
    ai.add_item(i,p)
# Out:
# torch.Size([1, 10, 128, 128]) torch.Size([1, 10, 128, 128]) torch.Size([128, 128])
# (14641, 8, 8, 10) (14641, 8, 8, 10) (14641, 8, 8)
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides

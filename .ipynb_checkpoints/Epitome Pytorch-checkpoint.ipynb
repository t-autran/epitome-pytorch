# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys,os,time

import numpy as np
import skimage.transform
import skimage.measure
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import rasterio

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn.feature_extraction.image import extract_patches_2d

import cProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

def cum_sum(arr, s):
    cumsum = torch.cumsum(torch.cumsum(arr,dim=2),dim=3)
    cumsum = F.pad(cumsum,(1,0,1,0),'constant',0)
    tot = cumsum[:,:,:-s,:-s]-cumsum[:,:,s:,:-s]-cumsum[:,:,:-s,s:]+cumsum[:,:,s:,s:]
    return tot

def to_disp(arr):
    arr_c = arr.cpu().numpy()
    arr_c = np.rollaxis(np.squeeze(arr_c),0,3)
    return arr_c

#learns N x N epitome from T, K x K random patches drawn from input image x.
#Applies NIT iterations of the E-M algorithm at scale sc; T*sc^2 patches are sampled.
#e,ev = initial epitome mean and variance. The mean is initialized
#to the uniform image with some small noise, and the variance is initialized to 1
#p returns an array of probabilities of using each part of the epitome

def epitome(x,K,N,T,NIT,sc):
    #initialize parameters
    x = F.interpolate(x,scale_factor=sc)
    x = np.clip(x,0,1)
    _, numDim, SY, SX = x.shape
    TFIN = T
    T = int(np.ceil(TFIN*sc**2))
    NFIN = N
    N = int(np.ceil(sc*NFIN))
    e = torch.zeros((1,numDim,N,N)).to(device)
    ev = torch.ones((1,numDim,N,N)).to(device)
    for i in range(numDim):
        e[:,i,:,:] = x[0,i,:,:].std()*torch.randn(N,N)/100 + x[0,i,:,:].mean() #e = mean of image plus noise
    p = (torch.ones((N,N))/N**2).to(device)
    MINP = 1e-6#1e-30
    MINV = 1e-2#1e-6
    
    #allocate trace of epitome
    etr = torch.zeros((NIT+1,1,numDim,NFIN,NFIN))
    etr[0,:,:,:,:] = F.interpolate(e,[NFIN,NFIN])
    N = int(np.ceil(sc*NFIN))
    e = torch.clamp(F.interpolate(e,[N,N]),min=0,max=1)
    ev = torch.clamp(F.interpolate(ev,[N,N]),min=MINV)
    p /= torch.sum(p)
    #x = torch.clamp(x,min=0,max=1)
    T = int(np.ceil(sc**2*TFIN))
    #lP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumPy = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    sumPy2 = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    ewrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
    evwrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
    SY = x.shape[2]
    SX = x.shape[3]
    ytemp = np.rollaxis(extract_patches_2d(torch.squeeze(x).permute(1,2,0),(K,K),max_patches=T),3,1)
    y = torch.from_numpy(ytemp).float().to(device)
    
    #perform NIT iterations of EM algorithm
    for nit in range(NIT):
        #glues together borders of e
        ewrap[:,:N,:N] = e;
        ewrap[:,N:,:] = ewrap[:,:K-1,:]
        ewrap[:,:,N:] = ewrap[:,:,:K-1]
        evwrap[:,:N,:N] = ev
        evwrap[:,N:,:] = evwrap[:,:K-1,:]
        evwrap[:,:,N:] = evwrap[:,:,:K-1]
        logevwrap = torch.log(evwrap)
        evwrapi = 1./evwrap

        # E STEP
        sumP[:,:] = 0
        sumPy[:,:,:] = 0
        sumPy2[:,:,:] = 0
        for t in range(T):
            yc = y[t,:,:,:]
            yct = torch.unsqueeze(torch.flip(yc,[1,2]),0)
            #compute posterior over patch location
            lP = torch.log(p)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrapi,0),yct))
            tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
            tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K)),dim=0)
            lP -= .5*(tmp4+tmp1-2*tmp2+tmp3)
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            P /= torch.sum(P)
            tmp = P.view(1,1,N,N)
            tmp = F.pad(tmp,(K-1,K-1,K-1,K-1),'constant',0).to(device)
            tmp = torch.squeeze(cum_sum(tmp,K))
            tmp[:,:K-1] += tmp[:,N:]
            tmp[:K-1,:] += tmp[N:,:]
            sumP += tmp[:N,:N]
            tmpP = torch.unsqueeze(torch.unsqueeze(F.pad(P,(K-1,K-1,K-1,K-1),'constant',0),0),0)
            #update mean and variance
            for i in range(numDim):
                yctmp = yc[i,:,:].view(1,1,K,K)
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp))#.to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy[i,:,:] += tmp[:N,:N]
                
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp**2))#.to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy2[i,:,:] += tmp[:N,:N]
        torch.cuda.empty_cache()
        #M STEP
        p = sumP/torch.sum(sumP)
        for i in range(numDim):
            e[0,i,:,:] = sumPy[i,:,:]/sumP
            ev[0,i,:,:] = sumPy2[i,:,:]/sumP - 2*e[0,i,:,:]*sumPy[i,:,:]/sumP + e[0,i,:,:]**2
        ev = torch.clamp(ev,min=MINV)
        etemp = F.interpolate(e,[NFIN,NFIN])
        etr[nit+1,:,:,:] = etemp

        rows,cols = 1,3
        fig=plt.figure(figsize=(cols*5,rows*5))
        fig.add_subplot(rows, cols, 1)
        plt.axis('off')
        td = to_disp(etemp[:,:3,:,:])
        plt.imshow(td)
        plt.title(str(N)+'x'+str(N)+' epitome')
        fig.add_subplot(rows, cols, 2)
        plt.axis('off')
        plt.imshow(p,cmap='hot',interpolation='nearest')
        plt.title('mixing proportions')
        fig.add_subplot(rows, cols, 3)
        plt.axis('off')
        tmp = np.sum(np.squeeze(ev.cpu().numpy()),axis=0)
        plt.imshow(tmp,cmap='hot',interpolation='nearest')
        curr_var = np.max(tmp)
        plt.title('variances, max='+str(max(tmp.flatten())))
        plt.show()
        plt.close()   
    return e,ev,p,etr

# %%
# %%time
p = pd.read_csv("big_lc_paths.csv", header=None)
paths = p[0].tolist()
palette = np.array([[0,0,0],[0,153,51],[0,102,255],[153,102,51],[255,153,0],[255,255,0],[204,102,153]])

tile = 0
naip_tile = rasterio.open("/mnt/blobfuse/esri-naip/"+paths[tile][:-7]+".mrf",'r')
naip = naip_tile.read().astype(float)/255.
naip_tile.close()

lc_tile = rasterio.open('/mnt/blobfuse/resampled-lc/'+paths[tile],'r')
lc = np.squeeze(lc_tile.read())
lc_tile.close()
print(np.unique(lc))
#lc[lc==1]=10
#lc[lc==2]=1
#lc[lc==10]=2
#lc[lc==4]=0
#lc[lc==15]=4
fig=plt.figure(figsize=(15,10))
fig.add_subplot(1,2,1)
plt.axis('off')
plt.imshow(np.rollaxis(naip,0,3)[:,:,:3])
fig.add_subplot(1,2,2)
plt.axis('off')
plt.imshow(lc)
plt.show()
plt.close()

trIM = np.zeros((10,naip.shape[1],naip.shape[2]),dtype=float)
trIM[:4,:,:] = naip
for i in range(6):
    trIM[4+i,:,:] = (lc==(i+1))
trIM = np.expand_dims(trIM,axis=0)
trIMtorch = torch.from_numpy(trIM).float().to(device)
    
tsIMtorch = trIMtorch
print(trIMtorch.shape)
# Out:
# [ 1  2  3  4  5  6 15]
# torch.Size([1, 10, 7662, 6185])
# CPU times: user 7.8 s, sys: 2.78 s, total: 10.6 s
# Wall time: 10.4 s

# %%
# %%time
#sc will be changed to a single number
#instead repeatedly call the method to create epitomes at different scales
#no longer accepts initializations of e or ev
#removed dependency on etri. removed lptr; not implemented
#e, ev, p, etr = epitome(trIMtorch,8,128,3000,30,[.5]) #scale could be [.125 .25 .5 .75]
cProfile.run('e,ev,p,etr=epitome(trIMtorch,8,128,30000,30,.5)',sort='cumtime')
torch.cuda.empty_cache()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides
#          52519621 function calls (52414411 primitive calls) in 1488.067 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000 1488.067 1488.067 {built-in method builtins.exec}
#         1    0.002    0.002 1488.067 1488.067 <string>:1(<module>)
#         1  822.493  822.493 1488.065 1488.065 <ipython-input-13-fd41c25b2264>:20(epitome)
#   4950000  290.197    0.000  290.197    0.000 {built-in method conv2d}
#    675000   70.871    0.000  158.414    0.000 <ipython-input-13-fd41c25b2264>:3(cum_sum)
#   1125000    4.147    0.000  114.749    0.000 functional.py:2112(pad)
#   1125000   11.194    0.000  109.867    0.000 {built-in method apply}
#   1125000   25.552    0.000   98.673    0.000 padding.py:12(forward)
#   5625001   43.973    0.000   43.973    0.000 {built-in method squeeze}
#    225000   30.063    0.000   30.063    0.000 {built-in method max}
#    675031   26.041    0.000   26.041    0.000 {built-in method sum}
#    225000   23.465    0.000   23.465    0.000 {built-in method flip}
#   1350000   21.311    0.000   21.311    0.000 {built-in method cumsum}
#   1125000   18.146    0.000   18.146    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#   3150000   17.730    0.000   17.730    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#   1125000   15.415    0.000   15.415    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#   2475000   15.240    0.000   15.240    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#   1125000   13.795    0.000   13.795    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#   1575000   11.345    0.000   11.345    0.000 {built-in method unsqueeze}
#        30    0.000    0.000    6.953    0.232 pyplot.py:236(show)
#        30    0.001    0.000    6.953    0.232 backend_inline.py:18(show)
#        30    0.001    0.000    6.918    0.231 display.py:129(display)
#        30    0.001    0.000    6.874    0.229 formatters.py:89(format)
#       360    0.001    0.000    6.872    0.019 formatters.py:220(catch_format_error)
#       270    0.000    0.000    6.864    0.025 <decorator-gen-9>:1(__call__)
#       270    0.001    0.000    6.863    0.025 formatters.py:331(__call__)
#        30    0.000    0.000    6.857    0.229 pylabtools.py:238(<lambda>)
#        30    0.001    0.000    6.856    0.229 pylabtools.py:91(print_figure)
#        30    0.009    0.000    6.855    0.229 backend_bases.py:2107(print_figure)
#    225030    4.335    0.000    4.335    0.000 {built-in method log}
#        60    0.001    0.000    3.740    0.062 backend_agg.py:512(print_png)
#    225000    3.534    0.000    3.534    0.000 {built-in method exp}
#   7650002    3.204    0.000    3.204    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        30    0.001    0.000    2.868    0.096 figure.py:2179(get_tightbbox)
#        90    0.003    0.000    2.862    0.032 _base.py:4137(get_tightbbox)
#       180    0.006    0.000    2.796    0.016 axis.py:1137(get_tightbbox)
#        60    2.753    0.046    2.753    0.046 {built-in method matplotlib._png.write_png}
#   1125000    1.805    0.000    2.488    0.000 padding.py:23(<listcomp>)
#      2160    0.047    0.000    2.351    0.001 axis.py:74(__init__)
#       360    0.017    0.000    2.124    0.006 axis.py:1020(_update_ticks)
#      3600    0.007    0.000    1.952    0.001 axis.py:967(iter_ticks)
#        90    0.001    0.000    1.530    0.017 figure.py:1145(add_subplot)
#        90    0.001    0.000    1.523    0.017 _subplots.py:25(__init__)
#        90    0.005    0.000    1.499    0.017 _base.py:423(__init__)
#       360    0.006    0.000    1.425    0.004 axis.py:1393(get_major_ticks)
#      1080    0.005    0.000    1.335    0.001 axis.py:1787(_get_tick)
#      6480    0.135    0.000    1.292    0.000 lines.py:290(__init__)
#   1125000    1.231    0.000    1.231    0.000 padding.py:18(<listcomp>)
#    225009    1.205    0.000    1.205    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#        90    0.006    0.000    1.198    0.013 _base.py:998(cla)
#      1080    0.005    0.000    1.027    0.001 axis.py:2159(_get_tick)
#        60    0.001    0.000    0.984    0.016 backend_agg.py:421(draw)
#   1020/60    0.005    0.000    0.944    0.016 artist.py:47(draw_wrapper)
#        60    0.001    0.000    0.944    0.016 figure.py:1438(draw)
#    240/60    0.002    0.000    0.924    0.015 image.py:123(_draw_list_compositing_images)
#       180    0.003    0.000    0.923    0.005 _base.py:2528(draw)
#   540/360    0.001    0.000    0.831    0.002 axis.py:670(__get__)
#   2250000    0.683    0.000    0.683    0.000 {built-in method builtins.sum}
#       180    0.001    0.000    0.653    0.004 axis.py:927(set_clip_path)
#       180    0.003    0.000    0.611    0.003 image.py:569(draw)
#   4563156    0.566    0.000    0.566    0.000 {built-in method builtins.len}
#       180    0.002    0.000    0.564    0.003 image.py:832(make_image)
#       180    0.037    0.000    0.558    0.003 image.py:275(_make_image)
#      3420    0.029    0.000    0.551    0.000 text.py:887(get_window_extent)
#       360    0.007    0.000    0.479    0.001 axis.py:1119(_get_tick_bboxes)
#   1125000    0.472    0.000    0.472    0.000 padding.py:24(<listcomp>)
#   1127220    0.458    0.000    0.461    0.000 {built-in method builtins.all}
#    109420    0.274    0.000    0.454    0.000 {built-in method numpy.core.multiarray.array}
#      1080    0.008    0.000    0.432    0.000 axis.py:479(_get_tick2line)
#       360    0.002    0.000    0.422    0.001 ticker.py:1943(__call__)
#      2880    0.063    0.000    0.421    0.000 text.py:276(_get_layout)
#       360    0.002    0.000    0.419    0.001 ticker.py:1947(tick_values)
#       360    0.021    0.000    0.411    0.001 ticker.py:1896(_raw_ticks)
#      3061    0.005    0.000    0.401    0.000 fromnumeric.py:49(_wrapfunc)
#        90    0.002    0.000    0.397    0.004 axis.py:1896(_update_label_position)
#        90    0.002    0.000    0.393    0.004 axis.py:2265(_update_label_position)
#       481    0.001    0.000    0.383    0.001 fromnumeric.py:1764(clip)
#       541    0.003    0.000    0.377    0.001 fromnumeric.py:36(_wrapit)
#       720    0.004    0.000    0.377    0.001 axis.py:844(set_tick_params)
#       180    0.001    0.000    0.368    0.002 _base.py:2678(grid)
#       360    0.002    0.000    0.367    0.001 axis.py:1423(grid)
#   1125068    0.363    0.000    0.363    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#        90    0.001    0.000    0.360    0.004 axis.py:1877(_get_tick_boxes_siblings)
#        90    0.001    0.000    0.356    0.004 axis.py:2246(_get_tick_boxes_siblings)
#     10260    0.015    0.000    0.352    0.000 markers.py:167(__init__)
#     11700    0.256    0.000    0.333    0.000 artist.py:854(update)
#     41492    0.031    0.000    0.328    0.000 numeric.py:433(asarray)
#     10260    0.034    0.000    0.318    0.000 markers.py:251(set_marker)
#     48451    0.314    0.000    0.314    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     38640    0.081    0.000    0.290    0.000 fromnumeric.py:64(_wrapreduction)
#       540    0.009    0.000    0.277    0.001 text.py:691(draw)
#      1080    0.009    0.000    0.276    0.000 axis.py:494(_get_gridline)
#      1080    0.009    0.000    0.275    0.000 axis.py:618(_get_gridline)
#       300    0.222    0.001    0.237    0.001 {built-in method matplotlib._image.resample}
#     20520    0.028    0.000    0.236    0.000 markers.py:200(_recache)
#      1260    0.007    0.000    0.236    0.000 axis.py:1357(_copy_tick_props)
# 270660/224070    0.150    0.000    0.235    0.000 artist.py:230(stale)
#     14460    0.095    0.000    0.232    0.000 artist.py:87(__init__)
#      1080    0.008    0.000    0.230    0.000 axis.py:589(_get_tick1line)
#      1080    0.008    0.000    0.228    0.000 axis.py:468(_get_tick1line)
#      4950    0.029    0.000    0.225    0.000 text.py:129(__init__)
#      7470    0.048    0.000    0.220    0.000 font_manager.py:665(__init__)
#      1080    0.009    0.000    0.213    0.000 axis.py:435(_get_text1)
#      2160    0.004    0.000    0.208    0.000 lines.py:945(get_path)
#      1080    0.008    0.000    0.207    0.000 axis.py:604(_get_tick2line)
#      1440    0.004    0.000    0.206    0.000 axis.py:770(_set_scale)
#      1560    0.008    0.000    0.206    0.000 backend_agg.py:220(get_text_width_height_descent)
#      2160    0.044    0.000    0.204    0.000 lines.py:649(recache)
#       481    0.201    0.000    0.201    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      1440    0.008    0.000    0.199    0.000 scale.py:68(set_default_locators_and_formatters)
#      1740    0.195    0.000    0.195    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#      1350    0.011    0.000    0.186    0.000 artist.py:650(set_clip_path)
#     14670    0.019    0.000    0.185    0.000 fromnumeric.py:1933(any)
#      5310    0.015    0.000    0.184    0.000 transforms.py:1429(transform)
#        92    0.182    0.002    0.182    0.002 {method 'cpu' of 'torch._C._TensorBase' objects}
#       180    0.003    0.000    0.180    0.001 axis.py:2500(get_tick_space)
#       180    0.003    0.000    0.180    0.001 axis.py:2121(get_tick_space)
#      1080    0.006    0.000    0.179    0.000 axis.py:801(cla)
#      4680    0.013    0.000    0.178    0.000 transforms.py:1522(transform_point)
#        32    0.000    0.000    0.177    0.006 tensor.py:395(__array__)
#        90    0.001    0.000    0.174    0.002 _base.py:615(_init_axis)
#      3780    0.019    0.000    0.164    0.000 lines.py:1233(update_from)
#       630    0.005    0.000    0.156    0.000 transforms.py:740(union)
#      2040    0.005    0.000    0.156    0.000 patches.py:194(get_transform)
#    248550    0.153    0.000    0.153    0.000 __init__.py:931(__getitem__)
#      1440    0.003    0.000    0.149    0.000 ticker.py:2484(__init__)
#       540    0.001    0.000    0.147    0.000 axis.py:231(set_clip_path)
#      1440    0.005    0.000    0.145    0.000 ticker.py:1794(__init__)
#    192790    0.065    0.000    0.142    0.000 {built-in method builtins.isinstance}
#      5310    0.008    0.000    0.140    0.000 transforms.py:2481(transform_affine)
#      2880    0.011    0.000    0.140    0.000 ticker.py:1870(set_params)
#        10    0.138    0.014    0.138    0.014 {method 'std' of 'torch._C._TensorBase' objects}
#      1500    0.001    0.000    0.135    0.000 patches.py:736(get_patch_transform)
#      7740    0.023    0.000    0.134    0.000 transforms.py:2076(scale)
#      1500    0.011    0.000    0.134    0.000 patches.py:707(_update_patch_transform)
#      6480    0.012    0.000    0.130    0.000 lines.py:1165(set_markerfacecolor)
# 9840/5670    0.035    0.000    0.127    0.000 transforms.py:2505(get_affine)
#      1080    0.008    0.000    0.127    0.000 axis.py:559(_get_text1)
#     14460    0.018    0.000    0.123    0.000 transforms.py:131(invalidate)
#       180    0.011    0.000    0.113    0.001 cm.py:208(to_rgba)
#     10740    0.038    0.000    0.111    0.000 transforms.py:771(__init__)
#       180    0.003    0.000    0.110    0.001 backend_agg.py:190(draw_text)
#      1080    0.007    0.000    0.110    0.000 axis.py:574(_get_text2)
#       180    0.002    0.000    0.107    0.001 axis.py:705(__init__)
# 39210/14460    0.065    0.000    0.105    0.000 transforms.py:142(_invalidate_internal)
#      1080    0.006    0.000    0.104    0.000 axis.py:452(_get_text2)
#     14460    0.010    0.000    0.103    0.000 <string>:12(__new__)
#     14760    0.093    0.000    0.093    0.000 {built-in method __new__ of type object at 0x55ba72214560}
#     49290    0.039    0.000    0.091    0.000 artist.py:288(pchanged)
#        90    0.001    0.000    0.090    0.001 pyplot.py:3184(imshow)
#     22860    0.033    0.000    0.088    0.000 transforms.py:1919(__init__)
#        90    0.001    0.000    0.087    0.001 __init__.py:1774(inner)
#        90    0.001    0.000    0.087    0.001 _base.py:978(_gen_axes_spines)
#       120    0.019    0.000    0.086    0.001 colors.py:457(__call__)
#       360    0.002    0.000    0.086    0.000 spines.py:485(linear_spine)
#        90    0.002    0.000    0.085    0.001 _axes.py:5348(imshow)
#       450    0.010    0.000    0.084    0.000 transforms.py:753(intersection)
#         1    0.032    0.032    0.084    0.084 image.py:299(extract_patches_2d)
#      5100    0.008    0.000    0.084    0.000 transforms.py:350(xmin)
#     30240    0.030    0.000    0.079    0.000 artist.py:66(_stale_axes_callback)
#     32674    0.049    0.000    0.077    0.000 abc.py:178(__instancecheck__)
#      2790    0.008    0.000    0.075    0.000 path.py:101(__init__)
#       450    0.002    0.000    0.075    0.000 patches.py:570(get_window_extent)
#     43890    0.033    0.000    0.072    0.000 transforms.py:1774(__init__)
#     11460    0.010    0.000    0.070    0.000 fromnumeric.py:2337(amin)
#       360    0.005    0.000    0.069    0.000 spines.py:42(__init__)
#      2880    0.019    0.000    0.069    0.000 ticker.py:1862(_staircase)
#      9300    0.009    0.000    0.069    0.000 transforms.py:1285(__add__)
#      6480    0.009    0.000    0.067    0.000 lines.py:1177(set_markerfacecoloralt)
#       480    0.006    0.000    0.065    0.000 patches.py:49(__init__)
#       360    0.004    0.000    0.065    0.000 ticker.py:655(set_locs)
#      2520    0.007    0.000    0.065    0.000 text.py:263(update_from)
#      1740    0.005    0.000    0.065    0.000 backend_agg.py:271(_get_agg_font)
#       630    0.005    0.000    0.065    0.000 path.py:521(get_extents)
#     10200    0.016    0.000    0.065    0.000 transforms.py:2584(composite_transform_factory)
#      1500    0.004    0.000    0.065    0.000 transforms.py:2050(rotate_deg_around)
#     11580    0.010    0.000    0.063    0.000 fromnumeric.py:2227(amax)
# 4410/4140    0.012    0.000    0.063    0.000 transforms.py:1072(get_points)
#     12240    0.018    0.000    0.062    0.000 font_manager.py:989(_normalize_font_family)
#     24300    0.061    0.000    0.061    0.000 {built-in method numpy.core.multiarray.dot}
#      2700    0.032    0.000    0.061    0.000 transforms.py:711(translated)
#     11700    0.010    0.000    0.059    0.000 artist.py:887(<listcomp>)
#       360    0.000    0.000    0.059    0.000 spines.py:164(register_axis)
#     67950    0.059    0.000    0.059    0.000 transforms.py:88(__init__)
#      2280    0.014    0.000    0.057    0.000 transforms.py:2030(rotate_deg)
#     14430    0.019    0.000    0.056    0.000 artist.py:612(set_figure)
#       360    0.000    0.000    0.056    0.000 spines.py:176(cla)
#     53400    0.038    0.000    0.055    0.000 six.py:586(iteritems)
#      2790    0.022    0.000    0.055    0.000 path.py:198(_update_values)
#      3330    0.009    0.000    0.055    0.000 transforms.py:833(from_extents)
#       361    0.000    0.000    0.055    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       361    0.000    0.000    0.054    0.000 _methods.py:34(_sum)
#      6480    0.021    0.000    0.054    0.000 lines.py:1052(set_linestyle)
#      1440    0.015    0.000    0.053    0.000 ticker.py:1843(_validate_steps)
#      1710    0.006    0.000    0.053    0.000 markers.py:702(_set_tickleft)
#      2880    0.010    0.000    0.051    0.000 text.py:854(get_prop_tup)
#         1    0.000    0.000    0.051    0.051 validation.py:310(check_array)
#      1740    0.002    0.000    0.051    0.000 font_manager.py:1473(findfont)
#         1    0.000    0.000    0.051    0.051 validation.py:33(_assert_all_finite)
#      1710    0.006    0.000    0.050    0.000 markers.py:722(_set_tickdown)
#      2880    0.004    0.000    0.050    0.000 shape_base.py:236(hstack)
#      6840    0.015    0.000    0.049    0.000 artist.py:858(_update_property)
#     12630    0.013    0.000    0.049    0.000 artist.py:303(set_transform)
#      1740    0.004    0.000    0.048    0.000 font_manager.py:1255(findfont)
#     10800    0.009    0.000    0.048    0.000 axis.py:331(_set_artist_props)
#      6300    0.029    0.000    0.048    0.000 artist.py:963(update_from)
#       360    0.002    0.000    0.047    0.000 axis.py:1827(_get_pixel_distance_along_axis)
#      9360    0.009    0.000    0.047    0.000 __init__.py:584(is_numlike)
#     10200    0.021    0.000    0.045    0.000 transforms.py:2403(__init__)
#     83673    0.041    0.000    0.045    0.000 {built-in method builtins.getattr}
#     24120    0.044    0.000    0.044    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.044    0.001 display.py:79(publish_display_data)
#      1740    0.003    0.000    0.044    0.000 font_manager.py:1019(get)
#        30    0.001    0.000    0.043    0.001 zmqshell.py:94(publish)
#      2280    0.020    0.000    0.043    0.000 transforms.py:2014(rotate)
#      4020    0.009    0.000    0.043    0.000 colors.py:142(to_rgba)
#      1710    0.005    0.000    0.042    0.000 markers.py:716(_set_tickup)
#       120    0.010    0.000    0.042    0.000 colors.py:927(__call__)
#      1710    0.005    0.000    0.042    0.000 markers.py:708(_set_tickright)
#       840    0.007    0.000    0.041    0.000 core.py:2772(__new__)
#       120    0.001    0.000    0.040    0.000 backend_agg.py:442(get_renderer)
#       180    0.022    0.000    0.039    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       720    0.002    0.000    0.039    0.000 text.py:225(_get_xy_display)
#      6300    0.012    0.000    0.039    0.000 text.py:840(get_unitless_position)
#    270840    0.039    0.000    0.039    0.000 artist.py:715(get_animated)
#     20610    0.034    0.000    0.038    0.000 transforms.py:169(set_children)
#      2700    0.004    0.000    0.038    0.000 font_manager.py:924(copy)
#      8100    0.024    0.000    0.038    0.000 font_manager.py:711(__hash__)
#       270    0.004    0.000    0.038    0.000 _base.py:1511(apply_aspect)
#      7680    0.005    0.000    0.038    0.000 transforms.py:1795(transform)
#      2880    0.005    0.000    0.037    0.000 shape_base.py:283(<listcomp>)
#      2820    0.005    0.000    0.037    0.000 transforms.py:2362(get_matrix)
#      5130    0.015    0.000    0.037    0.000 text.py:178(update)
# 14220/10620    0.008    0.000    0.037    0.000 transforms.py:2434(_invalidate_internal)
#        60    0.031    0.001    0.037    0.001 backend_agg.py:91(__init__)
# 9000/8640    0.020    0.000    0.037    0.000 spines.py:436(get_spine_transform)
#       120    0.036    0.000    0.036    0.000 {method 'take' of 'numpy.ndarray' objects}
#      3540    0.007    0.000    0.036    0.000 transforms.py:2062(translate)
# 20100/13740    0.009    0.000    0.036    0.000 {built-in method builtins.hash}
#      1470    0.003    0.000    0.036    0.000 patches.py:301(_set_facecolor)
#       630    0.003    0.000    0.035    0.000 transforms.py:747(<listcomp>)
#       600    0.002    0.000    0.034    0.000 core.py:6350(array)
#      7290    0.007    0.000    0.034    0.000 __init__.py:2042(_to_unmasked_float_array)
#        60    0.000    0.000    0.034    0.001 pyplot.py:638(close)
#      5100    0.007    0.000    0.033    0.000 transforms.py:364(xmax)
#        30    0.000    0.000    0.033    0.001 _pylab_helpers.py:71(destroy_all)
#      7860    0.013    0.000    0.033    0.000 transforms.py:1875(transform_affine)
#      6480    0.007    0.000    0.033    0.000 lines.py:715(set_transform)
#      8640    0.013    0.000    0.033    0.000 shape_base.py:11(atleast_1d)
#     32100    0.022    0.000    0.033    0.000 six.py:583(itervalues)
#       360    0.002    0.000    0.033    0.000 axis.py:2202(_get_pixel_distance_along_axis)
#      2160    0.010    0.000    0.033    0.000 stride_tricks.py:198(broadcast_arrays)
#      1080    0.002    0.000    0.033    0.000 axis.py:415(_get_text1_transform)
#       360    0.010    0.000    0.032    0.000 ticker.py:736(_set_format)
#      1650    0.003    0.000    0.032    0.000 transforms.py:823(from_bounds)
#       360    0.005    0.000    0.032    0.000 axis.py:974(<listcomp>)
#      1080    0.002    0.000    0.032    0.000 axis.py:538(_get_text1_transform)
#      5190    0.006    0.000    0.032    0.000 transforms.py:371(ymax)
#      2400    0.002    0.000    0.031    0.000 {method 'min' of 'numpy.ndarray' objects}
#      1530    0.009    0.000    0.031    0.000 core.py:2928(__array_finalize__)
#        30    0.031    0.001    0.031    0.001 {built-in method gc.collect}
#     12960    0.021    0.000    0.031    0.000 lines.py:1020(_split_drawstyle_linestyle)
#      1080    0.006    0.000    0.031    0.000 _base.py:711(get_xaxis_text1_transform)
#      5100    0.006    0.000    0.031    0.000 transforms.py:357(ymin)
#      1080    0.006    0.000    0.030    0.000 _base.py:791(get_yaxis_text1_transform)
#      6480    0.010    0.000    0.030    0.000 lines.py:632(set_data)
#      2340    0.013    0.000    0.029    0.000 shape_base.py:555(column_stack)
#      4500    0.011    0.000    0.029    0.000 transforms.py:2768(__init__)
#     12630    0.006    0.000    0.029    0.000 {method 'get' of 'dict' objects}
#      2400    0.002    0.000    0.029    0.000 _methods.py:30(_amin)
#       630    0.002    0.000    0.028    0.000 transforms.py:748(<listcomp>)
#     46806    0.028    0.000    0.028    0.000 _weakrefset.py:70(__contains__)
#     12000    0.008    0.000    0.028    0.000 artist.py:184(convert_xunits)
#     18302    0.011    0.000    0.028    0.000 numeric.py:504(asanyarray)
#      3240    0.004    0.000    0.028    0.000 ticker.py:566(__call__)
# 9900/5400    0.010    0.000    0.027    0.000 _base.py:686(get_xaxis_transform)
#      4770    0.005    0.000    0.027    0.000 font_manager.py:804(set_family)
#        60    0.001    0.000    0.027    0.000 figure.py:470(_set_dpi)
#      2820    0.003    0.000    0.027    0.000 {method 'all' of 'numpy.ndarray' objects}
#      4860    0.025    0.000    0.027    0.000 font_manager.py:839(set_weight)
#       630    0.002    0.000    0.027    0.000 transforms.py:749(<listcomp>)
#        90    0.001    0.000    0.026    0.000 image.py:850(set_extent)
#       630    0.002    0.000    0.026    0.000 transforms.py:750(<listcomp>)
#      1080    0.001    0.000    0.026    0.000 axis.py:418(_get_text2_transform)
#      1080    0.001    0.000    0.026    0.000 axis.py:541(_get_text2_transform)
#       180    0.026    0.000    0.026    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#  1440/720    0.003    0.000    0.025    0.000 transforms.py:2513(inverted)
#      2700    0.006    0.000    0.025    0.000 axis.py:510(update_position)
# 9900/5400    0.009    0.000    0.025    0.000 _base.py:766(get_yaxis_transform)
#      2700    0.006    0.000    0.025    0.000 axis.py:633(update_position)
#        90    0.001    0.000    0.025    0.000 axis.py:1939(_update_offset_text_position)
#      1080    0.004    0.000    0.024    0.000 _base.py:739(get_xaxis_text2_transform)
#      1440    0.003    0.000    0.024    0.000 transforms.py:807(unit)
#      1080    0.005    0.000    0.024    0.000 _base.py:818(get_yaxis_text2_transform)
#       360    0.002    0.000    0.024    0.000 colors.py:896(process_value)
#       990    0.001    0.000    0.024    0.000 patches.py:308(set_facecolor)
#       630    0.006    0.000    0.024    0.000 {built-in method matplotlib._path.get_path_extents}
#      2820    0.002    0.000    0.024    0.000 _methods.py:45(_all)
#       360    0.009    0.000    0.023    0.000 ticker.py:668(_compute_offset)
#       360    0.001    0.000    0.023    0.000 transforms.py:2241(frozen)
#        30    0.001    0.000    0.023    0.001 tight_bbox.py:13(adjust_bbox)
#   900/450    0.003    0.000    0.023    0.000 transforms.py:2426(frozen)
#      4860    0.017    0.000    0.023    0.000 font_manager.py:875(set_size)
#       180    0.003    0.000    0.022    0.000 _base.py:3043(set_xlim)
#      6120    0.022    0.000    0.022    0.000 {built-in method numpy.core.multiarray.concatenate}
#        30    0.001    0.000    0.022    0.001 pyplot.py:431(figure)
#        60    0.000    0.000    0.022    0.000 transforms.py:2005(clear)
#       810    0.001    0.000    0.022    0.000 transforms.py:1882(transform_point)
#        90    0.001    0.000    0.022    0.000 _subplots.py:131(update_params)
#    105270    0.021    0.000    0.021    0.000 {built-in method builtins.iter}
#        90    0.001    0.000    0.021    0.000 gridspec.py:456(get_position)
#     12780    0.011    0.000    0.021    0.000 text.py:1159(set_text)
#      1230    0.006    0.000    0.021    0.000 transforms.py:436(bounds)
#       900    0.002    0.000    0.021    0.000 shape_base.py:182(vstack)
#       900    0.006    0.000    0.020    0.000 transforms.py:1790(__eq__)
#      2880    0.003    0.000    0.020    0.000 axis.py:1515(convert_units)
#      2850    0.019    0.000    0.019    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     14370    0.010    0.000    0.019    0.000 lines.py:62(_scale_dashes)
#     10260    0.013    0.000    0.019    0.000 markers.py:226(set_fillstyle)
#     16350    0.009    0.000    0.019    0.000 figure.py:58(_stale_figure_callback)
#      3240    0.003    0.000    0.019    0.000 axis.py:311(set_label1)
#        30    0.000    0.000    0.019    0.001 backend_bases.py:153(new_figure_manager)
#     12000    0.006    0.000    0.019    0.000 artist.py:193(convert_yunits)
#        90    0.002    0.000    0.019    0.000 image.py:629(set_data)
#      4680    0.006    0.000    0.019    0.000 artist.py:924(set_zorder)
#       900    0.011    0.000    0.019    0.000 cycler.py:349(by_key)
#      3300    0.002    0.000    0.018    0.000 {method 'max' of 'numpy.ndarray' objects}
#      3240    0.003    0.000    0.018    0.000 axis.py:322(set_label2)
#      6480    0.010    0.000    0.018    0.000 lines.py:1005(set_linewidth)
#        30    0.001    0.000    0.018    0.001 session.py:657(send)
#       510    0.000    0.000    0.018    0.000 transforms.py:1778(__array__)
#       480    0.001    0.000    0.018    0.000 patches.py:417(set_fill)
# 5640/5460    0.004    0.000    0.017    0.000 transforms.py:2687(get_matrix)
#      2880    0.003    0.000    0.017    0.000 units.py:118(is_numlike)
#      2040    0.001    0.000    0.017    0.000 fromnumeric.py:2803(round_)
#       120    0.001    0.000    0.017    0.000 patches.py:664(__init__)
#    115890    0.017    0.000    0.017    0.000 artist.py:202(axes)
#     11702    0.017    0.000    0.017    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        60    0.002    0.000    0.017    0.000 patches.py:507(draw)
#        90    0.000    0.000    0.017    0.000 pyplot.py:1385(title)
#      6480    0.010    0.000    0.016    0.000 lines.py:1376(set_dash_capstyle)
#       180    0.000    0.000    0.016    0.000 transforms.py:286(__array__)
#      1530    0.009    0.000    0.016    0.000 core.py:2902(_update_from)
#        90    0.001    0.000    0.016    0.000 _axes.py:141(set_title)
#      2040    0.002    0.000    0.016    0.000 fromnumeric.py:2734(around)
#        30    0.000    0.000    0.016    0.001 session.py:598(serialize)
#      3300    0.002    0.000    0.016    0.000 _methods.py:26(_amax)
#       240    0.002    0.000    0.016    0.000 core.py:5551(min)
#      9450    0.009    0.000    0.015    0.000 lines.py:1200(set_xdata)
#      2160    0.002    0.000    0.015    0.000 transforms.py:1902(inverted)
#      2610    0.004    0.000    0.015    0.000 transforms.py:1847(frozen)
#      8670    0.015    0.000    0.015    0.000 {built-in method matplotlib._path.affine_transform}
#      1740    0.001    0.000    0.015    0.000 font_manager.py:721(__eq__)
#    106320    0.015    0.000    0.015    0.000 {method 'items' of 'dict' objects}
#        30    0.003    0.000    0.015    0.001 figure.py:286(__init__)
#     16770    0.011    0.000    0.015    0.000 __init__.py:518(iterable)
#       900    0.002    0.000    0.015    0.000 shape_base.py:234(<listcomp>)
#        30    0.000    0.000    0.015    0.000 tight_bbox.py:40(restore_bbox)
#      1440    0.013    0.000    0.015    0.000 function_base.py:1079(diff)
#      2700    0.002    0.000    0.014    0.000 transforms.py:2285(get_affine)
#      2700    0.014    0.000    0.014    0.000 {built-in method numpy.core.multiarray.zeros}
#      5310    0.005    0.000    0.014    0.000 transforms.py:2485(transform_non_affine)
#        90    0.003    0.000    0.014    0.000 gridspec.py:84(get_grid_positions)
#      1740    0.004    0.000    0.014    0.000 font_manager.py:1015(make_rcparams_key)
#       180    0.001    0.000    0.014    0.000 _base.py:2848(tick_params)
#      3240    0.014    0.000    0.014    0.000 ticker.py:771(pprint_val)
#       180    0.002    0.000    0.014    0.000 _base.py:3363(set_ylim)
#      1440    0.007    0.000    0.014    0.000 ticker.py:501(__init__)
#       180    0.002    0.000    0.014    0.000 _base.py:1166(_set_title_offset_trans)
#      8760    0.014    0.000    0.014    0.000 {built-in method builtins.max}
#        90    0.000    0.000    0.013    0.000 _base.py:962(_gen_axes_patch)
#       300    0.000    0.000    0.013    0.000 transforms.py:1423(__array__)
#      4020    0.004    0.000    0.013    0.000 colors.py:107(_is_nth_color)
#      2701    0.006    0.000    0.013    0.000 shape_base.py:63(atleast_2d)
# 9360/8640    0.004    0.000    0.013    0.000 spines.py:158(_ensure_position_is_set)
#      4770    0.011    0.000    0.013    0.000 font_manager.py:857(set_stretch)
#      6480    0.007    0.000    0.013    0.000 lines.py:1153(set_markeredgewidth)
#        30    0.000    0.000    0.013    0.000 zmqshell.py:77(_flush_streams)
#      2160    0.012    0.000    0.013    0.000 stride_tricks.py:179(_broadcast_shape)
#     12240    0.013    0.000    0.013    0.000 font_manager.py:993(<listcomp>)
#      1080    0.002    0.000    0.013    0.000 transforms.py:2379(blended_transform_factory)
#        60    0.001    0.000    0.012    0.000 iostream.py:327(flush)
#     15702    0.012    0.000    0.012    0.000 {built-in method builtins.hasattr}
#      9450    0.007    0.000    0.012    0.000 lines.py:1210(set_ydata)
#        90    0.000    0.000    0.012    0.000 cm.py:356(autoscale_None)
#      1260    0.007    0.000    0.012    0.000 axis.py:338(_apply_params)
# 1650/1170    0.004    0.000    0.012    0.000 {method 'view' of 'numpy.generic' objects}
#       270    0.008    0.000    0.012    0.000 linalg.py:468(inv)
#       240    0.001    0.000    0.012    0.000 core.py:5672(max)
#       900    0.002    0.000    0.012    0.000 fromnumeric.py:2016(all)
#      6480    0.007    0.000    0.011    0.000 lines.py:1337(set_dash_joinstyle)
#        90    0.001    0.000    0.011    0.000 axis.py:1794(_get_label)
#       210    0.001    0.000    0.011    0.000 colors.py:987(autoscale_None)
#      6480    0.008    0.000    0.011    0.000 lines.py:1189(set_markersize)
#      6960    0.009    0.000    0.011    0.000 lines.py:34(_get_dash_pattern)
#       720    0.009    0.000    0.011    0.000 transforms.py:2909(nonsingular)
#      6480    0.005    0.000    0.011    0.000 lines.py:962(set_antialiased)
#        90    0.001    0.000    0.011    0.000 __init__.py:1363(safe_masked_invalid)
#      4950    0.005    0.000    0.011    0.000 text.py:1209(set_usetex)
#        90    0.001    0.000    0.011    0.000 _base.py:625(set_figure)
#      1080    0.003    0.000    0.011    0.000 axis.py:421(apply_tickdir)
#      1860    0.004    0.000    0.011    0.000 transforms.py:1039(__init__)
#       180    0.001    0.000    0.011    0.000 _base.py:846(_update_transScale)
#      6480    0.006    0.000    0.011    0.000 lines.py:984(set_drawstyle)
#      1080    0.003    0.000    0.011    0.000 axis.py:544(apply_tickdir)
#      6480    0.006    0.000    0.011    0.000 lines.py:1390(set_solid_capstyle)
#        90    0.001    0.000    0.011    0.000 axis.py:2186(_get_offset_text)
#      3420    0.005    0.000    0.011    0.000 ticker.py:557(fix_minus)
#      1740    0.005    0.000    0.010    0.000 font_manager.py:1017(<listcomp>)
#     64800    0.010    0.000    0.010    0.000 {method 'startswith' of 'str' objects}
#       120    0.000    0.000    0.010    0.000 session.py:102(<lambda>)
#       270    0.001    0.000    0.010    0.000 _base.py:903(_set_position)
# 14010/8100    0.009    0.000    0.010    0.000 transforms.py:2465(_get_is_affine)
#       180    0.000    0.000    0.010    0.000 transforms.py:1535(transform_path)
#       120    0.000    0.000    0.010    0.000 jsonapi.py:31(dumps)
#      4950    0.006    0.000    0.010    0.000 text.py:949(set_color)
#       900    0.003    0.000    0.010    0.000 transforms.py:2312(__init__)
#      1470    0.003    0.000    0.010    0.000 patches.py:273(_set_edgecolor)
#      1620    0.003    0.000    0.010    0.000 transforms.py:2667(__init__)
#        90    0.001    0.000    0.010    0.000 axis.py:2166(_get_label)
#       120    0.000    0.000    0.010    0.000 __init__.py:182(dumps)
#      6480    0.005    0.000    0.010    0.000 lines.py:1350(set_solid_joinstyle)
#       360    0.002    0.000    0.010    0.000 spines.py:392(set_position)
#    180/30    0.005    0.000    0.010    0.000 jsonutil.py:109(json_clean)
#      1440    0.004    0.000    0.009    0.000 axis.py:1588(set_major_locator)
#        10    0.009    0.001    0.009    0.001 {method 'mean' of 'torch._C._TensorBase' objects}
#      2250    0.002    0.000    0.009    0.000 artist.py:814(set_alpha)
#       120    0.000    0.000    0.009    0.000 encoder.py:181(encode)
#       780    0.009    0.000    0.009    0.000 __init__.py:1160(__setitem__)
#      1500    0.003    0.000    0.009    0.000 patches.py:726(_convert_units)
#      3780    0.003    0.000    0.009    0.000 re.py:160(match)
#       120    0.008    0.000    0.009    0.000 encoder.py:203(iterencode)
#       720    0.002    0.000    0.009    0.000 _base.py:3024(_validate_converted_limits)
#        60    0.007    0.000    0.009    0.000 image.py:169(_rgb_to_rgba)
#      3240    0.004    0.000    0.008    0.000 transforms.py:2782(get_matrix)
#        90    0.001    0.000    0.008    0.000 axis.py:1812(_get_offset_text)
#       630    0.001    0.000    0.008    0.000 transforms.py:282(frozen)
#     39121    0.008    0.000    0.008    0.000 {method 'append' of 'list' objects}
#        60    0.000    0.000    0.008    0.000 threading.py:531(wait)
#      6480    0.006    0.000    0.008    0.000 lines.py:619(axes)
#      6480    0.005    0.000    0.008    0.000 lines.py:1140(set_markeredgecolor)
#        56    0.000    0.000    0.008    0.000 threading.py:261(wait)
#       420    0.001    0.000    0.008    0.000 backend_bases.py:787(new_gc)
#       990    0.001    0.000    0.007    0.000 patches.py:288(set_edgecolor)
#      6480    0.003    0.000    0.007    0.000 lines.py:975(set_color)
#     29850    0.007    0.000    0.007    0.000 transforms.py:991(get_points)
#      1740    0.005    0.000    0.007    0.000 backend_agg.py:55(get_hinting_flag)
#       436    0.007    0.000    0.007    0.000 {method 'acquire' of '_thread.lock' objects}
#      2520    0.002    0.000    0.007    0.000 transforms.py:2233(_get_is_affine)
#       420    0.002    0.000    0.007    0.000 backend_bases.py:849(__init__)
#       180    0.001    0.000    0.007    0.000 _base.py:604(get_window_extent)
#      2010    0.001    0.000    0.007    0.000 transforms.py:2746(get_matrix)
#     17670    0.007    0.000    0.007    0.000 artist.py:210(axes)
#       960    0.007    0.000    0.007    0.000 {method 'round' of 'numpy.ndarray' objects}
#      3690    0.004    0.000    0.006    0.000 transforms.py:409(width)
#       180    0.003    0.000    0.006    0.000 transforms.py:564(anchored)
#      1080    0.003    0.000    0.006    0.000 axis.py:1529(set_units)
#       960    0.001    0.000    0.006    0.000 text.py:236(get_rotation)
#      1440    0.002    0.000    0.006    0.000 axis.py:1566(set_major_formatter)
#       300    0.002    0.000    0.006    0.000 __init__.py:333(connect)
#      4770    0.004    0.000    0.006    0.000 font_manager.py:817(set_style)
#      3098    0.002    0.000    0.006    0.000 <frozen importlib._bootstrap>:995(_handle_fromlist)
#        90    0.000    0.000    0.006    0.000 _base.py:2108(update_datalim)
#       180    0.000    0.000    0.006    0.000 transforms.py:1734(set)
#      6000    0.005    0.000    0.006    0.000 artist.py:317(get_transform)
#     38580    0.006    0.000    0.006    0.000 {method 'lower' of 'str' objects}
#       270    0.002    0.000    0.006    0.000 transforms.py:1009(set)
#      4860    0.003    0.000    0.006    0.000 font_manager.py:1102(get_default_size)
#      4950    0.003    0.000    0.006    0.000 text.py:240(set_rotation_mode)
#       360    0.001    0.000    0.006    0.000 fromnumeric.py:2159(ptp)
#       330    0.001    0.000    0.006    0.000 formatters.py:374(lookup)
#      1440    0.002    0.000    0.006    0.000 axis.py:1599(set_minor_locator)
#     11550    0.006    0.000    0.006    0.000 {method 'update' of 'dict' objects}
#        90    0.000    0.000    0.006    0.000 image.py:827(get_window_extent)
#       180    0.000    0.000    0.006    0.000 transforms.py:1546(transform_path_affine)
#       180    0.005    0.000    0.006    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     22650    0.006    0.000    0.006    0.000 transforms.py:1957(get_matrix)
#       180    0.001    0.000    0.006    0.000 _base.py:2130(_process_unit_info)
#       180    0.003    0.000    0.006    0.000 transforms.py:611(shrunk_to_aspect)
#      1440    0.005    0.000    0.006    0.000 axis.py:824(reset_ticks)
#       720    0.003    0.000    0.006    0.000 numeric.py:2491(seterr)
#      1440    0.002    0.000    0.006    0.000 axis.py:1577(set_minor_formatter)
#        90    0.001    0.000    0.006    0.000 _base.py:647(_set_lim_and_transforms)
#        30    0.000    0.000    0.006    0.000 <decorator-gen-10>:1(__call__)
#       180    0.000    0.000    0.005    0.000 transforms.py:1812(transform_path_affine)
#       960    0.005    0.000    0.005    0.000 text.py:56(get_rotation)
#        30    0.000    0.000    0.005    0.000 formatters.py:689(__call__)
#       960    0.002    0.000    0.005    0.000 text.py:1170(is_math_text)
#       180    0.000    0.000    0.005    0.000 axis.py:1456(update_units)
#        90    0.000    0.000    0.005    0.000 transforms.py:905(update_from_data_xy)
#        30    0.000    0.000    0.005    0.000 session.py:583(sign)
#       480    0.001    0.000    0.005    0.000 core.py:294(_extremum_fill_value)
#     31650    0.005    0.000    0.005    0.000 {method 'values' of 'dict' objects}
#      4770    0.003    0.000    0.005    0.000 font_manager.py:829(set_variant)
#        90    0.002    0.000    0.005    0.000 core.py:2328(masked_invalid)
#        90    0.000    0.000    0.005    0.000 image.py:787(__init__)
#   360/180    0.002    0.000    0.005    0.000 units.py:141(get_converter)
#       360    0.002    0.000    0.005    0.000 _methods.py:151(_ptp)
#       600    0.001    0.000    0.005    0.000 core.py:3659(filled)
#      2160    0.004    0.000    0.005    0.000 stride_tricks.py:250(<listcomp>)
#      1080    0.005    0.000    0.005    0.000 {method 'round' of 'numpy.generic' objects}
#      1980    0.005    0.000    0.005    0.000 {built-in method builtins.min}
#       810    0.002    0.000    0.005    0.000 __init__.py:1564(get_siblings)
#       330    0.002    0.000    0.005    0.000 formatters.py:397(lookup_by_type)
#       120    0.000    0.000    0.005    0.000 core.py:7763(asarray)
#       720    0.003    0.000    0.004    0.000 axis.py:875(_translate_tick_kw)
#        90    0.001    0.000    0.004    0.000 transforms.py:537(transformed)
#     36840    0.004    0.000    0.004    0.000 {built-in method builtins.id}
#       270    0.000    0.000    0.004    0.000 _base.py:857(get_position)
#        90    0.001    0.000    0.004    0.000 image.py:204(__init__)
#       120    0.000    0.000    0.004    0.000 hmac.py:90(update)
#     25380    0.004    0.000    0.004    0.000 artist.py:940(sticky_edges)
#      3060    0.002    0.000    0.004    0.000 text.py:1114(set_x)
#      2160    0.003    0.000    0.004    0.000 axis.py:192(_set_labelrotation)
#       900    0.002    0.000    0.004    0.000 transforms.py:2529(__init__)
#       150    0.004    0.000    0.004    0.000 {method 'update' of '_hashlib.HASH' objects}
#       180    0.001    0.000    0.004    0.000 transforms.py:1558(transform_path_non_affine)
#        30    0.000    0.000    0.004    0.000 <ipython-input-13-fd41c25b2264>:9(to_disp)
#        30    0.000    0.000    0.004    0.000 pretty.py:359(pretty)
#       540    0.001    0.000    0.004    0.000 text.py:532(set_clip_box)
#       720    0.002    0.000    0.004    0.000 ticker.py:201(_divmod)
#       930    0.002    0.000    0.004    0.000 patches.py:351(set_linewidth)
#        90    0.001    0.000    0.004    0.000 gridspec.py:266(get_subplot_params)
#       360    0.002    0.000    0.004    0.000 _base.py:4081(get_children)
#     10054    0.004    0.000    0.004    0.000 cycler.py:227(<genexpr>)
#       360    0.001    0.000    0.004    0.000 ticker.py:1699(le)
#       450    0.002    0.000    0.004    0.000 _base.py:3006(get_xlim)
#      1740    0.003    0.000    0.004    0.000 font_manager.py:1383(get_font)
#       180    0.000    0.000    0.004    0.000 fromnumeric.py:2092(cumsum)
#       360    0.001    0.000    0.004    0.000 _base.py:952(_set_artist_props)
#       152    0.003    0.000    0.004    0.000 iostream.py:195(schedule)
#       180    0.001    0.000    0.004    0.000 axis.py:1165(<listcomp>)
#       360    0.001    0.000    0.004    0.000 numeric.py:2891(__enter__)
#      1440    0.003    0.000    0.004    0.000 scale.py:560(scale_factory)
#       900    0.001    0.000    0.004    0.000 transforms.py:2573(get_matrix)
#        90    0.001    0.000    0.004    0.000 _base.py:1903(add_image)
#      3840    0.002    0.000    0.003    0.000 traitlets.py:545(__get__)
#      3060    0.002    0.000    0.003    0.000 text.py:1123(set_y)
#       480    0.001    0.000    0.003    0.000 patches.py:373(set_linestyle)
#      3780    0.003    0.000    0.003    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        30    0.000    0.000    0.003    0.000 backend_bases.py:163(new_figure_manager_given_figure)
#      1260    0.003    0.000    0.003    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       960    0.002    0.000    0.003    0.000 __init__.py:2026(is_math_text)
#       360    0.001    0.000    0.003    0.000 numeric.py:2896(__exit__)
#       240    0.000    0.000    0.003    0.000 core.py:309(minimum_fill_value)
#        90    0.000    0.000    0.003    0.000 pyplot.py:1432(axis)
#       540    0.001    0.000    0.003    0.000 spines.py:148(get_patch_transform)
#       600    0.001    0.000    0.003    0.000 core.py:214(_recursive_fill_value)
#       180    0.001    0.000    0.003    0.000 _base.py:1483(get_data_ratio)
#       120    0.003    0.000    0.003    0.000 mathtext.py:3245(__init__)
#        30    0.000    0.000    0.003    0.000 pretty.py:502(_default_pprint)
#       360    0.002    0.000    0.003    0.000 ticker.py:710(_set_orderOfMagnitude)
#      6480    0.003    0.000    0.003    0.000 stride_tricks.py:254(<genexpr>)
#       330    0.000    0.000    0.003    0.000 {method 'view' of 'numpy.ndarray' objects}
#       360    0.002    0.000    0.003    0.000 ticker.py:1772(scale_range)
#      2880    0.003    0.000    0.003    0.000 axis.py:215(get_tick_padding)
#        30    0.000    0.000    0.003    0.000 pretty.py:698(_repr_pprint)
#       210    0.000    0.000    0.003    0.000 {method 'any' of 'numpy.ndarray' objects}
#      1740    0.003    0.000    0.003    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        90    0.001    0.000    0.003    0.000 axis.py:2307(_update_offset_text_position)
#       120    0.000    0.000    0.003    0.000 backend_bases.py:2337(mpl_connect)
#       720    0.002    0.000    0.003    0.000 {built-in method builtins.sorted}
#        34    0.001    0.000    0.003    0.000 functional.py:1894(interpolate)
#      4980    0.003    0.000    0.003    0.000 core.py:3345(dtype)
#       240    0.001    0.000    0.003    0.000 transforms.py:427(size)
#      1170    0.002    0.000    0.003    0.000 transforms.py:392(intervalx)
#        60    0.000    0.000    0.003    0.000 backend_agg.py:142(draw_path)
#       390    0.000    0.000    0.003    0.000 {built-in method builtins.repr}
#       180    0.001    0.000    0.003    0.000 path.py:164(_fast_from_codes_and_verts)
#       480    0.002    0.000    0.003    0.000 core.py:3158(__getitem__)
#        30    0.002    0.000    0.003    0.000 tensor.py:324(__rdiv__)
#       210    0.000    0.000    0.003    0.000 _methods.py:42(_any)
#       720    0.001    0.000    0.003    0.000 axis.py:2062(get_view_interval)
#       270    0.001    0.000    0.003    0.000 _base.py:1290(set_aspect)
#      6480    0.003    0.000    0.003    0.000 lines.py:537(set_markevery)
#        30    0.000    0.000    0.003    0.000 figure.py:279(__repr__)
#        30    0.001    0.000    0.003    0.000 backend_bases.py:1770(__init__)
#       720    0.001    0.000    0.003    0.000 axis.py:2440(get_view_interval)
#      3780    0.003    0.000    0.003    0.000 re.py:278(_compile)
#       180    0.001    0.000    0.003    0.000 transforms.py:961(intervalx)
#       360    0.001    0.000    0.002    0.000 pyplot.py:966(gca)
#       840    0.001    0.000    0.002    0.000 patches.py:440(set_capstyle)
#     15150    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#       360    0.001    0.000    0.002    0.000 ticker.py:1715(ge)
#       360    0.001    0.000    0.002    0.000 __init__.py:2346(safe_first_element)
#       180    0.000    0.000    0.002    0.000 artist.py:243(get_window_extent)
#      1740    0.002    0.000    0.002    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#        90    0.001    0.000    0.002    0.000 transforms.py:869(update_from_path)
#      4320    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       540    0.000    0.000    0.002    0.000 artist.py:637(set_clip_box)
#       840    0.001    0.000    0.002    0.000 transforms.py:296(x0)
#        60    0.002    0.000    0.002    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       480    0.001    0.000    0.002    0.000 core.py:296(_scalar_fill_value)
#       240    0.000    0.000    0.002    0.000 core.py:360(maximum_fill_value)
#       360    0.002    0.000    0.002    0.000 axis.py:1172(get_tick_padding)
#        30    0.000    0.000    0.002    0.000 figure.py:2169(get_default_bbox_extra_artists)
#       360    0.001    0.000    0.002    0.000 text.py:1105(set_position)
#       180    0.001    0.000    0.002    0.000 transforms.py:966(intervaly)
#        30    0.000    0.000    0.002    0.000 session.py:564(msg)
#       420    0.001    0.000    0.002    0.000 numerictypes.py:687(issubdtype)
#        60    0.001    0.000    0.002    0.000 figure.py:873(set_size_inches)
#       450    0.001    0.000    0.002    0.000 _base.py:3345(get_ylim)
#        30    0.000    0.000    0.002    0.000 __init__.py:354(empty_cache)
#        90    0.001    0.000    0.002    0.000 _base.py:1662(axis)
#       360    0.001    0.000    0.002    0.000 spines.py:318(_calc_offset_transform)
#       990    0.001    0.000    0.002    0.000 core.py:596(filled)
#       360    0.000    0.000    0.002    0.000 fromnumeric.py:1577(nonzero)
#      1170    0.002    0.000    0.002    0.000 transforms.py:400(intervaly)
#        30    0.002    0.000    0.002    0.000 {built-in method torch._C._cuda_emptyCache}
#        90    0.000    0.000    0.002    0.000 copy.py:67(copy)
#       840    0.000    0.000    0.002    0.000 core.py:1326(make_mask_descr)
#        90    0.000    0.000    0.002    0.000 __init__.py:68(process_projection_requirements)
#      8100    0.002    0.000    0.002    0.000 font_manager.py:758(get_weight)
#        30    0.002    0.000    0.002    0.000 {built-in method binascii.b2a_base64}
#      8100    0.002    0.000    0.002    0.000 font_manager.py:730(get_family)
#      5040    0.002    0.000    0.002    0.000 transforms.py:1754(_get_is_affine)
#        90    0.000    0.000    0.002    0.000 transforms.py:1514(get_matrix)
#       720    0.002    0.000    0.002    0.000 numeric.py:2592(geterr)
# ...
#       360    0.000    0.000    0.000    0.000 text.py:848(get_position)
#       600    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       360    0.000    0.000    0.000    0.000 type_check.py:147(imag)
#       390    0.000    0.000    0.000    0.000 figure.py:88(<listcomp>)
#        30    0.000    0.000    0.000    0.000 _pylab_helpers.py:115(set_active)
#       180    0.000    0.000    0.000    0.000 transforms.py:314(x1)
#       180    0.000    0.000    0.000    0.000 image.py:743(get_resample)
#        30    0.000    0.000    0.000    0.000 {built-in method utcnow}
#       420    0.000    0.000    0.000    0.000 backend_bases.py:930(get_dashes)
#       270    0.000    0.000    0.000    0.000 pretty.py:100(_safe_getattr)
#       780    0.000    0.000    0.000    0.000 path.py:241(simplify_threshold)
#        30    0.000    0.000    0.000    0.000 figure.py:493(set_tight_layout)
#        90    0.000    0.000    0.000    0.000 image.py:747(set_filternorm)
#        30    0.000    0.000    0.000    0.000 hmac.py:108(_current)
#        90    0.000    0.000    0.000    0.000 gridspec.py:391(__init__)
#       330    0.000    0.000    0.000    0.000 formatters.py:359(_check_return)
#       180    0.000    0.000    0.000    0.000 transforms.py:983(minposx)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1045(set_clip_path)
#       180    0.000    0.000    0.000    0.000 transforms.py:323(y1)
#       152    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#        90    0.000    0.000    0.000    0.000 transforms.py:2449(__eq__)
#       120    0.000    0.000    0.000    0.000 py3compat.py:188(iteritems)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1120(set_url)
#        30    0.000    0.000    0.000    0.000 __init__.py:1176(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:10(showwarning)
#        30    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#        60    0.000    0.000    0.000    0.000 artist.py:505(get_snap)
#        90    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#        60    0.000    0.000    0.000    0.000 figure.py:933(get_facecolor)
#       360    0.000    0.000    0.000    0.000 core.py:3444(_get_mask)
#        30    0.000    0.000    0.000    0.000 tz.py:174(utcoffset)
#        30    0.000    0.000    0.000    0.000 figure.py:2170(<listcomp>)
#       360    0.000    0.000    0.000    0.000 _base.py:1287(get_aspect)
#       360    0.000    0.000    0.000    0.000 artist.py:1049(mouseover)
#       420    0.000    0.000    0.000    0.000 artist.py:490(get_gid)
#        30    0.000    0.000    0.000    0.000 session.py:242(extract_header)
#       360    0.000    0.000    0.000    0.000 _base.py:946(get_axes_locator)
#       180    0.000    0.000    0.000    0.000 transforms.py:987(minposy)
#        30    0.000    0.000    0.000    0.000 pretty.py:211(text)
#       360    0.000    0.000    0.000    0.000 axis.py:980(<listcomp>)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:990(get_snap)
#        90    0.000    0.000    0.000    0.000 gridspec.py:143(_normalize)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1151(get_hatch)
#        30    0.000    0.000    0.000    0.000 __init__.py:1419(get_backend)
#        90    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#       180    0.000    0.000    0.000    0.000 axis.py:1512(have_units)
#        34    0.000    0.000    0.000    0.000 functional.py:1944(_output_size)
#        30    0.000    0.000    0.000    0.000 patches.py:269(set_aa)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1178(get_hatch_linewidth)
#        90    0.000    0.000    0.000    0.000 _subplots.py:201(subplot_class_factory)
#        90    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:890(restore)
#       180    0.000    0.000    0.000    0.000 backend_agg.py:267(get_canvas_width_height)
#        60    0.000    0.000    0.000    0.000 transforms.py:2495(transform_path_non_affine)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1166(get_hatch_color)
#       150    0.000    0.000    0.000    0.000 __init__.py:1226(clear)
#        60    0.000    0.000    0.000    0.000 __init__.py:1433(is_interactive)
#       600    0.000    0.000    0.000    0.000 __init__.py:249(__hash__)
#       360    0.000    0.000    0.000    0.000 axis.py:1439(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 iostream.py:366(write)
#        30    0.000    0.000    0.000    0.000 session.py:739(<listcomp>)
#       360    0.000    0.000    0.000    0.000 {built-in method math.radians}
#       180    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       270    0.000    0.000    0.000    0.000 gridspec.py:51(get_geometry)
#       300    0.000    0.000    0.000    0.000 image.py:761(get_filternorm)
#       540    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       180    0.000    0.000    0.000    0.000 cm.py:290(get_array)
#       150    0.000    0.000    0.000    0.000 path.py:626(unit_rectangle)
#       420    0.000    0.000    0.000    0.000 backend_bases.py:1184(get_sketch_params)
#        60    0.000    0.000    0.000    0.000 pretty.py:465(__init__)
#       480    0.000    0.000    0.000    0.000 backend_bases.py:267(open_group)
#       180    0.000    0.000    0.000    0.000 {built-in method math.sin}
#       180    0.000    0.000    0.000    0.000 artist.py:475(get_url)
#       360    0.000    0.000    0.000    0.000 ticker.py:1593(tick_values)
#       270    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 formatters.py:940(_check_return)
#       240    0.000    0.000    0.000    0.000 artist.py:605(get_path_effects)
#        30    0.000    0.000    0.000    0.000 _pylab_helpers.py:35(get_fig_manager)
#        30    0.000    0.000    0.000    0.000 backend_bases.py:2087(_get_output_canvas)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1404(__init__)
#       180    0.000    0.000    0.000    0.000 _base.py:1412(get_anchor)
#        30    0.000    0.000    0.000    0.000 pretty.py:300(flush)
#       480    0.000    0.000    0.000    0.000 backend_bases.py:274(close_group)
#       300    0.000    0.000    0.000    0.000 image.py:778(get_filterrad)
#        60    0.000    0.000    0.000    0.000 threading.py:237(__enter__)
#        60    0.000    0.000    0.000    0.000 figure.py:929(get_edgecolor)
#       180    0.000    0.000    0.000    0.000 _base.py:2523(_get_axis_list)
#        60    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#        90    0.000    0.000    0.000    0.000 figure.py:108(<dictcomp>)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1103(set_linewidth)
#       360    0.000    0.000    0.000    0.000 scale.py:47(limit_range_for_scale)
#       180    0.000    0.000    0.000    0.000 text.py:580(get_wrap)
#        90    0.000    0.000    0.000    0.000 figure.py:1015(fixitems)
#        30    0.000    0.000    0.000    0.000 py3compat.py:19(encode)
#        90    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       180    0.000    0.000    0.000    0.000 text.py:761(get_color)
#       240    0.000    0.000    0.000    0.000 backend_agg.py:303(option_image_nocomposite)
#       180    0.000    0.000    0.000    0.000 backend_bases.py:1039(set_clip_rectangle)
#        56    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#        30    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#        60    0.000    0.000    0.000    0.000 __init__.py:1483(__init__)
#        60    0.000    0.000    0.000    0.000 threading.py:240(__exit__)
#       180    0.000    0.000    0.000    0.000 backend_bases.py:1793(is_saving)
#        60    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_hex}
#        30    0.000    0.000    0.000    0.000 configurable.py:426(initialized)
#        30    0.000    0.000    0.000    0.000 figure.py:415(_repr_html_)
#       212    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#        90    0.000    0.000    0.000    0.000 gridspec.py:75(set_height_ratios)
#        90    0.000    0.000    0.000    0.000 gridspec.py:66(set_width_ratios)
#         2    0.000    0.000    0.000    0.000 {built-in method ones}
#        30    0.000    0.000    0.000    0.000 weakref.py:356(remove)
#        90    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#       180    0.000    0.000    0.000    0.000 figure.py:516(get_constrained_layout)
#        90    0.000    0.000    0.000    0.000 _base.py:3734(set_navigate_mode)
#       180    0.000    0.000    0.000    0.000 artist.py:608(get_figure)
#        30    0.000    0.000    0.000    0.000 displaypub.py:38(_validate_data)
#       180    0.000    0.000    0.000    0.000 colors.py:97(_sanitize_extrema)
#        56    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#       180    0.000    0.000    0.000    0.000 {built-in method math.cos}
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1019(set_antialiased)
#       180    0.000    0.000    0.000    0.000 path.py:267(should_simplify)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1030(set_capstyle)
#        90    0.000    0.000    0.000    0.000 weakref.py:371(_commit_removals)
#        56    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#        60    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        30    0.000    0.000    0.000    0.000 pretty.py:495(remove)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:38(as_strided)
#       180    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method from_numpy}
#        31    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 jsonutil.py:49(encode_images)
#       180    0.000    0.000    0.000    0.000 backend_bases.py:766(flipy)
#        90    0.000    0.000    0.000    0.000 _base.py:3716(set_navigate)
#       180    0.000    0.000    0.000    0.000 backend_bases.py:1126(set_gid)
#        60    0.000    0.000    0.000    0.000 jsonutil.py:34(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 tensor.py:403(__array_wrap__)
#        60    0.000    0.000    0.000    0.000 patches.py:720(_update_x1)
#       116    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       180    0.000    0.000    0.000    0.000 artist.py:920(get_zorder)
#        90    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       180    0.000    0.000    0.000    0.000 backend_bases.py:563(get_image_magnification)
#        30    0.000    0.000    0.000    0.000 widgets.py:37(__init__)
#       180    0.000    0.000    0.000    0.000 path.py:249(simplify_threshold)
#        90    0.000    0.000    0.000    0.000 artist.py:479(set_url)
#        60    0.000    0.000    0.000    0.000 figure.py:759(set_canvas)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1094(set_joinstyle)
#       208    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        30    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        31    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        60    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        60    0.000    0.000    0.000    0.000 patches.py:723(_update_y1)
#        31    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        60    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        90    0.000    0.000    0.000    0.000 _subplots.py:123(get_subplotspec)
#        30    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        30    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        60    0.000    0.000    0.000    0.000 patches.py:233(get_facecolor)
#        30    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        90    0.000    0.000    0.000    0.000 gridspec.py:428(get_gridspec)
#         1    0.000    0.000    0.000    0.000 validation.py:125(_shape_repr)
#        90    0.000    0.000    0.000    0.000 tight_bbox.py:35(_l)
#        90    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 warnings.py:22(formatwarning)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1056(set_dashes)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1132(set_snap)
#        30    0.000    0.000    0.000    0.000 tz.py:218(_isdst)
#        60    0.000    0.000    0.000    0.000 artist.py:544(get_sketch_params)
#        60    0.000    0.000    0.000    0.000 patches.py:226(get_edgecolor)
#        34    0.000    0.000    0.000    0.000 functional.py:1934(_check_size_scale_factor)
#        30    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        90    0.000    0.000    0.000    0.000 artist.py:897(get_label)
#        60    0.000    0.000    0.000    0.000 figure.py:487(get_tight_layout)
#         1    0.000    0.000    0.000    0.000 functional.py:1950(<listcomp>)
#        60    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:6(parse)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:2046(draw)
#        60    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#        30    0.000    0.000    0.000    0.000 formatters.py:824(_check_return)
#        30    0.000    0.000    0.000    0.000 backend_bases.py:2689(destroy)
#        30    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:313(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#         1    0.000    0.000    0.000    0.000 validation.py:104(_num_samples)
#        60    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        56    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 image.py:204(_compute_n_patches)
#         1    0.000    0.000    0.000    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 validation.py:152(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:300(_is_master_process)
#         1    0.000    0.000    0.000    0.000 validation.py:617(check_random_state)
#         1    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#        30    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 image.py:286(<listcomp>)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:20(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:1202(isspmatrix)
#         1    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:29(get_config)
#         1    0.000    0.000    0.000    0.000 utils.py:5(_ntuple)
#
#
# CPU times: user 21min 54s, sys: 3min 5s, total: 24min 59s
# Wall time: 24min 48s

# %%
#Replaces the epitome (e,ev) of an image by another epitome image (emod)
#keeping the mapping intact. The routine can be used to edit images or to
#preprocess by coloring the image accoring to the image (see the segmentation
#part of the web page for more info). K specifies the patch size to use in 
#mapping inference and SPC defines the patch spacing.

def reconstruct(x,K,e,ev,emod,SPC):
    _,NoCh1,Ny,Nx = x.shape
    NoCh2 = emod.shape[0]
    #print(NoCh1,NoCh2)
    if NoCh1 == 1:
        x = torch.stack((x,x,x),dim=0)
        print(x.shape)
    
    NoCh1,N,Ny = e.shape
    SY = x.shape[2]
    SX = x.shape[3]
    
    ewrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    evwrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    MINP = 1e-6
    MINV = 1e-2
    
    ewrap[:,:N,:N] = e
    ewrap[:,N:,:] = ewrap[:,:K-1,:]
    ewrap[:,:,N:] = ewrap[:,:,:K-1]
    evwrap[:,:N,:N] = ev
    evwrap[:,N:,:] = evwrap[:,:K-1,:]
    evwrap[:,:,N:] = evwrap[:,:,:K-1]
    logevwrap = torch.log(evwrap)
    evwrapi = 1./evwrap
    tmp3 = torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K))
    tmp4 = torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K))
    #print(tmp3.shape,tmp4.shape)
    emodwrap = torch.zeros((NoCh2,N+K-1,N+K-1)).to(device)
    emodwrap[:,:N,:N] = emod
    emodwrap[:,N:,:] = emodwrap[:,:K-1,:]
    emodwrap[:,:,N:] = emodwrap[:,:,:K-1]
    
    z = torch.zeros((NoCh2,SY,SX)).to(device)
    cnt = torch.zeros((SY,SX)).to(device)
    ixt = 0
    iyt = 0
    for iy in range(0,SY-K+1,SPC):
        print('y index = '+str(iy))
        for ix in range(0,SX-K+1,SPC):
            #watch for indexing errors
            yc = x[:,:,iy:iy+K,ix:ix+K]
            yct = torch.flip(yc,[2,3])
            lP = torch.zeros(tmp4.shape).to(device)#[:,:] = 0
            #print(evwrapi.shape,ewrap.shape,evwrap.shape,yct.shape)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrap,0),yct))
            lP += -.5*(tmp4+tmp1-2*tmp2+tmp3)
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            P /= torch.sum(P)
            mxp,mxpj = torch.max(P,dim=1)
            mxpi = torch.argmax(mxp)
            mxp = torch.max(mxp)
            mxpj = mxpj[mxpi]
            #print(mxpi,mxpj)
            #watch for indexing errors
            newp = emodwrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            oldp = ewrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            z[:,iy:iy+K-1,ix:ix+K-1] += newp 
            cnt[iy:iy+K-1,ix:ix+K-1] += 1
            ixt = ix
            iyt = iy
    z = z[:,:iyt+K-1,:ixt+K-1]
    cnt = cnt[:iyt+K-1,:ixt+K-1]
    z /= cnt
    #for i in range(NoCh2):
        #z[i,:,:] /= cnt
    return z

# %%
# %%time
cProfile.run('z2=reconstruct(tsIMtorch[:,:4,:300,:300],17,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:10,:,:],3)')
#cProfile.run('z=reconstruct(tsIMtorch[:,:4,:,:],17,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:10,:,:],3)')
torch.cuda.empty_cache()
# Out:
# 4 6
# torch.Size([4, 64, 64]) torch.Size([4, 64, 64])
# y index = 0
#          225 function calls in 0.005 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.001    0.000 <ipython-input-13-fd41c25b2264>:3(cum_sum)
#         1    0.001    0.001    0.005    0.005 <ipython-input-29-7347389316ad>:7(reconstruct)
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 functional.py:2112(pad)
#         1    0.000    0.000    0.000    0.000 functional.py:346(argmax)
#        11    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#        10    0.000    0.000    0.000    0.000 iostream.py:300(_is_master_process)
#        10    0.000    0.000    0.000    0.000 iostream.py:313(_schedule_flush)
#        10    0.000    0.000    0.000    0.000 iostream.py:366(write)
#        11    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         2    0.000    0.000    0.000    0.000 padding.py:12(forward)
#         2    0.000    0.000    0.000    0.000 padding.py:18(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:23(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:24(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tensor.py:324(__rdiv__)
#        11    0.000    0.000    0.000    0.000 threading.py:1060(_wait_for_tstate_lock)
#        11    0.000    0.000    0.000    0.000 threading.py:1102(is_alive)
#        11    0.000    0.000    0.000    0.000 threading.py:504(is_set)
#         1    0.000    0.000    0.000    0.000 {built-in method _argmax}
#         2    0.000    0.000    0.000    0.000 {built-in method apply}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.exec}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 {built-in method conv2d}
#         4    0.000    0.000    0.000    0.000 {built-in method cumsum}
#         1    0.000    0.000    0.000    0.000 {built-in method exp}
#         1    0.000    0.000    0.000    0.000 {built-in method flip}
#         1    0.000    0.000    0.000    0.000 {built-in method log}
#         3    0.001    0.000    0.001    0.000 {built-in method max}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {built-in method squeeze}
#         1    0.000    0.000    0.000    0.000 {built-in method sum}
#         4    0.000    0.000    0.000    0.000 {built-in method unsqueeze}
#         6    0.000    0.000    0.000    0.000 {built-in method zeros}
#        11    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#        12    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#         6    0.001    0.000    0.001    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'torch._C._TensorBase' objects}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in run(statement, filename, sort)
#      14
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#      17
#      18 def runctx(statement, globals, locals, filename=None, sort=-1):
#
# /anaconda/envs/py35/lib/python3.5/profile.py in run(self, statement, filename, sort)
#      53         prof = self.profiler()
#      54         try:
# ---> 55             prof.run(statement)
#      56         except SystemExit:
#      57             pass
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in run(self, cmd)
#      93         import __main__
#      94         dict = __main__.__dict__
# ---> 95         return self.runctx(cmd, dict, dict)
#      96
#      97     def runctx(self, cmd, globals, locals):
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>()
#
# <ipython-input-29-7347389316ad> in reconstruct(x, K, e, ev, emod, SPC)
#      60             mxpi = torch.argmax(mxp)
#      61             mxp = torch.max(mxp)
# ---> 62             mxpj = mxpj[mxpi]
#      63             #print(mxpi,mxpj)
#      64             #watch for indexing errors
#
# IndexError: index 193 is out of bounds for dimension 0 with size 4

# %%
zcpu = z2.cpu().numpy()

# %%
zcpu.shape
# Out:
# (6, 298, 298)

# %%
zcpu[2]
# Out:
# array([[7.1225323e-02, 1.7243260e-01, 2.4489760e-01, ..., 1.3318388e-01,
#         1.6777182e-01, 1.7192534e-01],
#        [1.4427360e-03, 1.3005914e-01, 2.7331495e-01, ..., 1.6543475e-01,
#         1.1626265e-01, 1.2968609e-01],
#        [4.1035041e-02, 1.0947010e-03, 9.8647468e-02, ..., 1.7941293e-01,
#         1.9782571e-04, 1.9327951e-04],
#        ...,
#        [8.0230647e-01, 6.9742203e-01, 5.4161161e-01, ..., 2.7738142e-01,
#         2.8650445e-01, 3.5344177e-01],
#        [6.6144675e-01, 6.9963574e-01, 5.3055656e-01, ..., 3.0330148e-01,
#         3.0414540e-01, 3.0981106e-01],
#        [5.2601540e-01, 5.8800352e-01, 5.1109731e-01, ..., 1.3961579e-01,
#         2.0334284e-01, 2.2815298e-01]], dtype=float32)

# %%
np.savez_compressed('reconstruction2',a=zcpu)

# %%
zmax = np.argmax(np.reshape(zcpu,(6,-1)),axis=0)
zre = np.reshape(zmax,(zcpu.shape[1],-1))
zre.shape
# Out:
# (298, 298)

# %%
plt.figure()
plt.imshow(zre)
plt.axis('off')
plt.show()
plt.close()
plt.figure()
plt.imshow(lc[:300,:300])
plt.axis('off')
plt.show()
plt.close()

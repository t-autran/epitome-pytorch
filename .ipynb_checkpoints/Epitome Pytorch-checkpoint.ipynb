# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys,os,time

import numpy as np
import skimage.transform
import skimage.measure
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import rasterio

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn.feature_extraction.image import extract_patches_2d

import cProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

def cum_sum(arr, s):
    cumsum = torch.cumsum(torch.cumsum(arr,dim=2),dim=3)
    cumsum = F.pad(cumsum,(1,0,1,0),'constant',0)
    tot = cumsum[:,:,:-s,:-s]-cumsum[:,:,s:,:-s]-cumsum[:,:,:-s,s:]+cumsum[:,:,s:,s:]
    return tot

def to_disp(arr):
    arr_c = arr.cpu().numpy()
    arr_c = np.rollaxis(np.squeeze(arr_c),0,3)
    return arr_c

#learns N x N epitome from T, K x K random patches drawn from input image x.
#Applies NIT iterations of the E-M algorithm at scale sc; T*sc^2 patches are sampled.
#e,ev = initial epitome mean and variance. The mean is initialized
#to the uniform image with some small noise, and the variance is initialized to 1
#p returns an array of probabilities of using each part of the epitome

def epitome(x,K,N,T,NIT,sc):
    #initialize parameters
    x = F.interpolate(x,scale_factor=sc)
    x = np.clip(x,0,1)
    _, numDim, SY, SX = x.shape
    TFIN = T
    T = int(np.ceil(TFIN*sc**2))
    NFIN = N
    N = int(np.ceil(sc*NFIN))
    e = torch.zeros((1,numDim,N,N)).to(device)
    ev = torch.ones((1,numDim,N,N)).to(device)
    for i in range(numDim):
        e[:,i,:,:] = x[0,i,:,:].std()*torch.randn(N,N)/100 + x[0,i,:,:].mean() #e = mean of image plus noise
    p = (torch.ones((N,N))/N**2).to(device)
    MINP = 1e-6#1e-30
    MINV = 1e-2#1e-6
    
    #allocate trace of epitome
    etr = torch.zeros((NIT+1,1,numDim,NFIN,NFIN))
    etr[0,:,:,:,:] = F.interpolate(e,[NFIN,NFIN])
    N = int(np.ceil(sc*NFIN))
    e = torch.clamp(F.interpolate(e,[N,N]),min=0,max=1)
    ev = torch.clamp(F.interpolate(ev,[N,N]),min=MINV)
    p /= torch.sum(p)
    #x = torch.clamp(x,min=0,max=1)
    T = int(np.ceil(sc**2*TFIN))
    #lP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumPy = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    sumPy2 = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    ewrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
    evwrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
    SY = x.shape[2]
    SX = x.shape[3]
    ytemp = np.rollaxis(extract_patches_2d(torch.squeeze(x).permute(1,2,0),(K,K),max_patches=T),3,1)
    y = torch.from_numpy(ytemp).float().to(device)
    
    #perform NIT iterations of EM algorithm
    for nit in range(NIT):
        #glues together borders of e
        ewrap[:,:N,:N] = e;
        ewrap[:,N:,:] = ewrap[:,:K-1,:]
        ewrap[:,:,N:] = ewrap[:,:,:K-1]
        evwrap[:,:N,:N] = ev
        evwrap[:,N:,:] = evwrap[:,:K-1,:]
        evwrap[:,:,N:] = evwrap[:,:,:K-1]
        logevwrap = torch.log(evwrap)
        evwrapi = 1./evwrap

        # E STEP
        sumP[:,:] = 0
        sumPy[:,:,:] = 0
        sumPy2[:,:,:] = 0
        for t in range(T):
            yc = y[t,:,:,:]
            yct = torch.unsqueeze(torch.flip(yc,[1,2]),0)
            #compute posterior over patch location
            lP = torch.log(p)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrapi,0),yct))
            tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
            tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K)),dim=0)
            lP -= .5*(tmp4+tmp1-2*tmp2+tmp3)
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            nrmP = torch.sum(P)
            P /= nrmP
            tmp = P.view(1,1,N,N)
            tmp = F.pad(tmp,(K-1,K-1,K-1,K-1),'constant',0).to(device)
            tmp = torch.squeeze(cum_sum(tmp,K))
            tmp[:,:K-1] += tmp[:,N:]
            tmp[:K-1,:] += tmp[N:,:]
            sumP += tmp[:N,:N]
            tmpP = torch.unsqueeze(torch.unsqueeze(F.pad(P,(K-1,K-1,K-1,K-1),'constant',0),0),0)
            #update mean and variance
            for i in range(numDim):
                yctmp = yc[i,:,:].view(1,1,K,K)
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp))#.to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy[i,:,:] += tmp[:N,:N]
                
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp**2))#.to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy2[i,:,:] += tmp[:N,:N]
        torch.cuda.empty_cache()
        #M STEP
        p = sumP/torch.sum(sumP)
        for i in range(numDim):
            e[0,i,:,:] = sumPy[i,:,:]/sumP
            ev[0,i,:,:] = sumPy2[i,:,:]/sumP - 2*e[0,i,:,:]*sumPy[i,:,:]/sumP + e[0,i,:,:]**2
        ev = torch.clamp(ev,min=MINV)
        etemp = F.interpolate(e,[NFIN,NFIN])
        etr[nit+1,:,:,:] = etemp

        rows,cols = 1,3
        fig=plt.figure(figsize=(cols*5,rows*5))
        fig.add_subplot(rows, cols, 1)
        plt.axis('off')
        td = to_disp(etemp[:,:3,:,:])
        plt.imshow(td)
        plt.title(str(N)+'x'+str(N)+' epitome')
        fig.add_subplot(rows, cols, 2)
        plt.axis('off')
        plt.imshow(p,cmap='hot',interpolation='nearest')
        plt.title('mixing proportions')
        fig.add_subplot(rows, cols, 3)
        plt.axis('off')
        tmp = np.sum(np.squeeze(ev.cpu().numpy()),axis=0)
        plt.imshow(tmp,cmap='hot',interpolation='nearest')
        curr_var = np.max(tmp)
        plt.title('variances, max='+str(max(tmp.flatten())))
        plt.show()
        plt.close()   
    return e,ev,p,etr

# %%
# %%time
p = pd.read_csv("big_lc_paths.csv", header=None)
paths = p[0].tolist()
palette = np.array([[0,0,0],[0,153,51],[0,102,255],[153,102,51],[255,153,0],[255,255,0],[204,102,153]])

tile = 0
naip_tile = rasterio.open("/mnt/blobfuse/esri-naip/"+paths[tile][:-7]+".mrf",'r')
naip = naip_tile.read().astype(float)/255.
naip_tile.close()

lc_tile = rasterio.open('/mnt/blobfuse/resampled-lc/'+paths[tile],'r')
lc = np.squeeze(lc_tile.read())
lc_tile.close()
print(np.unique(lc))
#lc[lc==1]=10
#lc[lc==2]=1
#lc[lc==10]=2
#lc[lc==4]=0
#lc[lc==15]=4
fig=plt.figure(figsize=(15,10))
fig.add_subplot(1,2,1)
plt.axis('off')
plt.imshow(np.rollaxis(naip,0,3)[:,:,:3])
fig.add_subplot(1,2,2)
plt.axis('off')
plt.imshow(lc)
plt.show()
plt.close()

trIM = np.zeros((10,naip.shape[1],naip.shape[2]),dtype=float)
trIM[:4,:,:] = naip
for i in range(6):
    trIM[4+i,:,:] = (lc==(i+1))
trIM = np.expand_dims(trIM,axis=0)
trIMtorch = torch.from_numpy(trIM).float().to(device)
    
tsIMtorch = trIMtorch
print(trIMtorch.shape)

# %%
# %%time
#sc will be changed to a single number
#instead repeatedly call the method to create epitomes at different scales
#no longer accepts initializations of e or ev
#removed dependency on etri. removed lptr; not implemented
#e, ev, p, etr = epitome(trIMtorch,8,128,3000,30,[.5]) #scale could be [.125 .25 .5 .75]
cProfile.run('e,ev,p,etr=epitome(trIMtorch,8,128,4000,20,.5)',sort='cumtime')
torch.cuda.empty_cache()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides

# %%
#Replaces the epitome (e,ev) of an image by another epitome image (emod)
#keeping the mapping intact. The routine can be used to edit images or to
#preprocess by coloring the image accoring to the image (see the segmentation
#part of the web page for more info). K specifies the patch size to use in 
#mapping inference and SPC defines the patch spacing.

def reconstruct(x,K,e,ev,emod,SPC):
    _,NoCh1,Ny,Nx = x.shape
    NoCh2 = emod.shape[0]
    if NoCh1 == 0:
        temp = x
        x = torch.stack((temp,temp,temp),dim=0)
        print(x.shape)
        #x = torch.zeros((NoCh1,Nx,Ny))
        #x[:,:,0] = temp
        #x[:,:,1] = temp
        #x[:,:,2] = temp
    
    NoCh1,N,Ny = e.shape
    SY = x.shape[2]
    SX = x.shape[3]
    
    ewrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    evwrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    MINP = 1e-6
    MINV = 1e-2
    
    ewrap[:,:N,:N] = e
    ewrap[:,N:,:] = ewrap[:,:K-1,:]
    ewrap[:,:,N:] = ewrap[:,:,:K-1]
    evwrap[:,:N,:N] = ev
    evwrap[:,N:,:] = evwrap[:,:K-1,:]
    evwrap[:,:,N:] = evwrap[:,:,:K-1]
    logevwrap = torch.log(evwrap)
    evwrapi = 1./evwrap
    tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
    tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K)),dim=0)
    emodwrap = torch.zeros((NoCh2,N+K-1,N+K-1)).to(device)
    emodwrap[:,:N,:N] = emod
    emodwrap[:,N:,:] = emodwrap[:,:K-1,:]
    emodwrap[:,:,N:] = emodwrap[:,:,:K-1]
    
    z = torch.zeros((NoCh2,SY,SX)).to(device)
    cnt = torch.zeros((SY,SX)).to(device)
    ixt = 0
    iyt = 0
    for iy in range(0,SY-K+1,SPC):
        print('y index = '+str(iy))
        for ix in range(0,SX-K+1,SPC):
            #watch for indexing errors
            yc = x[:,:,iy:iy+K,ix:ix+K]
            yct = torch.flip(yc,[2,3])
            lP = torch.zeros(tmp4.shape).to(device)#[:,:] = 0
            #print(evwrapi.shape,ewrap.shape,evwrap.shape,yct.shape)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrap,0),yct))
            lP += -.5*(tmp4+tmp1-2*tmp2+tmp3)
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            nrmP = torch.sum(P)
            P /= nrmP
            mxp,mxpj = torch.max(P,dim=1)
            mxpi = torch.argmax(mxp)
            mxp = torch.max(mxp)
            mxpj = mxpj[mxpi]
            #print(mxpi,mxpj)
            #watch for indexing errors
            newp = emodwrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            oldp = ewrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            z[:,iy:iy+K-1,ix:ix+K-1] += newp 
            cnt[iy:iy+K-1,ix:ix+K-1] += 1
            ixt = ix
            iyt = iy
    z = z[:,:iyt+K-1,:ixt+K-1]
    cnt = cnt[:iyt+K-1,:ixt+K-1]
    z /= cnt
    #for i in range(NoCh2):
        #z[i,:,:] /= cnt
    return z

# %%
# %%time
cProfile.run('z2=reconstruct(tsIMtorch[:,:4,:300,:300],17,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:10,:,:],3)')
#cProfile.run('z=reconstruct(tsIMtorch[:,:4,:,:],17,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:10,:,:],3)')
torch.cuda.empty_cache()
# Out:
# y index = 0
# y index = 3
# y index = 6
# y index = 9
# y index = 12
# y index = 15
# y index = 18
# y index = 21
# y index = 24
# y index = 27
# y index = 30
# y index = 33
# y index = 36
# y index = 39
# y index = 42
# y index = 45
# y index = 48
# y index = 51
# y index = 54
# y index = 57
# y index = 60
# y index = 63
# y index = 66
# y index = 69
# y index = 72
# y index = 75
# y index = 78
# y index = 81
# y index = 84
# y index = 87
# y index = 90
# y index = 93
# y index = 96
# y index = 99
# y index = 102
# y index = 105
# y index = 108
# y index = 111
# y index = 114
# y index = 117
# y index = 120
# y index = 123
# y index = 126
# y index = 129
# y index = 132
# y index = 135
# y index = 138
# y index = 141
# y index = 144
# y index = 147
# y index = 150
# y index = 153
# y index = 156
# y index = 159
# y index = 162
# y index = 165
# y index = 168
# y index = 171
# y index = 174
# y index = 177
# y index = 180
# y index = 183
# y index = 186
# y index = 189
# y index = 192
# y index = 195
# y index = 198
# y index = 201
# y index = 204
# y index = 207
# y index = 210
# y index = 213
# y index = 216
# y index = 219
# y index = 222
# y index = 225
# y index = 228
# y index = 231
# y index = 234
# y index = 237
# y index = 240
# y index = 243
# y index = 246
# y index = 249
# y index = 252
# y index = 255
# y index = 258
# y index = 261
# y index = 264
# y index = 267
# y index = 270
# y index = 273
# y index = 276
# y index = 279
# y index = 282
# y index = 285
# y index = 288
# y index = 291
# y index = 294
# y index = 297
# y index = 300
# y index = 303
# y index = 306
# y index = 309
# y index = 312
# y index = 315
# y index = 318
# y index = 321
# y index = 324
# y index = 327
# y index = 330
# y index = 333
# y index = 336
# y index = 339
# y index = 342
# y index = 345
# y index = 348
# y index = 351
# y index = 354
# y index = 357
# y index = 360
# y index = 363
# y index = 366
# y index = 369
# y index = 372
# y index = 375
# y index = 378
# y index = 381
# y index = 384
# y index = 387
# y index = 390
# y index = 393
# y index = 396
# y index = 399
# y index = 402
# y index = 405
# y index = 408
# y index = 411
# y index = 414
# y index = 417
# y index = 420
# y index = 423
# y index = 426
# y index = 429
# y index = 432
# y index = 435
# y index = 438
# y index = 441
# y index = 444
# y index = 447
# y index = 450
# y index = 453
# y index = 456
# y index = 459
# y index = 462
# y index = 465
# y index = 468
# y index = 471
# y index = 474
# y index = 477
# y index = 480
# y index = 483
# y index = 486
# y index = 489
# y index = 492
# y index = 495
# y index = 498
# y index = 501
# y index = 504
# y index = 507
# y index = 510
# y index = 513
# y index = 516
# y index = 519
# y index = 522
# y index = 525
# y index = 528
# y index = 531
# y index = 534
# y index = 537
# y index = 540
# y index = 543
# y index = 546
# y index = 549
# y index = 552
# y index = 555
# y index = 558
# y index = 561
# y index = 564
# y index = 567
# y index = 570
# y index = 573
# y index = 576
# y index = 579
# y index = 582
# y index = 585
# y index = 588
# y index = 591
# y index = 594
# y index = 597
# y index = 600
# y index = 603
# y index = 606
# y index = 609
# y index = 612
# y index = 615
# y index = 618
# y index = 621
# y index = 624
# y index = 627
# y index = 630
# y index = 633
# y index = 636
# y index = 639
# y index = 642
# y index = 645
# y index = 648
# y index = 651
# y index = 654
# y index = 657
# y index = 660
# y index = 663
# y index = 666
# y index = 669
# y index = 672
# y index = 675
# y index = 678
# y index = 681
# y index = 684
# y index = 687
# y index = 690
# y index = 693
# y index = 696
# y index = 699
# y index = 702
# y index = 705
# y index = 708
# y index = 711
# y index = 714
# y index = 717
# y index = 720
# y index = 723
# y index = 726
# y index = 729
# y index = 732
# y index = 735
# y index = 738
# y index = 741
# y index = 744
# y index = 747
# y index = 750
# y index = 753
# y index = 756
# y index = 759
# y index = 762
# y index = 765
# y index = 768
# y index = 771
# y index = 774
# y index = 777
# y index = 780
# y index = 783
# y index = 786
# y index = 789
# y index = 792
# y index = 795
# y index = 798
# y index = 801
# y index = 804
# y index = 807
# y index = 810
# y index = 813
# y index = 816
# y index = 819
# y index = 822
# y index = 825
# y index = 828
# y index = 831
# y index = 834
# y index = 837
# y index = 840
# y index = 843
# y index = 846
# y index = 849
# y index = 852
# y index = 855
# y index = 858
# y index = 861
# y index = 864
# y index = 867
# y index = 870
# y index = 873
# y index = 876
# y index = 879
# y index = 882
# y index = 885
# y index = 888
# y index = 891
# y index = 894
# y index = 897
# y index = 900
# y index = 903
# y index = 906
# y index = 909
# y index = 912
# y index = 915
# y index = 918
# y index = 921
# y index = 924
# y index = 927
# y index = 930
# y index = 933
# y index = 936
# y index = 939
# y index = 942
# y index = 945
# y index = 948
# y index = 951
# y index = 954
# y index = 957
# y index = 960
# y index = 963
# y index = 966
# y index = 969
# y index = 972
# y index = 975
# y index = 978
# y index = 981
# y index = 984
# y index = 987
# y index = 990
# y index = 993
# y index = 996
# y index = 999
# y index = 1002
# y index = 1005
# y index = 1008
# y index = 1011
# y index = 1014
# y index = 1017
# y index = 1020
# y index = 1023
# y index = 1026
# y index = 1029
# y index = 1032
# y index = 1035
# y index = 1038
# y index = 1041
# y index = 1044
# y index = 1047
# y index = 1050
# y index = 1053
# y index = 1056
# y index = 1059
# y index = 1062
# y index = 1065
# y index = 1068
# y index = 1071
# y index = 1074
# y index = 1077
# y index = 1080
# y index = 1083
# y index = 1086
# y index = 1089
# y index = 1092
# y index = 1095
# y index = 1098
# y index = 1101
# y index = 1104
# y index = 1107
# y index = 1110
# y index = 1113
# y index = 1116
# y index = 1119
# y index = 1122
# y index = 1125
# y index = 1128
# y index = 1131
# y index = 1134
# y index = 1137
# y index = 1140
# y index = 1143
# y index = 1146
# y index = 1149
# y index = 1152
# y index = 1155
# y index = 1158
# y index = 1161
# y index = 1164
# y index = 1167
# y index = 1170
# y index = 1173
# y index = 1176
# y index = 1179
# y index = 1182
# y index = 1185
# y index = 1188
# y index = 1191
# y index = 1194
# y index = 1197
# y index = 1200
# y index = 1203
# y index = 1206
# y index = 1209
# y index = 1212
# y index = 1215
# y index = 1218
# y index = 1221
# y index = 1224
# y index = 1227
# y index = 1230
# y index = 1233
# y index = 1236
# y index = 1239
# y index = 1242
# y index = 1245
# y index = 1248
# y index = 1251
# y index = 1254
# y index = 1257
# y index = 1260
# y index = 1263
# y index = 1266
# y index = 1269
# y index = 1272
# y index = 1275
# y index = 1278
# y index = 1281
# y index = 1284
# y index = 1287
# y index = 1290
# y index = 1293
# y index = 1296
# y index = 1299
# y index = 1302
# y index = 1305
# y index = 1308
# y index = 1311
# y index = 1314
# y index = 1317
# y index = 1320
# y index = 1323
# y index = 1326
# y index = 1329
# y index = 1332
# y index = 1335
# y index = 1338
# y index = 1341
# y index = 1344
# y index = 1347
# y index = 1350
# y index = 1353
# y index = 1356
# y index = 1359
# y index = 1362
# y index = 1365
# y index = 1368
# y index = 1371
# y index = 1374
# y index = 1377
# y index = 1380
# y index = 1383
# y index = 1386
# y index = 1389
# y index = 1392
# y index = 1395
# y index = 1398
# y index = 1401
# y index = 1404
# y index = 1407
# y index = 1410
# y index = 1413
# y index = 1416
# y index = 1419
# y index = 1422
# y index = 1425
# y index = 1428
# y index = 1431
# y index = 1434
# y index = 1437
# y index = 1440
# y index = 1443
# y index = 1446
# y index = 1449
# y index = 1452
# y index = 1455
# y index = 1458
# y index = 1461
# y index = 1464
# y index = 1467
# y index = 1470
# y index = 1473
# y index = 1476
# y index = 1479
# y index = 1482
# y index = 1485
# y index = 1488
# y index = 1491
# y index = 1494
# y index = 1497
# y index = 1500
# y index = 1503
# y index = 1506
# y index = 1509
# y index = 1512
# y index = 1515
# y index = 1518
# y index = 1521
# y index = 1524
# y index = 1527
# y index = 1530
# y index = 1533
# y index = 1536
# y index = 1539
# y index = 1542
# y index = 1545
# y index = 1548
# y index = 1551
# y index = 1554
# y index = 1557
# y index = 1560
# y index = 1563
# y index = 1566
# y index = 1569
# y index = 1572
# y index = 1575
# y index = 1578
# y index = 1581
# y index = 1584
# y index = 1587
# y index = 1590
# y index = 1593
# y index = 1596
# y index = 1599
# y index = 1602
# y index = 1605
# y index = 1608
# y index = 1611
# y index = 1614
# y index = 1617
# y index = 1620
# y index = 1623
# y index = 1626
# y index = 1629
# y index = 1632
# y index = 1635
# y index = 1638
# y index = 1641
# y index = 1644
# y index = 1647
# y index = 1650
# y index = 1653
# y index = 1656
# y index = 1659
# y index = 1662
# y index = 1665
# y index = 1668
# y index = 1671
# y index = 1674
# y index = 1677
# y index = 1680
# y index = 1683
# y index = 1686
# y index = 1689
# y index = 1692
# y index = 1695
# y index = 1698
# y index = 1701
# y index = 1704
# y index = 1707
# y index = 1710
# y index = 1713
# y index = 1716
# y index = 1719
# y index = 1722
# y index = 1725
# y index = 1728
# y index = 1731
# y index = 1734
# y index = 1737
# y index = 1740
# y index = 1743
# y index = 1746
# y index = 1749
# y index = 1752
# y index = 1755
# y index = 1758
# y index = 1761
# y index = 1764
# y index = 1767
# y index = 1770
# y index = 1773
# y index = 1776
# y index = 1779
# y index = 1782
# y index = 1785
# y index = 1788
# y index = 1791
# y index = 1794
# y index = 1797
# y index = 1800
# y index = 1803
# y index = 1806
# y index = 1809
# y index = 1812
# y index = 1815
# y index = 1818
# y index = 1821
# y index = 1824
# y index = 1827
# y index = 1830
# y index = 1833
# y index = 1836
# y index = 1839
# y index = 1842
# y index = 1845
# y index = 1848
# y index = 1851
# y index = 1854
# y index = 1857
# y index = 1860
# y index = 1863
# y index = 1866
# y index = 1869
# y index = 1872
# y index = 1875
# y index = 1878
# y index = 1881
# y index = 1884
# y index = 1887
# y index = 1890
# y index = 1893
# y index = 1896
# y index = 1899
# y index = 1902
# y index = 1905
# y index = 1908
# y index = 1911
# y index = 1914
# y index = 1917
# y index = 1920
# y index = 1923
# y index = 1926
# y index = 1929
# y index = 1932
# y index = 1935
# y index = 1938
# y index = 1941
# y index = 1944
# y index = 1947
# y index = 1950
# y index = 1953
# y index = 1956
# y index = 1959
# y index = 1962
# y index = 1965
# y index = 1968
# y index = 1971
# y index = 1974
# y index = 1977
# y index = 1980
# y index = 1983
# y index = 1986
# y index = 1989
# y index = 1992
# y index = 1995
# y index = 1998
# y index = 2001
# y index = 2004
# y index = 2007
# y index = 2010
# y index = 2013
# y index = 2016
# y index = 2019
# y index = 2022
# y index = 2025
# y index = 2028
# y index = 2031
# y index = 2034
# y index = 2037
# y index = 2040
# y index = 2043
# y index = 2046
# y index = 2049
# y index = 2052
# y index = 2055
# y index = 2058
# y index = 2061
# y index = 2064
# y index = 2067
# y index = 2070
# y index = 2073
# y index = 2076
# y index = 2079
# y index = 2082
# y index = 2085
# y index = 2088
# y index = 2091
# y index = 2094
# y index = 2097
# y index = 2100
# y index = 2103
# y index = 2106
# y index = 2109
# y index = 2112
# y index = 2115
# y index = 2118
# y index = 2121
# y index = 2124
# y index = 2127
# y index = 2130
# y index = 2133
# y index = 2136
# y index = 2139
# y index = 2142
# y index = 2145
# y index = 2148
# y index = 2151
# y index = 2154
# y index = 2157
# y index = 2160
# y index = 2163
# y index = 2166
# y index = 2169
# y index = 2172
# y index = 2175
# y index = 2178
# y index = 2181
# y index = 2184
# y index = 2187
# y index = 2190
# y index = 2193
# y index = 2196
# y index = 2199
# y index = 2202
# y index = 2205
# y index = 2208
# y index = 2211
# y index = 2214
# y index = 2217
# y index = 2220
# y index = 2223
# y index = 2226
# y index = 2229
# y index = 2232
# y index = 2235
# y index = 2238
# y index = 2241
# y index = 2244
# y index = 2247
# y index = 2250
# y index = 2253
# y index = 2256
# y index = 2259
# y index = 2262
# y index = 2265
# y index = 2268
# y index = 2271
# y index = 2274
# y index = 2277
# y index = 2280
# y index = 2283
# y index = 2286
# y index = 2289
# y index = 2292
# y index = 2295
# y index = 2298
# y index = 2301
# y index = 2304
# y index = 2307
# y index = 2310
# y index = 2313
# y index = 2316
# y index = 2319
# y index = 2322
# y index = 2325
# y index = 2328
# y index = 2331
# y index = 2334
# y index = 2337
# y index = 2340
# y index = 2343
# y index = 2346
# y index = 2349
# y index = 2352
# y index = 2355
# y index = 2358
# y index = 2361
# y index = 2364
# y index = 2367
# y index = 2370
# y index = 2373
# y index = 2376
# y index = 2379
# y index = 2382
# y index = 2385
# y index = 2388
# y index = 2391
# y index = 2394
# y index = 2397
# y index = 2400
# y index = 2403
# y index = 2406
# y index = 2409
# y index = 2412
# y index = 2415
# y index = 2418
# y index = 2421
# y index = 2424
# y index = 2427
# y index = 2430
# y index = 2433
# y index = 2436
# y index = 2439
# y index = 2442
# y index = 2445
# y index = 2448
# y index = 2451
# y index = 2454
# y index = 2457
# y index = 2460
# y index = 2463
# y index = 2466
# y index = 2469
# y index = 2472
# y index = 2475
# y index = 2478
# y index = 2481
# y index = 2484
# y index = 2487
# y index = 2490
# y index = 2493
# y index = 2496
# y index = 2499
# y index = 2502
# y index = 2505
# y index = 2508
# y index = 2511
# y index = 2514
# y index = 2517
# y index = 2520
# y index = 2523
# y index = 2526
# y index = 2529
# y index = 2532
# y index = 2535
# y index = 2538
# y index = 2541
# y index = 2544
# y index = 2547
# y index = 2550
# y index = 2553
# y index = 2556
# y index = 2559
# y index = 2562
# y index = 2565
# y index = 2568
# y index = 2571
# y index = 2574
# y index = 2577
# y index = 2580
# y index = 2583
# y index = 2586
# y index = 2589
# y index = 2592
# y index = 2595
# y index = 2598
# y index = 2601
# y index = 2604
# y index = 2607
# y index = 2610
# y index = 2613
# y index = 2616
# y index = 2619
# y index = 2622
# y index = 2625
# y index = 2628
# y index = 2631
# y index = 2634
# y index = 2637
# y index = 2640
# y index = 2643
# y index = 2646
# y index = 2649
# y index = 2652
# y index = 2655
# y index = 2658
# y index = 2661
# y index = 2664
# y index = 2667
# y index = 2670
# y index = 2673
# y index = 2676
# y index = 2679
# y index = 2682
# y index = 2685
# y index = 2688
# y index = 2691
# y index = 2694
# y index = 2697
# y index = 2700
# y index = 2703
# y index = 2706
# y index = 2709
# y index = 2712
# y index = 2715
# y index = 2718
# y index = 2721
# y index = 2724
# y index = 2727
# y index = 2730
# y index = 2733
# y index = 2736
# y index = 2739
# y index = 2742
# y index = 2745
# y index = 2748
# y index = 2751
# y index = 2754
# y index = 2757
# y index = 2760
# y index = 2763
# y index = 2766
# y index = 2769
# y index = 2772
# y index = 2775
# y index = 2778
# y index = 2781
# y index = 2784
# y index = 2787
# y index = 2790
# y index = 2793
# y index = 2796
# y index = 2799
# y index = 2802
# y index = 2805
# y index = 2808
# y index = 2811
# y index = 2814
# y index = 2817
# y index = 2820
# y index = 2823
# y index = 2826
# y index = 2829
# y index = 2832
# y index = 2835
# y index = 2838
# y index = 2841
# y index = 2844
# y index = 2847
# y index = 2850
# y index = 2853
# y index = 2856
# y index = 2859
# y index = 2862
# y index = 2865
# y index = 2868
# y index = 2871
# y index = 2874
# y index = 2877
# y index = 2880
# y index = 2883
# y index = 2886
# y index = 2889
# y index = 2892
# y index = 2895
# y index = 2898
# y index = 2901
# y index = 2904
# y index = 2907
# y index = 2910
# y index = 2913
# y index = 2916
# y index = 2919
# y index = 2922
# y index = 2925
# y index = 2928
# y index = 2931
# y index = 2934
# y index = 2937
# y index = 2940
# y index = 2943
# y index = 2946
# y index = 2949
# y index = 2952
# y index = 2955
# y index = 2958
# y index = 2961
# y index = 2964
# y index = 2967
# y index = 2970
# y index = 2973
# y index = 2976
# y index = 2979
# y index = 2982
# y index = 2985
# y index = 2988
# y index = 2991
# y index = 2994
# y index = 2997
# y index = 3000
# y index = 3003
# y index = 3006
# y index = 3009
# y index = 3012
# y index = 3015
# y index = 3018
# y index = 3021
# y index = 3024
# y index = 3027
# y index = 3030
# y index = 3033
# y index = 3036
# y index = 3039
# y index = 3042
# y index = 3045
# y index = 3048
# y index = 3051
# y index = 3054
# y index = 3057
# y index = 3060
# y index = 3063
# y index = 3066
# y index = 3069
# y index = 3072
# y index = 3075
# y index = 3078
# y index = 3081
# y index = 3084
# y index = 3087
# y index = 3090
# y index = 3093
# y index = 3096
# y index = 3099
# y index = 3102
# y index = 3105
# y index = 3108
# y index = 3111
# y index = 3114
# y index = 3117
# y index = 3120
# y index = 3123
# y index = 3126
# y index = 3129
# y index = 3132
# y index = 3135
# y index = 3138
# y index = 3141
# y index = 3144
# y index = 3147
# y index = 3150
# y index = 3153
# y index = 3156
# y index = 3159
# y index = 3162
# y index = 3165
# y index = 3168
# y index = 3171
# y index = 3174
# y index = 3177
# y index = 3180
# y index = 3183
# y index = 3186
# y index = 3189
# y index = 3192
# y index = 3195
# y index = 3198
# y index = 3201
# y index = 3204
# y index = 3207
# y index = 3210
# y index = 3213
# y index = 3216
# y index = 3219
# y index = 3222
# y index = 3225
# y index = 3228
# y index = 3231
# y index = 3234
# y index = 3237
# y index = 3240
# y index = 3243
# y index = 3246
# y index = 3249
# y index = 3252
# y index = 3255
# y index = 3258
# y index = 3261
# y index = 3264
# y index = 3267
# y index = 3270
# y index = 3273
# y index = 3276
# y index = 3279
# y index = 3282
# y index = 3285
# y index = 3288
# y index = 3291
# y index = 3294
# y index = 3297
# y index = 3300
# y index = 3303
# y index = 3306
# y index = 3309
# y index = 3312
# y index = 3315
# y index = 3318
# y index = 3321
# y index = 3324
# y index = 3327
# y index = 3330
# y index = 3333
# y index = 3336
# y index = 3339
# y index = 3342
# y index = 3345
# y index = 3348
# y index = 3351
# y index = 3354
# y index = 3357
# y index = 3360
# y index = 3363
# y index = 3366
# y index = 3369
# y index = 3372
# y index = 3375
# y index = 3378
# y index = 3381
# y index = 3384
# y index = 3387
# y index = 3390
# y index = 3393
# y index = 3396
# y index = 3399
# y index = 3402
# y index = 3405
# y index = 3408
# y index = 3411
# y index = 3414
# y index = 3417
# y index = 3420
# y index = 3423
# y index = 3426
# y index = 3429
# y index = 3432
# y index = 3435
# y index = 3438
# y index = 3441
# y index = 3444
# y index = 3447
# y index = 3450
# y index = 3453
# y index = 3456
# y index = 3459
# y index = 3462
# y index = 3465
# y index = 3468
# y index = 3471
# y index = 3474
# y index = 3477
# y index = 3480
# y index = 3483
# y index = 3486
# y index = 3489
# y index = 3492
# y index = 3495
# y index = 3498
# y index = 3501
# y index = 3504
# y index = 3507
# y index = 3510
# y index = 3513
# y index = 3516
# y index = 3519
# y index = 3522
# y index = 3525
# y index = 3528
# y index = 3531
# y index = 3534
# y index = 3537
# y index = 3540
# y index = 3543
# y index = 3546
# y index = 3549
# y index = 3552
# y index = 3555
# y index = 3558
# y index = 3561
# y index = 3564
# y index = 3567
# y index = 3570
# y index = 3573
# y index = 3576
# y index = 3579
# y index = 3582
# y index = 3585
# y index = 3588
# y index = 3591
# y index = 3594
# y index = 3597
# y index = 3600
# y index = 3603
# y index = 3606
# y index = 3609
# y index = 3612
# y index = 3615
# y index = 3618
# y index = 3621
# y index = 3624
# y index = 3627
# y index = 3630
# y index = 3633
# y index = 3636
# y index = 3639
# y index = 3642
# y index = 3645
# y index = 3648
# y index = 3651
# y index = 3654
# y index = 3657
# y index = 3660
# y index = 3663
# y index = 3666
# y index = 3669
# y index = 3672
# y index = 3675
# y index = 3678
# y index = 3681
# y index = 3684
# y index = 3687
# y index = 3690
# y index = 3693
# y index = 3696
# y index = 3699
# y index = 3702
# y index = 3705
# y index = 3708
# y index = 3711
# y index = 3714
# y index = 3717
# y index = 3720
# y index = 3723
# y index = 3726
# y index = 3729
# y index = 3732
# y index = 3735
# y index = 3738
# y index = 3741
# y index = 3744
# y index = 3747
# y index = 3750
# y index = 3753
# y index = 3756
# y index = 3759
# y index = 3762
# y index = 3765
# y index = 3768
# y index = 3771
# y index = 3774
# y index = 3777
# y index = 3780
# y index = 3783
# y index = 3786
# y index = 3789
# y index = 3792
# y index = 3795
# y index = 3798
# y index = 3801
# y index = 3804
# y index = 3807
# y index = 3810
# y index = 3813
# y index = 3816
# y index = 3819
# y index = 3822
# y index = 3825
# y index = 3828
# y index = 3831
# y index = 3834
# y index = 3837
# y index = 3840
# y index = 3843
# y index = 3846
# y index = 3849
# y index = 3852
# y index = 3855
# y index = 3858
# y index = 3861
# y index = 3864
# y index = 3867
# y index = 3870
# y index = 3873
# y index = 3876
# y index = 3879
# y index = 3882
# y index = 3885
# y index = 3888
# y index = 3891
# y index = 3894
# y index = 3897
# y index = 3900
# y index = 3903
# y index = 3906
# y index = 3909
# y index = 3912
# y index = 3915
# y index = 3918
# y index = 3921
# y index = 3924
# y index = 3927
# y index = 3930
# y index = 3933
# y index = 3936
# y index = 3939
# y index = 3942
# y index = 3945
# y index = 3948
# y index = 3951
# y index = 3954
# y index = 3957
# y index = 3960
# y index = 3963
# y index = 3966
# y index = 3969
# y index = 3972
# y index = 3975
# y index = 3978
# y index = 3981
# y index = 3984
# y index = 3987
# y index = 3990
# y index = 3993
# y index = 3996
# y index = 3999
# y index = 4002
# y index = 4005
# y index = 4008
# y index = 4011
# y index = 4014
# y index = 4017
# y index = 4020
# y index = 4023
# y index = 4026
# y index = 4029
# y index = 4032
# y index = 4035
# y index = 4038
# y index = 4041
# y index = 4044
# y index = 4047
# y index = 4050
# y index = 4053
# y index = 4056
# y index = 4059
# y index = 4062
# y index = 4065
# y index = 4068
# y index = 4071
# y index = 4074
# y index = 4077
# y index = 4080
# y index = 4083
# y index = 4086
# y index = 4089
# y index = 4092
# y index = 4095
# y index = 4098
# y index = 4101
# y index = 4104
# y index = 4107
# y index = 4110
# y index = 4113
# y index = 4116
# y index = 4119
# y index = 4122
# y index = 4125
# y index = 4128
# y index = 4131
# y index = 4134
# y index = 4137
# y index = 4140
# y index = 4143
# y index = 4146
# y index = 4149
# y index = 4152
# y index = 4155
# y index = 4158
# y index = 4161
# y index = 4164
# y index = 4167
# y index = 4170
# y index = 4173
# y index = 4176
# y index = 4179
# y index = 4182
# y index = 4185
# y index = 4188
# y index = 4191
# y index = 4194
# y index = 4197
# y index = 4200
# y index = 4203
# y index = 4206
# y index = 4209
# y index = 4212
# y index = 4215
# y index = 4218
# y index = 4221
# y index = 4224
# y index = 4227
# y index = 4230
# y index = 4233
# y index = 4236
# y index = 4239
# y index = 4242
# y index = 4245
# y index = 4248
# y index = 4251
# y index = 4254
# y index = 4257
# y index = 4260
# y index = 4263
# y index = 4266
# y index = 4269
# y index = 4272
# y index = 4275
# y index = 4278
# y index = 4281
# y index = 4284
# y index = 4287
# y index = 4290
# y index = 4293
# y index = 4296
# y index = 4299
# y index = 4302
# y index = 4305
# y index = 4308
# y index = 4311
# y index = 4314
# y index = 4317
# y index = 4320
# y index = 4323
# y index = 4326
# y index = 4329
# y index = 4332
# y index = 4335
# y index = 4338
# y index = 4341
# y index = 4344
# y index = 4347
# y index = 4350
# y index = 4353
# y index = 4356
# y index = 4359
# y index = 4362
# y index = 4365
# y index = 4368
# y index = 4371
# y index = 4374
# y index = 4377
# y index = 4380
# y index = 4383
# y index = 4386
# y index = 4389
# y index = 4392
# y index = 4395
# y index = 4398
# y index = 4401
# y index = 4404
# y index = 4407
# y index = 4410
# y index = 4413
# y index = 4416
# y index = 4419
# y index = 4422
# y index = 4425
# y index = 4428
# y index = 4431
# y index = 4434
# y index = 4437
# y index = 4440
# y index = 4443
# y index = 4446
# y index = 4449
# y index = 4452
# y index = 4455
# y index = 4458
# y index = 4461
# y index = 4464
# y index = 4467
# y index = 4470
# y index = 4473
# y index = 4476
# y index = 4479
# y index = 4482
# y index = 4485
# y index = 4488
# y index = 4491
# y index = 4494
# y index = 4497
# y index = 4500
# y index = 4503
# y index = 4506
# y index = 4509
# y index = 4512
# y index = 4515
# y index = 4518
# y index = 4521
# y index = 4524
# y index = 4527
# y index = 4530
# y index = 4533
# y index = 4536
# y index = 4539
# y index = 4542
# y index = 4545
# y index = 4548
# y index = 4551
# y index = 4554
# y index = 4557
# y index = 4560
# y index = 4563
# y index = 4566
# y index = 4569
# y index = 4572
# y index = 4575
# y index = 4578
# y index = 4581
# y index = 4584
# y index = 4587
# y index = 4590
# y index = 4593
# y index = 4596
# y index = 4599
# y index = 4602
# y index = 4605
# y index = 4608
# y index = 4611
# y index = 4614
# y index = 4617
# y index = 4620
# y index = 4623
# y index = 4626
# y index = 4629
# y index = 4632
# y index = 4635
# y index = 4638
# y index = 4641
# y index = 4644
# y index = 4647
# y index = 4650
# y index = 4653
# y index = 4656
# y index = 4659
# y index = 4662
# y index = 4665
# y index = 4668
# y index = 4671
# y index = 4674
# y index = 4677
# y index = 4680
# y index = 4683
# y index = 4686
# y index = 4689
# y index = 4692
# y index = 4695
# y index = 4698
# y index = 4701
# y index = 4704
# y index = 4707
# y index = 4710
# y index = 4713
# y index = 4716
# y index = 4719
# y index = 4722
# y index = 4725
# y index = 4728
# y index = 4731
# y index = 4734
# y index = 4737
# y index = 4740
# y index = 4743
# y index = 4746
# y index = 4749
# y index = 4752
# y index = 4755
# y index = 4758
# y index = 4761
# y index = 4764
# y index = 4767
# y index = 4770
# y index = 4773
# y index = 4776
# y index = 4779
# y index = 4782
# y index = 4785
# y index = 4788
# y index = 4791
# y index = 4794
# y index = 4797
# y index = 4800
# y index = 4803
# y index = 4806
# y index = 4809
# y index = 4812
# y index = 4815
# y index = 4818
# y index = 4821
# y index = 4824
# y index = 4827
# y index = 4830
# y index = 4833
# y index = 4836
# y index = 4839
# y index = 4842
# y index = 4845
# y index = 4848
# y index = 4851
# y index = 4854
# y index = 4857
# y index = 4860
# y index = 4863
# y index = 4866
# y index = 4869
# y index = 4872
# y index = 4875
# y index = 4878
# y index = 4881
# y index = 4884
# y index = 4887
# y index = 4890
# y index = 4893
# y index = 4896
# y index = 4899
# y index = 4902
# y index = 4905
# y index = 4908
# y index = 4911
# y index = 4914
# y index = 4917
# y index = 4920
# y index = 4923
# y index = 4926
# y index = 4929
# y index = 4932
# y index = 4935
# y index = 4938
# y index = 4941
# y index = 4944
# y index = 4947
# y index = 4950
# y index = 4953
# y index = 4956
# y index = 4959
# y index = 4962
# y index = 4965
# y index = 4968
# y index = 4971
# y index = 4974
# y index = 4977
# y index = 4980
# y index = 4983
# y index = 4986
# y index = 4989
# y index = 4992
# y index = 4995
# y index = 4998
# y index = 5001
# y index = 5004
# y index = 5007
# y index = 5010
# y index = 5013
# y index = 5016
# y index = 5019
# y index = 5022
# y index = 5025
# y index = 5028
# y index = 5031
# y index = 5034
# y index = 5037
# y index = 5040
# y index = 5043
# y index = 5046
# y index = 5049
# y index = 5052
# y index = 5055
# y index = 5058
# y index = 5061
# y index = 5064
# y index = 5067
# y index = 5070
# y index = 5073
# y index = 5076
# y index = 5079
# y index = 5082
# y index = 5085
# y index = 5088
# y index = 5091
# y index = 5094
# y index = 5097
# y index = 5100
# y index = 5103
# y index = 5106
# y index = 5109
# y index = 5112
# y index = 5115
# y index = 5118
# y index = 5121
# y index = 5124
# y index = 5127
# y index = 5130
# y index = 5133
# y index = 5136
# y index = 5139
# y index = 5142
# y index = 5145
# y index = 5148
# y index = 5151
# y index = 5154
# y index = 5157
# y index = 5160
# y index = 5163
# y index = 5166
# y index = 5169
# y index = 5172
# y index = 5175
# y index = 5178
# y index = 5181
# y index = 5184
# y index = 5187
# y index = 5190
# y index = 5193
# y index = 5196
# y index = 5199
# y index = 5202
# y index = 5205
# y index = 5208
# y index = 5211
# y index = 5214
# y index = 5217
# y index = 5220
# y index = 5223
# y index = 5226
# y index = 5229
# y index = 5232
# y index = 5235
# y index = 5238
# y index = 5241
# y index = 5244
# y index = 5247
# y index = 5250
# y index = 5253
# y index = 5256
# y index = 5259
# y index = 5262
# y index = 5265
# y index = 5268
# y index = 5271
# y index = 5274
# y index = 5277
# y index = 5280
# y index = 5283
# y index = 5286
# y index = 5289
# y index = 5292
# y index = 5295
# y index = 5298
# y index = 5301
# y index = 5304
# y index = 5307
# y index = 5310
# y index = 5313
# y index = 5316
# y index = 5319
# y index = 5322
# y index = 5325
# y index = 5328
# y index = 5331
# y index = 5334
# y index = 5337
# y index = 5340
# y index = 5343
# y index = 5346
# y index = 5349
# y index = 5352
# y index = 5355
# y index = 5358
# y index = 5361
# y index = 5364
# y index = 5367
# y index = 5370
# y index = 5373
# y index = 5376
# y index = 5379
# y index = 5382
# y index = 5385
# y index = 5388
# y index = 5391
# y index = 5394
# y index = 5397
# y index = 5400
# y index = 5403
# y index = 5406
# y index = 5409
# y index = 5412
# y index = 5415
# y index = 5418
# y index = 5421
# y index = 5424
# y index = 5427
# y index = 5430
# y index = 5433
# y index = 5436
# y index = 5439
# y index = 5442
# y index = 5445
# y index = 5448
# y index = 5451
# y index = 5454
# y index = 5457
# y index = 5460
# y index = 5463
# y index = 5466
# y index = 5469
# y index = 5472
# y index = 5475
# y index = 5478
# y index = 5481
# y index = 5484
# y index = 5487
# y index = 5490
# y index = 5493
# y index = 5496
# y index = 5499
# y index = 5502
# y index = 5505
# y index = 5508
# y index = 5511
# y index = 5514
# y index = 5517
# y index = 5520
# y index = 5523
# y index = 5526
# y index = 5529
# y index = 5532
# y index = 5535
# y index = 5538
# y index = 5541
# y index = 5544
# y index = 5547
# y index = 5550
# y index = 5553
# y index = 5556
# y index = 5559
# y index = 5562
# y index = 5565
# y index = 5568
# y index = 5571
# y index = 5574
# y index = 5577
# y index = 5580
# y index = 5583
# y index = 5586
# y index = 5589
# y index = 5592
# y index = 5595
# y index = 5598
# y index = 5601
# y index = 5604
# y index = 5607
# y index = 5610
# y index = 5613
# y index = 5616
# y index = 5619
# y index = 5622
# y index = 5625
# y index = 5628
# y index = 5631
# y index = 5634
# y index = 5637
# y index = 5640
# y index = 5643
# y index = 5646
# y index = 5649
# y index = 5652
# y index = 5655
# y index = 5658
# y index = 5661
# y index = 5664
# y index = 5667
# y index = 5670
# y index = 5673
# y index = 5676
# y index = 5679
# y index = 5682
# y index = 5685
# y index = 5688
# y index = 5691
# y index = 5694
# y index = 5697
# y index = 5700
# y index = 5703
# y index = 5706
# y index = 5709
# y index = 5712
# y index = 5715
# y index = 5718
# y index = 5721
# y index = 5724
# y index = 5727
# y index = 5730
# y index = 5733
# y index = 5736
# y index = 5739
# y index = 5742
# y index = 5745
# y index = 5748
# y index = 5751
# y index = 5754
# y index = 5757
# y index = 5760
# y index = 5763
# y index = 5766
# y index = 5769
# y index = 5772
# y index = 5775
# y index = 5778
# y index = 5781
# y index = 5784
# y index = 5787
# y index = 5790
# y index = 5793
# y index = 5796
# y index = 5799
# y index = 5802
# y index = 5805
# y index = 5808
# y index = 5811
# y index = 5814
# y index = 5817
# y index = 5820
# y index = 5823
# y index = 5826
# y index = 5829
# y index = 5832
# y index = 5835
# y index = 5838
# y index = 5841
# y index = 5844
# y index = 5847
# y index = 5850
# y index = 5853
# y index = 5856
# y index = 5859
# y index = 5862
# y index = 5865
# y index = 5868
# y index = 5871
# y index = 5874
# y index = 5877
# y index = 5880
# y index = 5883
# y index = 5886
# y index = 5889
# y index = 5892
# y index = 5895
# y index = 5898
# y index = 5901
# y index = 5904
# y index = 5907
# y index = 5910
# y index = 5913
# y index = 5916
# y index = 5919
# y index = 5922
# y index = 5925
# y index = 5928
# y index = 5931
# y index = 5934
# y index = 5937
# y index = 5940
# y index = 5943
# y index = 5946
# y index = 5949
# y index = 5952
# y index = 5955
# y index = 5958
# y index = 5961
# y index = 5964
# y index = 5967
# y index = 5970
# y index = 5973
# y index = 5976
# y index = 5979
# y index = 5982
# y index = 5985
# y index = 5988
# y index = 5991
# y index = 5994
# y index = 5997
# y index = 6000
# y index = 6003
# y index = 6006
# y index = 6009
# y index = 6012
# y index = 6015
# y index = 6018
# y index = 6021
# y index = 6024
# y index = 6027
# y index = 6030
# y index = 6033
# y index = 6036
# y index = 6039
# y index = 6042
# y index = 6045
# y index = 6048
# y index = 6051
# y index = 6054
# y index = 6057
# y index = 6060
# y index = 6063
# y index = 6066
# y index = 6069
# y index = 6072
# y index = 6075
# y index = 6078
# y index = 6081
# y index = 6084
# y index = 6087
# y index = 6090
# y index = 6093
# y index = 6096
# y index = 6099
# y index = 6102
# y index = 6105
# y index = 6108
# y index = 6111
# y index = 6114
# y index = 6117
# y index = 6120
# y index = 6123
# y index = 6126
# y index = 6129
# y index = 6132
# y index = 6135
# y index = 6138
# y index = 6141
# y index = 6144
# y index = 6147
# y index = 6150
# y index = 6153
# y index = 6156
# y index = 6159
# y index = 6162
# y index = 6165
# y index = 6168
# y index = 6171
# y index = 6174
# y index = 6177
# y index = 6180
# y index = 6183
# y index = 6186
# y index = 6189
# y index = 6192
# y index = 6195
# y index = 6198
# y index = 6201
# y index = 6204
# y index = 6207
# y index = 6210
# y index = 6213
# y index = 6216
# y index = 6219
# y index = 6222
# y index = 6225
# y index = 6228
# y index = 6231
# y index = 6234
# y index = 6237
# y index = 6240
# y index = 6243
# y index = 6246
# y index = 6249
# y index = 6252
# y index = 6255
# y index = 6258
# y index = 6261
# y index = 6264
# y index = 6267
# y index = 6270
# y index = 6273
# y index = 6276
# y index = 6279
# y index = 6282
# y index = 6285
# y index = 6288
# y index = 6291
# y index = 6294
# y index = 6297
# y index = 6300
# y index = 6303
# y index = 6306
# y index = 6309
# y index = 6312
# y index = 6315
# y index = 6318
# y index = 6321
# y index = 6324
# y index = 6327
# y index = 6330
# y index = 6333
# y index = 6336
# y index = 6339
# y index = 6342
# y index = 6345
# y index = 6348
# y index = 6351
# y index = 6354
# y index = 6357
# y index = 6360
# y index = 6363
# y index = 6366
# y index = 6369
# y index = 6372
# y index = 6375
# y index = 6378
# y index = 6381
# y index = 6384
# y index = 6387
# y index = 6390
# y index = 6393
# y index = 6396
# y index = 6399
# y index = 6402
# y index = 6405
# y index = 6408
# y index = 6411
# y index = 6414
# y index = 6417
# y index = 6420
# y index = 6423
# y index = 6426
# y index = 6429
# y index = 6432
# y index = 6435
# y index = 6438
# y index = 6441
# y index = 6444
# y index = 6447
# y index = 6450
# y index = 6453
# y index = 6456
# y index = 6459
# y index = 6462
# y index = 6465
# y index = 6468
# y index = 6471
# y index = 6474
# y index = 6477
# y index = 6480
# y index = 6483
# y index = 6486
# y index = 6489
# y index = 6492
# y index = 6495
# y index = 6498
# y index = 6501
# y index = 6504
# y index = 6507
# y index = 6510
# y index = 6513
# y index = 6516
# y index = 6519
# y index = 6522
# y index = 6525
# y index = 6528
# y index = 6531
# y index = 6534
# y index = 6537
# y index = 6540
# y index = 6543
# y index = 6546
# y index = 6549
# y index = 6552
# y index = 6555
# y index = 6558
# y index = 6561
# y index = 6564
# y index = 6567
# y index = 6570
# y index = 6573
# y index = 6576
# y index = 6579
# y index = 6582
# y index = 6585
# y index = 6588
# y index = 6591
# y index = 6594
# y index = 6597
# y index = 6600
# y index = 6603
# y index = 6606
# y index = 6609
# y index = 6612
# y index = 6615
# y index = 6618
# y index = 6621
# y index = 6624
# y index = 6627
# y index = 6630
# y index = 6633
# y index = 6636
# y index = 6639
# y index = 6642
# y index = 6645
# y index = 6648
# y index = 6651
# y index = 6654
# y index = 6657
# y index = 6660
# y index = 6663
# y index = 6666
# y index = 6669
# y index = 6672
# y index = 6675
# y index = 6678
# y index = 6681
# y index = 6684
# y index = 6687
# y index = 6690
# y index = 6693
# y index = 6696
# y index = 6699
# y index = 6702
# y index = 6705
# y index = 6708
# y index = 6711
# y index = 6714
# y index = 6717
# y index = 6720
# y index = 6723
# y index = 6726
# y index = 6729
# y index = 6732
# y index = 6735
# y index = 6738
# y index = 6741
# y index = 6744
# y index = 6747
# y index = 6750
# y index = 6753
# y index = 6756
# y index = 6759
# y index = 6762
# y index = 6765
# y index = 6768
# y index = 6771
# y index = 6774
# y index = 6777
# y index = 6780
# y index = 6783
# y index = 6786
# y index = 6789
# y index = 6792
# y index = 6795
# y index = 6798
# y index = 6801
# y index = 6804
# y index = 6807
# y index = 6810
# y index = 6813
# y index = 6816
# y index = 6819
# y index = 6822
# y index = 6825
# y index = 6828
# y index = 6831
# y index = 6834
# y index = 6837
# y index = 6840
# y index = 6843
# y index = 6846
# y index = 6849
# y index = 6852
# y index = 6855
# y index = 6858
# y index = 6861
# y index = 6864
# y index = 6867
# y index = 6870
# y index = 6873
# y index = 6876
# y index = 6879
# y index = 6882
# y index = 6885
# y index = 6888
# y index = 6891
# y index = 6894
# y index = 6897
# y index = 6900
# y index = 6903
# y index = 6906
# y index = 6909
# y index = 6912
# y index = 6915
# y index = 6918
# y index = 6921
# y index = 6924
# y index = 6927
# y index = 6930
# y index = 6933
# y index = 6936
# y index = 6939
# y index = 6942
# y index = 6945
# y index = 6948
# y index = 6951
# y index = 6954
# y index = 6957
# y index = 6960
# y index = 6963
# y index = 6966
# y index = 6969
# y index = 6972
# y index = 6975
# y index = 6978
# y index = 6981
# y index = 6984
# y index = 6987
# y index = 6990
# y index = 6993
# y index = 6996
# y index = 6999
# y index = 7002
# y index = 7005
# y index = 7008
# y index = 7011
# y index = 7014
# y index = 7017
# y index = 7020
# y index = 7023
# y index = 7026
# y index = 7029
# y index = 7032
# y index = 7035
# y index = 7038
# y index = 7041
# y index = 7044
# y index = 7047
# y index = 7050
# y index = 7053
# y index = 7056
# y index = 7059
# y index = 7062
# y index = 7065
# y index = 7068
# y index = 7071
# y index = 7074
# y index = 7077
# y index = 7080
# y index = 7083
# y index = 7086
# y index = 7089
# y index = 7092
# y index = 7095
# y index = 7098
# y index = 7101
# y index = 7104
# y index = 7107
# y index = 7110
# y index = 7113
# y index = 7116
# y index = 7119
# y index = 7122
# y index = 7125
# y index = 7128
# y index = 7131
# y index = 7134
# y index = 7137
# y index = 7140
# y index = 7143
# y index = 7146
# y index = 7149
# y index = 7152
# y index = 7155
# y index = 7158
# y index = 7161
# y index = 7164
# y index = 7167
# y index = 7170
# y index = 7173
# y index = 7176
# y index = 7179
# y index = 7182
# y index = 7185
# y index = 7188
# y index = 7191
# y index = 7194
# y index = 7197
# y index = 7200
# y index = 7203
# y index = 7206
# y index = 7209
# y index = 7212
# y index = 7215
# y index = 7218
# y index = 7221
# y index = 7224
# y index = 7227
# y index = 7230
# y index = 7233
# y index = 7236
# y index = 7239
# y index = 7242
# y index = 7245
# y index = 7248
# y index = 7251
# y index = 7254
# y index = 7257
# y index = 7260
# y index = 7263
# y index = 7266
# y index = 7269
# y index = 7272
# y index = 7275
# y index = 7278
# y index = 7281
# y index = 7284
# y index = 7287
# y index = 7290
# y index = 7293
# y index = 7296
# y index = 7299
# y index = 7302
# y index = 7305
# y index = 7308
# y index = 7311
# y index = 7314
# y index = 7317
# y index = 7320
# y index = 7323
# y index = 7326
# y index = 7329
# y index = 7332
# y index = 7335
# y index = 7338
# y index = 7341
# y index = 7344
# y index = 7347
# y index = 7350
# y index = 7353
# y index = 7356
# y index = 7359
# y index = 7362
# y index = 7365
# y index = 7368
# y index = 7371
# y index = 7374
# y index = 7377
# y index = 7380
# y index = 7383
# y index = 7386
# y index = 7389
# y index = 7392
# y index = 7395
# y index = 7398
# y index = 7401
# y index = 7404
# y index = 7407
# y index = 7410
# y index = 7413
# y index = 7416
# y index = 7419
# y index = 7422
# y index = 7425
# y index = 7428
# y index = 7431
# y index = 7434
# y index = 7437
# y index = 7440
# y index = 7443
# y index = 7446
# y index = 7449
# y index = 7452
# y index = 7455
# y index = 7458
# y index = 7461
# y index = 7464
# y index = 7467
# y index = 7470
# y index = 7473
# y index = 7476
# y index = 7479
# y index = 7482
# y index = 7485
# y index = 7488
# y index = 7491
# y index = 7494
# y index = 7497
# y index = 7500
# y index = 7503
# y index = 7506
# y index = 7509
# y index = 7512
# y index = 7515
# y index = 7518
# y index = 7521
# y index = 7524
# y index = 7527
# y index = 7530
# y index = 7533
# y index = 7536
# y index = 7539
# y index = 7542
# y index = 7545
# y index = 7548
# y index = 7551
# y index = 7554
# y index = 7557
# y index = 7560
# y index = 7563
# y index = 7566
# y index = 7569
# y index = 7572
# y index = 7575
# y index = 7578
# y index = 7581
# y index = 7584
# y index = 7587
# y index = 7590
# y index = 7593
# y index = 7596
# y index = 7599
# y index = 7602
# y index = 7605
# y index = 7608
# y index = 7611
# y index = 7614
# y index = 7617
# y index = 7620
# y index = 7623
# y index = 7626
# y index = 7629
# y index = 7632
# y index = 7635
# y index = 7638
# y index = 7641
# y index = 7644
#          94460930 function calls in 10019.564 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.001    0.000 <ipython-input-4-1993b0e73850>:7(cum_sum)
#         1 3418.663 3418.663 10019.563 10019.563 <ipython-input-8-6d931a332863>:7(reconstruct)
#         1    0.000    0.000 10019.564 10019.564 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 functional.py:2112(pad)
#   5243293   17.360    0.000  184.625    0.000 functional.py:346(argmax)
#      7647    0.116    0.000    0.163    0.000 iostream.py:195(schedule)
#      5098    0.010    0.000    0.014    0.000 iostream.py:300(_is_master_process)
#      5098    0.007    0.000    0.025    0.000 iostream.py:313(_schedule_flush)
#      5098    0.032    0.000    0.217    0.000 iostream.py:366(write)
#      7647    0.008    0.000    0.008    0.000 iostream.py:93(_event_pipe)
#         2    0.000    0.000    0.000    0.000 module.py:471(__call__)
#         2    0.000    0.000    0.000    0.000 padding.py:12(forward)
#         2    0.000    0.000    0.000    0.000 padding.py:15(forward)
#         2    0.000    0.000    0.000    0.000 padding.py:18(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:23(<listcomp>)
#         2    0.000    0.000    0.000    0.000 padding.py:24(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tensor.py:324(__rdiv__)
#      7647    0.010    0.000    0.016    0.000 threading.py:1060(_wait_for_tstate_lock)
#      7647    0.017    0.000    0.038    0.000 threading.py:1102(is_alive)
#      7647    0.005    0.000    0.005    0.000 threading.py:504(is_set)
#   5243293  123.231    0.000  123.231    0.000 {built-in method _argmax}
#         2    0.000    0.000    0.000    0.000 {built-in method apply}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000 10019.564 10019.564 {built-in method builtins.exec}
#      5098    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#      2549    0.020    0.000    0.237    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#  10486586  625.825    0.000  625.825    0.000 {built-in method conv2d}
#         4    0.000    0.000    0.000    0.000 {built-in method cumsum}
#   5243293   87.496    0.000   87.496    0.000 {built-in method exp}
#   5243293  518.626    0.000  518.626    0.000 {built-in method flip}
#         1    0.000    0.000    0.000    0.000 {built-in method log}
#  15729879 4480.014    0.000 4480.014    0.000 {built-in method max}
#      5098    0.004    0.000    0.004    0.000 {built-in method posix.getpid}
#  10486588   86.724    0.000   86.724    0.000 {built-in method squeeze}
#   5243295  313.896    0.000  313.896    0.000 {built-in method sum}
#  10486588   88.140    0.000   88.140    0.000 {built-in method unsqueeze}
#   5243298   53.447    0.000   53.447    0.000 {built-in method zeros}
#      7647    0.006    0.000    0.006    0.000 {method 'acquire' of '_thread.lock' objects}
#      7647    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#   5243293    2.892    0.000    2.892    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#        12    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#   5243297  161.869    0.000  161.869    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#   5243293   41.142    0.000   41.142    0.000 {method 'view' of 'torch._C._TensorBase' objects}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>()
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in run(statement, filename, sort)
#      14
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#      17
#      18 def runctx(statement, globals, locals, filename=None, sort=-1):
#
# /anaconda/envs/py35/lib/python3.5/profile.py in run(self, statement, filename, sort)
#      53         prof = self.profiler()
#      54         try:
# ---> 55             prof.run(statement)
#      56         except SystemExit:
#      57             pass
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in run(self, cmd)
#      93         import __main__
#      94         dict = __main__.__dict__
# ---> 95         return self.runctx(cmd, dict, dict)
#      96
#      97     def runctx(self, cmd, globals, locals):
#
# /anaconda/envs/py35/lib/python3.5/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>()
#
# <ipython-input-8-6d931a332863> in reconstruct(x, K, e, ev, emod, SPC)
#      75     z = z[:,:iyt+K-1,:ixt+K-1]
#      76     cnt = cnt[:iyt+K-1,:ixt+K-1]
# ---> 77     z /= cnt
#      78     #for i in range(NoCh2):
#      79         #z[i,:,:] /= cnt
#
# RuntimeError: Expected object of type torch.cuda.FloatTensor but found type torch.FloatTensor for argument #3 'other'

# %%
zcpu = z2.cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e3e26227800e> in <module>()
# ----> 1 zcpu = z2.cpu().numpy()
#
# NameError: name 'z2' is not defined

# %%
zcpu.shape

# %%
np.savez_compressed('reconstruction2',a=zcpu)

# %%
zmax = np.argmax(np.reshape(zcpu,(6,-1)),axis=0)
zre = np.reshape(zmax,(zcpu.shape[1],-1))
zre.shape

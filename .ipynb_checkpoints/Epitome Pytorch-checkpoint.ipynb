# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys,os,time

import numpy as np
import skimage.transform
import skimage.measure
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import rasterio

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn.feature_extraction.image import extract_patches_2d

import cProfile
import re
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

def epitome_small(x,K,N,T,NIT,sc):
    return epitome(x,K,N,T,NIT,sc,0,0)

m = nn.ConstantPad2d((1,0,1,0),0)
def cum_sum(arr, s):
    cumsum = torch.cumsum(torch.cumsum(arr,dim=2),dim=3)
    cumsum = m(cumsum)
    tot = cumsum[:,:,:-s,:-s]-cumsum[:,:,s:,:-s]-cumsum[:,:,:-s,s:]+cumsum[:,:,s:,s:]
    return tot

def to_disp(arr):
    arr_c = arr.cpu().numpy()
    arr_c = np.rollaxis(np.squeeze(arr_c),0,3)
    return arr_c

#learns N x N epitome from T, K x K patches drawn randomly from input image x.
#sc is an optional array of scales to be learnt at, At scale sc[i], T*sc[i]^2 patches are sampled.
#NIT iterations of the E-M algorithm are applied at each scale.
#e,ev = initial epitome mean and variance. If not provided, the mean is initialized
#to the uniform image with some small noise, and the variance is initialized to 1
#p returns an array of probabilities of using each part of the epitome
# the input images should have pixel values between 0 and 1.

def epitome(x,K,N,T,NIT,sc,e,ev):
    #initialize parameters
    xFIN = x
    x = F.interpolate(x,scale_factor=sc)
    x = np.clip(x,0,1)
    _, numDim, SY, SX = x.shape
    TFIN = T
    T = int(np.ceil(TFIN*sc**2))
    NFIN = N
    N = int(np.ceil(sc*NFIN))
    e = torch.zeros((1,numDim,N,N)).to(device)
    ev = torch.ones((1,numDim,N,N)).to(device)
    for i in range(numDim):
        e[:,i,:,:] = x[0,i,:,:].std()*torch.randn(N,N)/100 + x[0,i,:,:].mean() #e = mean of image plus noise
    p = torch.ones((N,N))/N**2
    MINP = 1e-6
    MINV = 1e-2
    #MINP = 1e-30
    #MINV = 1e-6
    
    #allocate space for trace of epitome and start plotting
    etr = torch.zeros((NIT+1,1,numDim,NFIN,NFIN))
    etr[0,:,:,:,:] = F.interpolate(e,size=(NFIN,NFIN))
    etri = 1
    
    plt.figure(figsize=(10,10))
    plt.imshow(to_disp(xFIN[:,:3,:,:]))
    plt.axis('off')
    plt.show()
    plt.close()
                            
    N = int(np.ceil(sc*NFIN))
    e = F.interpolate(e,[N,N])
    e = torch.clamp(e,min=0,max=1)
    ev = F.interpolate(ev,[N,N])
    ev[ev<MINV] = MINV
    #print(p.shape)
    #p = F.interpolate(p.view(1,1,N,N),[N,N])#,mode='constant')
    p /= torch.sum(p)
    x = F.interpolate(xFIN,scale_factor=sc)
    x = torch.clamp(x,min=0,max=1)
    T = int(np.ceil(sc**2*TFIN))
    lP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumP = torch.zeros((N,N),dtype=torch.float).to(device)
    sumPy = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    sumPy2 = torch.zeros((numDim,N,N),dtype=torch.float).to(device)
    ewrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)
    evwrap = torch.zeros((numDim,N+K-1,N+K-1),dtype=torch.float).to(device)

    SY = x.shape[2]
    SX = x.shape[3]

    ytemp = np.rollaxis(extract_patches_2d(torch.squeeze(x).permute(1,2,0),(K,K),max_patches=T),3,1)
    y = torch.from_numpy(ytemp).float().to(device)

    #perform NIT iterations of EM algorithm
    lPtr = torch.zeros((NIT,1)).float().to(device)
    for nit in range(NIT):
        #glues together borders of e
        ewrap[:,:N,:N] = e;
        ewrap[:,N:,:] = ewrap[:,:K-1,:]
        ewrap[:,:,N:] = ewrap[:,:,:K-1]
        evwrap[:,:N,:N] = ev
        evwrap[:,N:,:] = evwrap[:,:K-1,:]
        evwrap[:,:,N:] = evwrap[:,:,:K-1]
        logevwrap = torch.log(evwrap)
        evwrapi = 1./evwrap

        # E STEP
        sumP[:,:] = 0
        sumPy[:,:,:] = 0
        sumPy2[:,:,:] = 0
        for t in range(T):
            #get current training case
            yc = y[t,:,:,:]
            yct = torch.flip(yc,[1,2])
            yct = torch.unsqueeze(yc,0)
            #print(yct.shape)
            #compute posterior over patch location
            lP[:,:] = torch.log(p)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrapi,0),yct))
            tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
            tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K)),dim=0)
            lP -= .5*(tmp4+tmp1-2*tmp2+tmp3)
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            nrmP = torch.sum(P)
            P /= nrmP
            lPtr[nit] += mxlP + torch.log(nrmP)

            tmp = P.view(1,1,N,N)
            cp = nn.ConstantPad2d((K-1,K-1,K-1,K-1),0)
            tmp = cp(tmp)
            tmp = torch.squeeze(cum_sum(tmp,K)).to(device)
            tmp[:,:K-1] += tmp[:,N:]
            tmp[:K-1,:] += tmp[N:,:]
            sumP += tmp[:N,:N]
            for i in range(numDim):
                #mean
                tmpP = torch.unsqueeze(torch.unsqueeze(cp(P),0),0)
                #print(P.shape,tmpP.shape,K)
                yctmp = yc[i,:,:].view(1,1,K,K)
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp)).to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy[i,:,:] += tmp[:N,:N]

                #variance
                tmp = torch.squeeze(F.conv2d(tmpP,yctmp**2)).to(device)
                tmp[:,:K-1] += tmp[:,N:]
                tmp[:K-1,:] += tmp[N:,:]
                sumPy2[i,:,:] += tmp[:N,:N]

        torch.cuda.empty_cache()
        #M STEP
        p = sumP/torch.sum(sumP)
        for i in range(numDim):
            e[0,i,:,:] = sumPy[i,:,:]/sumP
            ev[0,i,:,:] = sumPy2[i,:,:]/sumP - 2*e[0,i,:,:]*sumPy[i,:,:]/sumP + e[0,i,:,:]**2
        ev = torch.clamp(ev,min=MINV)
        etemp = F.interpolate(e,size=(NFIN,NFIN))
        #print(torch.mode(etemp.view(1,-1)))
        etr[etri,:,:,:] = etemp
        etri += 1

        rows,cols = 1,3
        fig=plt.figure(figsize=(cols*5,rows*5))

        fig.add_subplot(rows, cols, 1)
        plt.axis('off')
        #print(etr.shape)
        td = to_disp(etr[etri-1,:,:3,:,:])
        #print(td.shape,np.min(td),np.max(td))
        plt.imshow(td)
        plt.title(str(N)+'x'+str(N)+' epitome')

        fig.add_subplot(rows, cols, 2)
        plt.axis('off')
        plt.imshow(p,cmap='hot',interpolation='nearest')
        plt.title('mixing proportions')

        fig.add_subplot(rows, cols, 3)
        plt.axis('off')
        tmp = np.sum(np.squeeze(ev.cpu().numpy()),axis=0)
        plt.imshow(tmp,cmap='hot',interpolation='nearest')
        curr_var = np.max(tmp)
        plt.title('variances, max='+str(max(tmp.flatten())))

        plt.show()
        plt.close()
    return e,ev,p,etr

# %%
p = pd.read_csv("big_lc_paths.csv", header=None)
paths = p[0].tolist()

def fn(i):
    return paths[i].replace('/','-')[:-7]

naip_tile = rasterio.open("/mnt/blobfuse/esri-naip/"+fn(0).replace('-','/')+".mrf",'r')
naip = naip_tile.read().astype(float)
naip_tile.close()

lc_tile = rasterio.open('/mnt/blobfuse/resampled-lc/'+paths[0],'r')
lc = np.squeeze(lc_tile.read())
lc_tile.close()

trIM = np.zeros((10,naip.shape[1],naip.shape[2]),dtype=float)
trIM[:4,:,:] = naip/255.
for i in range(6):
    trIM[4+i,:,:] = (lc==i)
trIM = np.expand_dims(trIM,axis=0)
trIMtorch = torch.from_numpy(trIM).float().to(device)
    
tsIMtorch = trIMtorch

# %%
# %%time
#sc will be changed to a single number
#instead repeatedly call the method to create epitomes at different scales
#e, ev, p, etr = epitome_small(trIMtorch,8,128,3000,30,[.5]) #scale could be [.125 .25 .5 .75]
cProfile.run('e, ev, p, etr = epitome_small(trIMtorch,8,128,3000,10,.5)')
torch.cuda.empty_cache()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides
#          6341280 function calls (6303984 primitive calls) in 71.261 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        11    0.000    0.000    0.002    0.000 <decorator-gen-10>:1(__call__)
#        11    0.000    0.000    0.001    0.000 <decorator-gen-11>:1(__call__)
#        11    0.000    0.000    0.000    0.000 <decorator-gen-12>:1(__call__)
#        99    0.000    0.000    3.527    0.036 <decorator-gen-9>:1(__call__)
#      1077    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:995(_handle_fromlist)
#        11    0.000    0.000    0.193    0.018 <ipython-input-3-8d36289f28d1>:13(to_disp)
#         1   32.350   32.350   71.261   71.261 <ipython-input-3-8d36289f28d1>:26(epitome)
#         1    0.000    0.000   71.261   71.261 <ipython-input-3-8d36289f28d1>:3(epitome_small)
#     22500    2.436    0.000    5.572    0.000 <ipython-input-3-8d36289f28d1>:7(cum_sum)
#         1    0.000    0.000   71.261   71.261 <string>:1(<module>)
#      4988    0.004    0.000    0.007    0.000 <string>:12(__new__)
#        66    0.000    0.000    0.000    0.000 __init__.py:1155(__init__)
#       275    0.003    0.000    0.003    0.000 __init__.py:1160(__setitem__)
#        11    0.000    0.000    0.000    0.000 __init__.py:1176(__init__)
#        92    0.000    0.000    0.000    0.000 __init__.py:1206(push)
#        53    0.000    0.000    0.000    0.000 __init__.py:1226(clear)
#        31    0.000    0.000    0.000    0.000 __init__.py:1231(bubble)
#         2    0.000    0.000    0.000    0.000 __init__.py:1263(debug)
#        31    0.000    0.000    0.333    0.011 __init__.py:1363(safe_masked_invalid)
#        11    0.000    0.000    0.000    0.000 __init__.py:1419(get_backend)
#        22    0.000    0.000    0.000    0.000 __init__.py:1433(is_interactive)
#        22    0.000    0.000    0.000    0.000 __init__.py:1483(__init__)
#        62    0.000    0.000    0.000    0.000 __init__.py:1488(__contains__)
#       341    0.000    0.000    0.001    0.000 __init__.py:1491(clean)
#       341    0.000    0.000    0.000    0.000 __init__.py:1496(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1507(getEffectiveLevel)
#         2    0.000    0.000    0.000    0.000 __init__.py:1521(isEnabledFor)
#       279    0.001    0.000    0.002    0.000 __init__.py:1564(get_siblings)
#       279    0.000    0.000    0.000    0.000 __init__.py:1571(<listcomp>)
#       212    0.001    0.000    0.001    0.000 __init__.py:161(__init__)
#        31    0.000    0.000    0.569    0.018 __init__.py:1774(inner)
#        62    0.000    0.000    0.001    0.000 __init__.py:1789(<genexpr>)
#        44    0.000    0.000    0.007    0.000 __init__.py:182(dumps)
#       106    0.000    0.000    0.000    0.000 __init__.py:183(add_destroy_callback)
#       335    0.001    0.000    0.001    0.000 __init__.py:2026(is_math_text)
#      2515    0.003    0.000    0.012    0.000 __init__.py:2042(_to_unmasked_float_array)
#       745    0.000    0.000    0.000    0.000 __init__.py:2311(<lambda>)
#       124    0.000    0.000    0.001    0.000 __init__.py:2346(safe_first_element)
#        31    0.000    0.000    0.001    0.000 __init__.py:2362(sanitize_sequence)
#       212    0.000    0.000    0.000    0.000 __init__.py:249(__hash__)
#        31    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:29(get_config)
#       529    0.001    0.000    0.001    0.000 __init__.py:313(__init__)
#       106    0.001    0.000    0.002    0.000 __init__.py:333(connect)
#        10    0.000    0.000    0.001    0.000 __init__.py:354(empty_cache)
#        11    0.000    0.000    0.001    0.000 __init__.py:362(disconnect)
#       943    0.000    0.000    0.000    0.000 __init__.py:378(process)
#      5765    0.004    0.000    0.005    0.000 __init__.py:518(iterable)
#        31    0.000    0.000    0.000    0.000 __init__.py:52(get_projection_class)
#      3215    0.003    0.000    0.016    0.000 __init__.py:584(is_numlike)
#        22    0.000    0.000    0.000    0.000 __init__.py:589(to_filehandle)
#        44    0.000    0.000    0.000    0.000 __init__.py:621(open_file_cm)
#       558    0.000    0.000    0.000    0.000 __init__.py:637(_string_to_bool)
#        31    0.000    0.000    0.001    0.000 __init__.py:68(process_projection_requirements)
#     86194    0.051    0.000    0.051    0.000 __init__.py:931(__getitem__)
#        30    0.000    0.000    0.006    0.000 _axes.py:141(set_title)
#        31    0.001    0.000    0.567    0.018 _axes.py:5348(imshow)
#        61    0.001    0.000    0.005    0.000 _base.py:1166(_set_title_offset_trans)
#       124    0.000    0.000    0.000    0.000 _base.py:1287(get_aspect)
#        93    0.000    0.000    0.001    0.000 _base.py:1290(set_aspect)
#        93    0.000    0.000    0.000    0.000 _base.py:1365(set_adjustable)
#        62    0.000    0.000    0.000    0.000 _base.py:1412(get_anchor)
#        62    0.000    0.000    0.001    0.000 _base.py:1483(get_data_ratio)
#        93    0.002    0.000    0.013    0.000 _base.py:1511(apply_aspect)
#        62    0.000    0.000    0.000    0.000 _base.py:155(__init__)
#        31    0.000    0.000    0.001    0.000 _base.py:1662(axis)
#        62    0.000    0.000    0.000    0.000 _base.py:168(set_prop_cycle)
#        31    0.000    0.000    0.000    0.000 _base.py:1826(_sci)
#        31    0.000    0.000    0.001    0.000 _base.py:1903(add_image)
#        31    0.000    0.000    0.002    0.000 _base.py:2108(update_datalim)
#        62    0.000    0.000    0.002    0.000 _base.py:2130(_process_unit_info)
#        62    0.000    0.000    0.000    0.000 _base.py:2523(_get_axis_list)
#        62    0.001    0.000    1.308    0.021 _base.py:2528(draw)
#        62    0.000    0.000    0.197    0.003 _base.py:2678(grid)
#        62    0.000    0.000    0.005    0.000 _base.py:2848(tick_params)
#        31    0.000    0.000    0.000    0.000 _base.py:2947(set_axis_off)
#        31    0.000    0.000    0.000    0.000 _base.py:2952(set_axis_on)
#        62    0.000    0.000    0.000    0.000 _base.py:2968(get_xbound)
#       155    0.001    0.000    0.001    0.000 _base.py:3006(get_xlim)
#       248    0.001    0.000    0.003    0.000 _base.py:3024(_validate_converted_limits)
#        62    0.001    0.000    0.008    0.000 _base.py:3043(set_xlim)
#       155    0.000    0.000    0.000    0.000 _base.py:3150(get_xscale)
#        62    0.000    0.000    0.000    0.000 _base.py:3308(get_ybound)
#       155    0.001    0.000    0.001    0.000 _base.py:3345(get_ylim)
#        62    0.001    0.000    0.005    0.000 _base.py:3363(set_ylim)
#       155    0.000    0.000    0.000    0.000 _base.py:3470(get_yscale)
#        31    0.000    0.000    0.000    0.000 _base.py:3716(set_navigate)
#        31    0.000    0.000    0.000    0.000 _base.py:3734(set_navigate_mode)
#       124    0.001    0.000    0.001    0.000 _base.py:4081(get_children)
#        31    0.000    0.000    0.000    0.000 _base.py:4133(get_default_bbox_extra_artists)
#        31    0.000    0.000    0.000    0.000 _base.py:4134(<listcomp>)
#        31    0.001    0.000    0.979    0.032 _base.py:4137(get_tightbbox)
#        31    0.000    0.000    0.000    0.000 _base.py:4185(<listcomp>)
#        31    0.002    0.000    0.480    0.015 _base.py:423(__init__)
#        31    0.000    0.000    0.000    0.000 _base.py:481(<listcomp>)
#        62    0.000    0.000    0.002    0.000 _base.py:604(get_window_extent)
#        31    0.000    0.000    0.060    0.002 _base.py:615(_init_axis)
#        31    0.000    0.000    0.004    0.000 _base.py:625(set_figure)
#        31    0.000    0.000    0.002    0.000 _base.py:647(_set_lim_and_transforms)
# 3410/1860    0.003    0.000    0.009    0.000 _base.py:686(get_xaxis_transform)
#       372    0.002    0.000    0.011    0.000 _base.py:711(get_xaxis_text1_transform)
#       372    0.002    0.000    0.009    0.000 _base.py:739(get_xaxis_text2_transform)
# 3419/1865    0.003    0.000    0.009    0.000 _base.py:766(get_yaxis_transform)
#       373    0.002    0.000    0.011    0.000 _base.py:791(get_yaxis_text1_transform)
#       373    0.002    0.000    0.009    0.000 _base.py:818(get_yaxis_text2_transform)
#        62    0.000    0.000    0.004    0.000 _base.py:846(_update_transScale)
#        93    0.000    0.000    0.001    0.000 _base.py:857(get_position)
#        93    0.000    0.000    0.004    0.000 _base.py:903(_set_position)
#        93    0.000    0.000    0.000    0.000 _base.py:930(set_axes_locator)
#       124    0.000    0.000    0.000    0.000 _base.py:946(get_axes_locator)
#       124    0.000    0.000    0.001    0.000 _base.py:952(_set_artist_props)
#        31    0.000    0.000    0.005    0.000 _base.py:962(_gen_axes_patch)
#        31    0.000    0.000    0.029    0.001 _base.py:978(_gen_axes_spines)
#        31    0.002    0.000    0.378    0.012 _base.py:998(cla)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:201(__subclasshook__)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:204(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:221(__subclasshook__)
#        18    0.000    0.000    0.000    0.000 _collections_abc.py:224(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:285(__subclasshook__)
#       162    0.000    0.000    0.000    0.000 _collections_abc.py:310(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:313(<genexpr>)
#       124    0.001    0.000    0.002    0.000 _methods.py:151(_ptp)
#      1142    0.001    0.000    0.109    0.000 _methods.py:26(_amax)
#       840    0.001    0.000    0.112    0.000 _methods.py:30(_amin)
#       125    0.000    0.000    0.051    0.000 _methods.py:34(_sum)
#        74    0.000    0.000    0.016    0.000 _methods.py:42(_any)
#       974    0.001    0.000    0.008    0.000 _methods.py:45(_all)
#       145    0.000    0.000    0.000    0.000 _pylab_helpers.py:105(get_active)
#        11    0.000    0.000    0.000    0.000 _pylab_helpers.py:115(set_active)
#        11    0.000    0.000    0.000    0.000 _pylab_helpers.py:35(get_fig_manager)
#        11    0.000    0.000    0.012    0.001 _pylab_helpers.py:71(destroy_all)
#        22    0.000    0.000    0.000    0.000 _pylab_helpers.py:91(get_all_fig_managers)
#        31    0.000    0.000    0.000    0.000 _subplots.py:123(get_subplotspec)
#        31    0.000    0.000    0.007    0.000 _subplots.py:131(update_params)
#        31    0.000    0.000    0.000    0.000 _subplots.py:201(subplot_class_factory)
#        31    0.000    0.000    0.488    0.016 _subplots.py:25(__init__)
#       243    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       243    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#       243    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#        67    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#       210    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       329    0.000    0.000    0.001    0.000 _weakrefset.py:58(__iter__)
#     24271    0.022    0.000    0.022    0.000 _weakrefset.py:70(__contains__)
#       211    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#     18771    0.028    0.000    0.054    0.000 abc.py:178(__instancecheck__)
#    341/13    0.002    0.000    0.004    0.000 abc.py:194(__subclasscheck__)
#       124    0.000    0.000    0.000    0.000 artist.py:1049(mouseover)
#      4135    0.003    0.000    0.010    0.000 artist.py:184(convert_xunits)
#      4135    0.002    0.000    0.006    0.000 artist.py:193(convert_yunits)
#     39924    0.006    0.000    0.006    0.000 artist.py:202(axes)
#      6094    0.002    0.000    0.002    0.000 artist.py:210(axes)
# 93325/77280    0.050    0.000    0.079    0.000 artist.py:230(stale)
#        62    0.000    0.000    0.001    0.000 artist.py:243(get_window_extent)
#     16994    0.014    0.000    0.032    0.000 artist.py:288(pchanged)
#       124    0.000    0.000    0.000    0.000 artist.py:296(is_transform_set)
#      4353    0.004    0.000    0.017    0.000 artist.py:303(set_transform)
#      2068    0.002    0.000    0.002    0.000 artist.py:317(get_transform)
#    354/22    0.002    0.000    1.316    0.060 artist.py:47(draw_wrapper)
#        62    0.000    0.000    0.000    0.000 artist.py:475(get_url)
#        31    0.000    0.000    0.000    0.000 artist.py:479(set_url)
#       144    0.000    0.000    0.000    0.000 artist.py:490(get_gid)
#        22    0.000    0.000    0.000    0.000 artist.py:505(get_snap)
#        22    0.000    0.000    0.000    0.000 artist.py:544(get_sketch_params)
#        82    0.000    0.000    0.000    0.000 artist.py:605(get_path_effects)
#        62    0.000    0.000    0.000    0.000 artist.py:608(get_figure)
#      4977    0.006    0.000    0.019    0.000 artist.py:612(set_figure)
#       183    0.000    0.000    0.001    0.000 artist.py:637(set_clip_box)
#       465    0.004    0.000    0.062    0.000 artist.py:650(set_clip_path)
#     10412    0.010    0.000    0.027    0.000 artist.py:66(_stale_axes_callback)
#       184    0.000    0.000    0.000    0.000 artist.py:704(get_alpha)
#      3221    0.001    0.000    0.001    0.000 artist.py:711(get_visible)
#     93387    0.012    0.000    0.012    0.000 artist.py:715(get_animated)
#       372    0.000    0.000    0.000    0.000 artist.py:719(get_clip_on)
#       372    0.000    0.000    0.000    0.000 artist.py:723(get_clip_box)
#       403    0.000    0.000    0.000    0.000 artist.py:727(get_clip_path)
#       144    0.000    0.000    0.000    0.000 artist.py:759(_set_gc_clip)
#       708    0.000    0.000    0.000    0.000 artist.py:769(get_rasterized)
#       708    0.000    0.000    0.000    0.000 artist.py:789(get_agg_filter)
#       776    0.001    0.000    0.003    0.000 artist.py:814(set_alpha)
#       124    0.000    0.000    0.001    0.000 artist.py:828(set_visible)
#      4033    0.013    0.000    0.039    0.000 artist.py:854(update)
#      2355    0.005    0.000    0.017    0.000 artist.py:858(_update_property)
#      4988    0.097    0.000    0.116    0.000 artist.py:87(__init__)
#      4033    0.003    0.000    0.020    0.000 artist.py:887(<listcomp>)
#        31    0.000    0.000    0.000    0.000 artist.py:897(get_label)
#        62    0.000    0.000    0.000    0.000 artist.py:901(set_label)
#        62    0.000    0.000    0.000    0.000 artist.py:920(get_zorder)
#      1614    0.002    0.000    0.007    0.000 artist.py:924(set_zorder)
#      8762    0.001    0.000    0.001    0.000 artist.py:940(sticky_edges)
#      2175    0.010    0.000    0.016    0.000 artist.py:963(update_from)
#       124    0.006    0.000    0.719    0.006 axis.py:1020(_update_ticks)
#       124    0.002    0.000    0.174    0.001 axis.py:1119(_get_tick_bboxes)
#        62    0.002    0.000    0.956    0.015 axis.py:1137(get_tightbbox)
#        62    0.000    0.000    0.001    0.000 axis.py:1165(<listcomp>)
#       124    0.000    0.000    0.001    0.000 axis.py:1172(get_tick_padding)
#       435    0.002    0.000    0.080    0.000 axis.py:1357(_copy_tick_props)
#       124    0.002    0.000    0.483    0.004 axis.py:1393(get_major_ticks)
#       124    0.000    0.000    0.000    0.000 axis.py:1408(get_minor_ticks)
#       124    0.001    0.000    0.196    0.002 axis.py:1423(grid)
#       124    0.000    0.000    0.000    0.000 axis.py:1439(<dictcomp>)
#        62    0.000    0.000    0.002    0.000 axis.py:1456(update_units)
#       372    0.000    0.000    0.000    0.000 axis.py:1478(_update_axisinfo)
#        62    0.000    0.000    0.000    0.000 axis.py:1512(have_units)
#       980    0.001    0.000    0.007    0.000 axis.py:1515(convert_units)
#       372    0.001    0.000    0.002    0.000 axis.py:1529(set_units)
#       496    0.001    0.000    0.002    0.000 axis.py:1566(set_major_formatter)
#       496    0.001    0.000    0.002    0.000 axis.py:1577(set_minor_formatter)
#       496    0.001    0.000    0.003    0.000 axis.py:1588(set_major_locator)
#       496    0.001    0.000    0.002    0.000 axis.py:1599(set_minor_locator)
#       745    0.000    0.000    0.000    0.000 axis.py:172(<dictcomp>)
#       372    0.002    0.000    0.356    0.001 axis.py:1787(_get_tick)
#        31    0.000    0.000    0.004    0.000 axis.py:1794(_get_label)
#        31    0.000    0.000    0.003    0.000 axis.py:1812(_get_offset_text)
#       124    0.001    0.000    0.017    0.000 axis.py:1827(_get_pixel_distance_along_axis)
#        31    0.000    0.000    0.127    0.004 axis.py:1877(_get_tick_boxes_siblings)
#        31    0.001    0.000    0.140    0.005 axis.py:1896(_update_label_position)
#       745    0.001    0.000    0.002    0.000 axis.py:192(_set_labelrotation)
#        31    0.000    0.000    0.008    0.000 axis.py:1939(_update_offset_text_position)
#       248    0.000    0.000    0.001    0.000 axis.py:2062(get_view_interval)
#        62    0.000    0.000    0.000    0.000 axis.py:2087(get_minpos)
#        62    0.001    0.000    0.062    0.001 axis.py:2121(get_tick_space)
#       993    0.001    0.000    0.001    0.000 axis.py:215(get_tick_padding)
#       373    0.002    0.000    0.416    0.001 axis.py:2159(_get_tick)
#        31    0.000    0.000    0.003    0.000 axis.py:2166(_get_label)
#        31    0.000    0.000    0.004    0.000 axis.py:2186(_get_offset_text)
#       124    0.001    0.000    0.011    0.000 axis.py:2202(_get_pixel_distance_along_axis)
#        31    0.000    0.000    0.124    0.004 axis.py:2246(_get_tick_boxes_siblings)
#        31    0.001    0.000    0.136    0.004 axis.py:2265(_update_label_position)
#        31    0.000    0.000    0.001    0.000 axis.py:2307(_update_offset_text_position)
#       186    0.000    0.000    0.049    0.000 axis.py:231(set_clip_path)
#       248    0.000    0.000    0.001    0.000 axis.py:2440(get_view_interval)
#        62    0.000    0.000    0.000    0.000 axis.py:2466(get_minpos)
#        62    0.001    0.000    0.061    0.001 axis.py:2500(get_tick_space)
#      1118    0.001    0.000    0.006    0.000 axis.py:311(set_label1)
#      1118    0.001    0.000    0.006    0.000 axis.py:322(set_label2)
#      3725    0.003    0.000    0.016    0.000 axis.py:331(_set_artist_props)
#       434    0.002    0.000    0.004    0.000 axis.py:338(_apply_params)
#       434    0.000    0.000    0.000    0.000 axis.py:340(<listcomp>)
#       434    0.000    0.000    0.000    0.000 axis.py:343(<listcomp>)
#       434    0.000    0.000    0.000    0.000 axis.py:363(<dictcomp>)
#       434    0.000    0.000    0.000    0.000 axis.py:376(<listcomp>)
#       434    0.000    0.000    0.000    0.000 axis.py:389(<listcomp>)
#       372    0.001    0.000    0.011    0.000 axis.py:415(_get_text1_transform)
#       372    0.001    0.000    0.009    0.000 axis.py:418(_get_text2_transform)
#       372    0.001    0.000    0.004    0.000 axis.py:421(apply_tickdir)
#       372    0.003    0.000    0.045    0.000 axis.py:435(_get_text1)
#       372    0.002    0.000    0.037    0.000 axis.py:452(_get_text2)
#       372    0.003    0.000    0.079    0.000 axis.py:468(_get_tick1line)
#       372    0.003    0.000    0.072    0.000 axis.py:479(_get_tick2line)
#       372    0.003    0.000    0.095    0.000 axis.py:494(_get_gridline)
#       930    0.002    0.000    0.009    0.000 axis.py:510(update_position)
#       373    0.001    0.000    0.011    0.000 axis.py:538(_get_text1_transform)
#       373    0.001    0.000    0.009    0.000 axis.py:541(_get_text2_transform)
#       373    0.001    0.000    0.004    0.000 axis.py:544(apply_tickdir)
#       373    0.003    0.000    0.111    0.000 axis.py:559(_get_text1)
#       373    0.002    0.000    0.039    0.000 axis.py:574(_get_text2)
#       373    0.003    0.000    0.076    0.000 axis.py:589(_get_tick1line)
#       373    0.003    0.000    0.070    0.000 axis.py:604(_get_tick2line)
#       373    0.003    0.000    0.093    0.000 axis.py:618(_get_gridline)
#       933    0.003    0.000    0.009    0.000 axis.py:633(update_position)
#   186/124    0.001    0.000    0.252    0.002 axis.py:670(__get__)
#        62    0.001    0.000    0.037    0.001 axis.py:705(__init__)
#       745    0.016    0.000    0.768    0.001 axis.py:74(__init__)
#       124    0.000    0.000    0.001    0.000 axis.py:764(get_transform)
#       310    0.000    0.000    0.000    0.000 axis.py:767(get_scale)
#       496    0.001    0.000    0.070    0.000 axis.py:770(_set_scale)
#       124    0.000    0.000    0.001    0.000 axis.py:779(limit_range_for_scale)
#       372    0.002    0.000    0.061    0.000 axis.py:801(cla)
#       496    0.002    0.000    0.002    0.000 axis.py:824(reset_ticks)
#       248    0.001    0.000    0.199    0.001 axis.py:844(set_tick_params)
#       248    0.001    0.000    0.002    0.000 axis.py:875(_translate_tick_kw)
#        62    0.000    0.000    0.120    0.002 axis.py:927(set_clip_path)
#       124    0.000    0.000    0.000    0.000 axis.py:962(_set_artist_props)
#      1242    0.002    0.000    0.659    0.001 axis.py:967(iter_ticks)
#       124    0.002    0.000    0.010    0.000 axis.py:974(<listcomp>)
#       124    0.000    0.000    0.000    0.000 axis.py:980(<listcomp>)
#        22    0.000    0.000    0.000    0.000 backend_agg.py:127(_update_methods)
#        22    0.000    0.000    0.001    0.000 backend_agg.py:142(draw_path)
#        60    0.001    0.000    0.039    0.001 backend_agg.py:190(draw_text)
#       550    0.003    0.000    0.084    0.000 backend_agg.py:220(get_text_width_height_descent)
#        60    0.000    0.000    0.000    0.000 backend_agg.py:267(get_canvas_width_height)
#       610    0.002    0.000    0.032    0.000 backend_agg.py:271(_get_agg_font)
#        84    0.000    0.000    0.000    0.000 backend_agg.py:303(option_image_nocomposite)
#        22    0.000    0.000    1.331    0.061 backend_agg.py:421(draw)
#        44    0.000    0.000    0.016    0.000 backend_agg.py:442(get_renderer)
#        22    0.001    0.000    2.460    0.112 backend_agg.py:512(print_png)
#       610    0.002    0.000    0.003    0.000 backend_agg.py:55(get_hinting_flag)
#        22    0.012    0.001    0.014    0.001 backend_agg.py:91(__init__)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1003(set_alpha)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1019(set_antialiased)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1030(set_capstyle)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:1039(set_clip_rectangle)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1045(set_clip_path)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1056(set_dashes)
#       226    0.000    0.000    0.000    0.000 backend_bases.py:1077(set_foreground)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1094(set_joinstyle)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1103(set_linewidth)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1120(set_url)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:1126(set_gid)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1132(set_snap)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1151(get_hatch)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1157(get_hatch_path)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1166(get_hatch_color)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1178(get_hatch_linewidth)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:1184(get_sketch_params)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1404(__init__)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1441(__init__)
#        11    0.000    0.000    0.007    0.001 backend_bases.py:153(new_figure_manager)
#        11    0.000    0.000    0.001    0.000 backend_bases.py:163(new_figure_manager_given_figure)
#        11    0.000    0.000    0.001    0.000 backend_bases.py:1770(__init__)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:1793(is_saving)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:1838(draw_event)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:2046(draw)
#        11    0.000    0.000    0.000    0.000 backend_bases.py:2087(_get_output_canvas)
#        11    0.003    0.000    3.524    0.320 backend_bases.py:2107(print_figure)
#        44    0.000    0.000    0.001    0.000 backend_bases.py:2337(mpl_connect)
#        11    0.000    0.000    0.001    0.000 backend_bases.py:2391(mpl_disconnect)
#        22    0.000    0.000    0.000    0.000 backend_bases.py:263(__init__)
#        11    0.000    0.000    0.000    0.000 backend_bases.py:2669(__init__)
#       166    0.000    0.000    0.000    0.000 backend_bases.py:267(open_group)
#        11    0.000    0.000    0.000    0.000 backend_bases.py:2689(destroy)
#       166    0.000    0.000    0.000    0.000 backend_bases.py:274(close_group)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:563(get_image_magnification)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:766(flipy)
#       144    0.000    0.000    0.003    0.000 backend_bases.py:787(new_gc)
#       144    0.001    0.000    0.002    0.000 backend_bases.py:849(__init__)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:890(restore)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:920(get_clip_path)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:930(get_dashes)
#       144    0.000    0.000    0.000    0.000 backend_bases.py:990(get_snap)
#        11    0.000    0.000    3.567    0.324 backend_inline.py:18(show)
#        11    0.000    0.000    0.000    0.000 backend_inline.py:51(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 base.py:1202(isspmatrix)
#        10    0.000    0.000    0.000    0.000 bunch.py:11(__getattr__)
#        42    0.000    0.000    0.000    0.000 cm.py:140(get_cmap)
#        31    0.000    0.000    0.000    0.000 cm.py:178(__init__)
#        62    0.010    0.000    0.048    0.001 cm.py:208(to_rgba)
#        62    0.000    0.000    0.000    0.000 cm.py:290(get_array)
#        31    0.000    0.000    0.109    0.004 cm.py:356(autoscale_None)
#        31    0.000    0.000    0.000    0.000 cm.py:383(changed)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#         4    0.000    0.000    0.000    0.000 codecs.py:318(decode)
#      1388    0.001    0.000    0.005    0.000 colors.py:107(_is_nth_color)
#      1388    0.003    0.000    0.015    0.000 colors.py:142(to_rgba)
#         2    0.000    0.000    0.000    0.000 colors.py:176(_to_rgba_no_colorcycle)
#         3    0.000    0.000    0.000    0.000 colors.py:362(makeMappingArray)
#        40    0.007    0.000    0.028    0.001 colors.py:457(__call__)
#         1    0.000    0.000    0.000    0.000 colors.py:578(_set_extremes)
#         1    0.000    0.000    0.000    0.000 colors.py:685(_init)
#        31    0.000    0.000    0.000    0.000 colors.py:874(__init__)
#       120    0.001    0.000    0.008    0.000 colors.py:896(process_value)
#        40    0.003    0.000    0.014    0.000 colors.py:927(__call__)
#        62    0.000    0.000    0.000    0.000 colors.py:97(_sanitize_extrema)
#        71    0.000    0.000    0.108    0.002 colors.py:987(autoscale_None)
#        20    0.000    0.000    0.000    0.000 configurable.py:102(<listcomp>)
#      10/2    0.000    0.000    0.000    0.000 configurable.py:106(_find_my_config)
#         2    0.000    0.000    0.000    0.000 configurable.py:131(_load_config)
#         2    0.000    0.000    0.001    0.000 configurable.py:170(_config_changed)
#         2    0.000    0.000    0.001    0.000 configurable.py:38(__init__)
#        33    0.000    0.000    0.000    0.000 configurable.py:381(instance)
#        11    0.000    0.000    0.000    0.000 configurable.py:426(initialized)
#        20    0.000    0.000    0.000    0.000 configurable.py:99(section_names)
#       102    0.000    0.000    0.000    0.000 contextlib.py:135(helper)
#       102    0.000    0.000    0.000    0.000 contextlib.py:37(__init__)
#       102    0.000    0.000    0.000    0.000 contextlib.py:57(__enter__)
#       102    0.000    0.000    0.000    0.000 contextlib.py:63(__exit__)
#        31    0.000    0.000    0.000    0.000 copy.py:269(_reconstruct)
#        31    0.000    0.000    0.001    0.000 copy.py:67(copy)
#        31    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         1    0.000    0.000    0.000    0.000 copyreg.py:96(_slotnames)
#       280    0.000    0.000    0.000    0.000 core.py:1280(_replace_dtype_fields_recursive)
#       280    0.000    0.000    0.001    0.000 core.py:1312(_replace_dtype_fields)
#       280    0.000    0.000    0.001    0.000 core.py:1326(make_mask_descr)
#       755    0.000    0.000    0.001    0.000 core.py:1359(getmask)
#        31    0.000    0.000    0.015    0.000 core.py:1546(_shrink_mask)
#       164    0.000    0.000    0.000    0.000 core.py:1818(_check_mask_axis)
#       204    0.000    0.000    0.001    0.000 core.py:214(_recursive_fill_value)
#       204    0.000    0.000    0.001    0.000 core.py:229(_get_dtype_of)
#        31    0.116    0.004    0.117    0.004 core.py:2328(masked_invalid)
#        40    0.000    0.000    0.000    0.000 core.py:239(default_fill_value)
#       280    0.002    0.000    0.013    0.000 core.py:2772(__new__)
#        40    0.000    0.000    0.000    0.000 core.py:284(_scalar_fill_value)
#       515    0.003    0.000    0.005    0.000 core.py:2902(_update_from)
#       515    0.003    0.000    0.010    0.000 core.py:2928(__array_finalize__)
#       164    0.000    0.000    0.002    0.000 core.py:294(_extremum_fill_value)
#       164    0.000    0.000    0.001    0.000 core.py:296(_scalar_fill_value)
#        82    0.000    0.000    0.001    0.000 core.py:309(minimum_fill_value)
#       160    0.001    0.000    0.001    0.000 core.py:3158(__getitem__)
#        80    0.000    0.000    0.000    0.000 core.py:3175(_scalar_heuristic)
#      1680    0.001    0.000    0.001    0.000 core.py:3345(dtype)
#       854    0.001    0.000    0.001    0.000 core.py:3361(shape)
#       120    0.000    0.000    0.000    0.000 core.py:3444(_get_mask)
#        31    0.000    0.000    0.016    0.001 core.py:3531(shrink_mask)
#       524    0.001    0.000    0.001    0.000 core.py:3560(_get_data)
#        40    0.000    0.000    0.000    0.000 core.py:3582(get_fill_value)
#        82    0.000    0.000    0.001    0.000 core.py:360(maximum_fill_value)
#       204    0.000    0.000    0.002    0.000 core.py:3659(filled)
#        40    0.000    0.000    0.000    0.000 core.py:443(_check_fill_value)
#        82    0.001    0.000    0.110    0.001 core.py:5551(min)
#        82    0.000    0.000    0.108    0.001 core.py:5672(max)
#       345    0.000    0.000    0.001    0.000 core.py:596(filled)
#       200    0.001    0.000    0.011    0.000 core.py:6350(array)
#       120    0.000    0.000    0.000    0.000 core.py:669(getdata)
#        40    0.000    0.000    0.002    0.000 core.py:7763(asarray)
#       372    0.000    0.000    0.000    0.000 cycler.py:138(keys)
#       372    0.000    0.000    0.000    0.000 cycler.py:225(__iter__)
#      3412    0.001    0.000    0.001    0.000 cycler.py:227(<genexpr>)
#       310    0.004    0.000    0.006    0.000 cycler.py:349(by_key)
#       620    0.000    0.000    0.000    0.000 cycler.py:371(<genexpr>)
#        11    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#       110    0.000    0.000    0.000    0.000 dir2.py:53(get_real_method)
#        11    0.000    0.000    3.555    0.323 display.py:129(display)
#        11    0.000    0.000    0.022    0.002 display.py:79(publish_display_data)
#        11    0.000    0.000    0.000    0.000 displaypub.py:38(_validate_data)
#        44    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#        44    0.000    0.000    0.007    0.000 encoder.py:181(encode)
#        44    0.007    0.000    0.007    0.000 encoder.py:203(iterencode)
#        31    0.000    0.000    0.000    0.000 figure.py:1012(_make_key)
#        31    0.000    0.000    0.000    0.000 figure.py:1015(fixitems)
#        31    0.000    0.000    0.000    0.000 figure.py:1031(fixlist)
#        31    0.000    0.000    0.000    0.000 figure.py:107(_entry_from_axes)
#        31    0.000    0.000    0.000    0.000 figure.py:108(<dictcomp>)
#        31    0.000    0.000    0.491    0.016 figure.py:1145(add_subplot)
#        31    0.000    0.000    0.000    0.000 figure.py:115(bubble)
#        31    0.000    0.000    0.001    0.000 figure.py:122(add)
#        11    0.000    0.000    0.000    0.000 figure.py:1401(clf)
#        22    0.000    0.000    1.316    0.060 figure.py:1438(draw)
#        84    0.000    0.000    0.000    0.000 figure.py:1450(<genexpr>)
#        62    0.000    0.000    0.000    0.000 figure.py:1454(<lambda>)
#       215    0.000    0.000    0.000    0.000 figure.py:152(current_key_axes)
#        92    0.000    0.000    0.000    0.000 figure.py:165(__call__)
#        31    0.000    0.000    0.000    0.000 figure.py:168(__contains__)
#        11    0.000    0.000    0.000    0.000 figure.py:176(__init__)
#        11    0.000    0.000    0.000    0.000 figure.py:1765(_set_artist_props)
#       123    0.000    0.000    0.017    0.000 figure.py:1771(gca)
#        31    0.000    0.000    0.000    0.000 figure.py:1819(sca)
#        42    0.000    0.000    0.001    0.000 figure.py:208(update)
#        11    0.000    0.000    0.001    0.000 figure.py:2169(get_default_bbox_extra_artists)
#        11    0.000    0.000    0.000    0.000 figure.py:2170(<listcomp>)
#        11    0.000    0.000    0.981    0.089 figure.py:2179(get_tightbbox)
#        11    0.000    0.000    0.000    0.000 figure.py:2195(<listcomp>)
#       252    0.000    0.000    0.000    0.000 figure.py:247(_update_this)
#        11    0.000    0.000    0.001    0.000 figure.py:279(__repr__)
#        11    0.001    0.000    0.006    0.001 figure.py:286(__init__)
#        11    0.000    0.000    0.000    0.000 figure.py:415(_repr_html_)
#       110    0.000    0.000    0.001    0.000 figure.py:462(_get_axes)
#      1425    0.000    0.000    0.000    0.000 figure.py:467(_get_dpi)
#        22    0.000    0.000    0.009    0.000 figure.py:470(_set_dpi)
#        22    0.000    0.000    0.000    0.000 figure.py:487(get_tight_layout)
#        11    0.000    0.000    0.000    0.000 figure.py:493(set_tight_layout)
#        64    0.000    0.000    0.000    0.000 figure.py:516(get_constrained_layout)
#        11    0.000    0.000    0.000    0.000 figure.py:524(set_constrained_layout)
#        11    0.000    0.000    0.000    0.000 figure.py:553(set_constrained_layout_pads)
#      5633    0.004    0.000    0.007    0.000 figure.py:58(_stale_figure_callback)
#        11    0.000    0.000    0.000    0.000 figure.py:662(get_children)
#        22    0.000    0.000    0.000    0.000 figure.py:759(set_canvas)
#        11    0.000    0.000    0.000    0.000 figure.py:78(__init__)
#       141    0.000    0.000    0.001    0.000 figure.py:82(as_list)
#       141    0.000    0.000    0.000    0.000 figure.py:86(<listcomp>)
#        22    0.000    0.000    0.006    0.000 figure.py:873(set_size_inches)
#       141    0.000    0.000    0.000    0.000 figure.py:88(<listcomp>)
#        66    0.000    0.000    0.000    0.000 figure.py:896(<genexpr>)
#        62    0.000    0.000    0.000    0.000 figure.py:90(get)
#        84    0.000    0.000    0.001    0.000 figure.py:913(get_size_inches)
#        22    0.000    0.000    0.000    0.000 figure.py:929(get_edgecolor)
#        22    0.000    0.000    0.000    0.000 figure.py:933(get_facecolor)
#        22    0.000    0.000    0.000    0.000 figure.py:953(set_edgecolor)
#        22    0.000    0.000    0.000    0.000 figure.py:961(set_facecolor)
#       612    0.001    0.000    0.005    0.000 font_manager.py:1015(make_rcparams_key)
#       612    0.002    0.000    0.003    0.000 font_manager.py:1017(<listcomp>)
#       610    0.001    0.000    0.016    0.000 font_manager.py:1019(get)
#         2    0.000    0.000    0.000    0.000 font_manager.py:1026(set)
#      1675    0.001    0.000    0.002    0.000 font_manager.py:1102(get_default_size)
#       382    0.001    0.000    0.003    0.000 font_manager.py:1125(score_family)
#       382    0.001    0.000    0.001    0.000 font_manager.py:1148(<listcomp>)
#       382    0.000    0.000    0.000    0.000 font_manager.py:1158(score_style)
#       382    0.000    0.000    0.000    0.000 font_manager.py:1175(score_variant)
#       382    0.001    0.000    0.002    0.000 font_manager.py:1186(score_stretch)
#       382    0.002    0.000    0.002    0.000 font_manager.py:1204(score_weight)
#       382    0.000    0.000    0.000    0.000 font_manager.py:1231(score_size)
#       610    0.003    0.000    0.026    0.000 font_manager.py:1255(findfont)
#       610    0.001    0.000    0.001    0.000 font_manager.py:1383(get_font)
#       610    0.001    0.000    0.027    0.000 font_manager.py:1473(findfont)
#      2577    0.016    0.000    0.078    0.000 font_manager.py:665(__init__)
#      2806    0.009    0.000    0.014    0.000 font_manager.py:711(__hash__)
#       602    0.000    0.000    0.005    0.000 font_manager.py:721(__eq__)
#         2    0.000    0.000    0.000    0.000 font_manager.py:727(__str__)
#      3190    0.001    0.000    0.001    0.000 font_manager.py:730(get_family)
#      3190    0.001    0.000    0.001    0.000 font_manager.py:743(get_style)
#      3190    0.000    0.000    0.000    0.000 font_manager.py:751(get_variant)
#      3190    0.001    0.000    0.001    0.000 font_manager.py:758(get_weight)
#      3190    0.001    0.000    0.001    0.000 font_manager.py:767(get_stretch)
#       384    0.000    0.000    0.000    0.000 font_manager.py:775(get_size)
#      3540    0.001    0.000    0.001    0.000 font_manager.py:781(get_size_in_points)
#      3418    0.001    0.000    0.001    0.000 font_manager.py:784(get_file)
#         2    0.000    0.000    0.000    0.000 font_manager.py:790(get_fontconfig_pattern)
#      1645    0.002    0.000    0.009    0.000 font_manager.py:804(set_family)
#      1645    0.002    0.000    0.002    0.000 font_manager.py:817(set_style)
#      1645    0.001    0.000    0.002    0.000 font_manager.py:829(set_variant)
#      1675    0.010    0.000    0.010    0.000 font_manager.py:839(set_weight)
#      1645    0.004    0.000    0.005    0.000 font_manager.py:857(set_stretch)
#      1675    0.006    0.000    0.008    0.000 font_manager.py:875(set_size)
#      1645    0.000    0.000    0.000    0.000 font_manager.py:900(set_file)
#       932    0.001    0.000    0.013    0.000 font_manager.py:924(copy)
#      4222    0.007    0.000    0.021    0.000 font_manager.py:989(_normalize_font_family)
#      4222    0.004    0.000    0.004    0.000 font_manager.py:993(<listcomp>)
#         2    0.000    0.000    0.000    0.000 fontconfig_pattern.py:179(generate_fontconfig_pattern)
#         2    0.000    0.000    0.000    0.000 fontconfig_pattern.py:191(<listcomp>)
#       132    0.000    0.000    3.530    0.027 formatters.py:220(catch_format_error)
#       121    0.000    0.000    0.000    0.000 formatters.py:274(_get_type)
#        99    0.000    0.000    3.527    0.036 formatters.py:331(__call__)
#       121    0.000    0.000    0.000    0.000 formatters.py:359(_check_return)
#       121    0.000    0.000    0.002    0.000 formatters.py:374(lookup)
#       121    0.001    0.000    0.002    0.000 formatters.py:397(lookup_by_type)
#       330    0.000    0.000    0.001    0.000 formatters.py:550(_in_deferred_types)
#         1    0.000    0.000    0.001    0.001 formatters.py:56(_default_formatter)
#         1    0.000    0.000    0.001    0.001 formatters.py:61(_default_mime_formatter)
#         1    0.000    0.000    0.000    0.000 formatters.py:673(_singleton_printers_default)
#        11    0.000    0.000    0.002    0.000 formatters.py:689(__call__)
#        11    0.000    0.000    0.000    0.000 formatters.py:824(_check_return)
#        11    0.000    0.000    3.532    0.321 formatters.py:89(format)
#        11    0.000    0.000    0.001    0.000 formatters.py:903(__call__)
#        11    0.000    0.000    0.000    0.000 formatters.py:940(_check_return)
#        11    0.000    0.000    0.000    0.000 formatters.py:949(__call__)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1104(searchsorted)
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:1236(squeeze)
#       124    0.000    0.000    0.001    0.000 fromnumeric.py:1577(nonzero)
#       168    0.000    0.000    0.379    0.002 fromnumeric.py:1764(clip)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1821(sum)
#      5059    0.007    0.000    0.060    0.000 fromnumeric.py:1933(any)
#       310    0.001    0.000    0.004    0.000 fromnumeric.py:2016(all)
#        62    0.000    0.000    0.001    0.000 fromnumeric.py:2092(cumsum)
#       124    0.000    0.000    0.002    0.000 fromnumeric.py:2159(ptp)
#      3995    0.003    0.000    0.019    0.000 fromnumeric.py:2227(amax)
#      3954    0.004    0.000    0.023    0.000 fromnumeric.py:2337(amin)
#       692    0.001    0.000    0.006    0.000 fromnumeric.py:2734(around)
#       692    0.000    0.000    0.006    0.000 fromnumeric.py:2803(round_)
#       187    0.002    0.000    0.377    0.002 fromnumeric.py:36(_wrapit)
#      1049    0.002    0.000    0.385    0.000 fromnumeric.py:49(_wrapfunc)
#     13328    0.027    0.000    0.092    0.000 fromnumeric.py:64(_wrapreduction)
#       499    0.004    0.000    0.005    0.000 function_base.py:1079(diff)
#         3    0.000    0.000    0.000    0.000 function_base.py:13(_index_deprecate)
#       496    0.000    0.000    0.000    0.000 function_base.py:241(iterable)
#         3    0.000    0.000    0.000    0.000 function_base.py:25(linspace)
#        15    0.000    0.000    0.005    0.000 functional.py:1894(interpolate)
#        15    0.000    0.000    0.000    0.000 functional.py:1934(_check_size_scale_factor)
#        15    0.000    0.000    0.002    0.000 functional.py:1944(_output_size)
#         2    0.000    0.000    0.000    0.000 functional.py:1950(<listcomp>)
#    105000    0.354    0.000   11.318    0.000 functional.py:2112(pad)
#         2    0.000    0.000    0.000    0.000 genericpath.py:27(isfile)
#       248    0.001    0.000    0.001    0.000 getlimits.py:376(__new__)
#        31    0.000    0.000    0.000    0.000 gridspec.py:138(__getitem__)
#        31    0.000    0.000    0.000    0.000 gridspec.py:143(_normalize)
#        31    0.000    0.000    0.000    0.000 gridspec.py:175(__init__)
#        31    0.000    0.000    0.001    0.000 gridspec.py:266(get_subplot_params)
#        31    0.000    0.000    0.000    0.000 gridspec.py:283(<dictcomp>)
#        31    0.000    0.000    0.000    0.000 gridspec.py:391(__init__)
#        31    0.000    0.000    0.000    0.000 gridspec.py:41(__init__)
#        31    0.000    0.000    0.000    0.000 gridspec.py:428(get_gridspec)
#        31    0.000    0.000    0.007    0.000 gridspec.py:456(get_position)
#        93    0.000    0.000    0.000    0.000 gridspec.py:51(get_geometry)
#        31    0.000    0.000    0.000    0.000 gridspec.py:66(set_width_ratios)
#        31    0.000    0.000    0.000    0.000 gridspec.py:75(set_height_ratios)
#        31    0.001    0.000    0.005    0.000 gridspec.py:84(get_grid_positions)
#        11    0.000    0.000    0.000    0.000 hmac.py:108(_current)
#        11    0.000    0.000    0.000    0.000 hmac.py:127(hexdigest)
#        44    0.000    0.000    0.004    0.000 hmac.py:90(update)
#        11    0.000    0.000    0.000    0.000 hmac.py:95(copy)
#     84/22    0.001    0.000    1.308    0.059 image.py:123(_draw_list_compositing_images)
#       208    0.000    0.000    0.000    0.000 image.py:133(<genexpr>)
#        22    0.959    0.044    0.960    0.044 image.py:169(_rgb_to_rgba)
#        31    0.000    0.000    0.002    0.000 image.py:204(__init__)
#         1    0.000    0.000    0.000    0.000 image.py:204(_compute_n_patches)
#         1    0.000    0.000    0.001    0.001 image.py:241(extract_patches)
#        31    0.000    0.000    0.000    0.000 image.py:249(get_size)
#        31    0.000    0.000    0.000    0.000 image.py:256(set_alpha)
#        31    0.000    0.000    0.000    0.000 image.py:266(changed)
#        62    0.013    0.000    1.171    0.019 image.py:275(_make_image)
#         1    0.000    0.000    0.000    0.000 image.py:286(<listcomp>)
#         1    0.001    0.001    0.221    0.221 image.py:299(extract_patches_2d)
#        62    0.001    0.000    1.194    0.019 image.py:569(draw)
#        31    0.001    0.000    0.440    0.014 image.py:629(set_data)
#       164    0.000    0.000    0.000    0.000 image.py:688(get_interpolation)
#        31    0.000    0.000    0.000    0.000 image.py:699(set_interpolation)
#        31    0.000    0.000    0.000    0.000 image.py:732(set_resample)
#        62    0.000    0.000    0.000    0.000 image.py:743(get_resample)
#        31    0.000    0.000    0.000    0.000 image.py:747(set_filternorm)
#       102    0.000    0.000    0.000    0.000 image.py:761(get_filternorm)
#        31    0.000    0.000    0.000    0.000 image.py:765(set_filterrad)
#       102    0.000    0.000    0.000    0.000 image.py:778(get_filterrad)
#        31    0.000    0.000    0.002    0.000 image.py:787(__init__)
#        31    0.000    0.000    0.002    0.000 image.py:827(get_window_extent)
#        62    0.004    0.000    1.177    0.019 image.py:832(make_image)
#        62    0.000    0.000    0.000    0.000 image.py:843(_check_unsampled_image)
#        31    0.000    0.000    0.009    0.000 image.py:850(set_extent)
#        93    0.000    0.000    0.000    0.000 image.py:870(get_extent)
#       110    0.000    0.000    0.000    0.000 inspect.py:72(isclass)
#        57    0.001    0.000    0.001    0.000 iostream.py:195(schedule)
#        11    0.000    0.000    0.000    0.000 iostream.py:207(send_multipart)
#        11    0.000    0.000    0.000    0.000 iostream.py:260(send_multipart)
#         1    0.000    0.000    0.000    0.000 iostream.py:300(_is_master_process)
#         1    0.000    0.000    0.000    0.000 iostream.py:313(_schedule_flush)
#        22    0.000    0.000    0.005    0.000 iostream.py:327(flush)
#         1    0.000    0.000    0.000    0.000 iostream.py:366(write)
#        57    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#        44    0.000    0.000    0.008    0.000 jsonapi.py:31(dumps)
#     66/11    0.000    0.000    0.003    0.000 jsonutil.py:109(json_clean)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:34(_ensure_tzinfo)
#        11    0.000    0.000    0.000    0.000 jsonutil.py:49(encode_images)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:87(date_default)
#        93    0.000    0.000    0.000    0.000 linalg.py:103(get_linalg_error_extobj)
#        93    0.000    0.000    0.000    0.000 linalg.py:108(_makearray)
#       186    0.000    0.000    0.000    0.000 linalg.py:113(isComplexType)
#        93    0.000    0.000    0.000    0.000 linalg.py:126(_realType)
#        93    0.000    0.000    0.000    0.000 linalg.py:141(_commonType)
#        93    0.000    0.000    0.000    0.000 linalg.py:200(_assertRankAtLeast2)
#        93    0.000    0.000    0.000    0.000 linalg.py:211(_assertNdSquareness)
#        93    0.003    0.000    0.004    0.000 linalg.py:468(inv)
#         1    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#         1    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#         1    0.000    0.000    0.000    0.000 linecache.py:82(updatecache)
#      2235    0.003    0.000    0.006    0.000 lines.py:1005(set_linewidth)
#      4470    0.007    0.000    0.011    0.000 lines.py:1020(_split_drawstyle_linestyle)
#      2235    0.008    0.000    0.019    0.000 lines.py:1052(set_linestyle)
#      2235    0.001    0.000    0.003    0.000 lines.py:1140(set_markeredgecolor)
#      2235    0.002    0.000    0.004    0.000 lines.py:1153(set_markeredgewidth)
# ...
#      5564    0.004    0.000    0.005    0.000 {built-in method builtins.hasattr}
# 6950/4756    0.003    0.000    0.013    0.000 {built-in method builtins.hash}
#     12723    0.002    0.000    0.002    0.000 {built-in method builtins.id}
# 226116/225537    0.056    0.000    0.110    0.000 {built-in method builtins.isinstance}
# 1544/1026    0.001    0.000    0.004    0.000 {built-in method builtins.issubclass}
#     35908    0.008    0.000    0.008    0.000 {built-in method builtins.iter}
#    547625    0.071    0.000    0.071    0.000 {built-in method builtins.len}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      3051    0.005    0.000    0.005    0.000 {built-in method builtins.max}
#       690    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#       266    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#       137    0.000    0.000    0.001    0.000 {built-in method builtins.repr}
#      1368    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       250    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#    210000    0.065    0.000    0.065    0.000 {built-in method builtins.sum}
#        12    0.002    0.000    0.002    0.000 {built-in method clamp}
#    165000   10.515    0.000   10.515    0.000 {built-in method conv2d}
#     45000    0.730    0.000    0.730    0.000 {built-in method cumsum}
#      7500    0.127    0.000    0.127    0.000 {built-in method exp}
#      7500    0.815    0.000    0.815    0.000 {built-in method flip}
#         2    0.000    0.000    0.000    0.000 {built-in method from_numpy}
#        11    0.011    0.001    0.011    0.001 {built-in method gc.collect}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#     15010    0.274    0.000    0.274    0.000 {built-in method log}
#       124    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#        60    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       252    0.000    0.000    0.000    0.000 {built-in method math.floor}
#       372    0.000    0.000    0.000    0.000 {built-in method math.log10}
#       120    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        60    0.000    0.000    0.000    0.000 {built-in method math.sin}
#       102    0.093    0.001    0.098    0.001 {built-in method matplotlib._image.resample}
#      3003    0.005    0.000    0.005    0.000 {built-in method matplotlib._path.affine_transform}
#       217    0.002    0.000    0.008    0.000 {built-in method matplotlib._path.get_path_extents}
#        31    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#        22    1.127    0.051    1.127    0.051 {built-in method matplotlib._png.write_png}
#      7500    0.808    0.000    0.808    0.000 {built-in method max}
#       127    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.arange}
#     37776    0.290    0.000    0.636    0.000 {built-in method numpy.core.multiarray.array}
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.can_cast}
#      2109    0.008    0.000    0.008    0.000 {built-in method numpy.core.multiarray.concatenate}
#        41    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.copyto}
#      8383    0.021    0.000    0.021    0.000 {built-in method numpy.core.multiarray.dot}
#       121    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.min_scalar_type}
#       511    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.result_type}
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.unravel_index}
#       952    0.006    0.000    0.006    0.000 {built-in method numpy.core.multiarray.zeros}
#       496    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.geterrobj}
#       248    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.seterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method ones}
#        12    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        11    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        10    0.001    0.000    0.001    0.000 {built-in method randn}
#    187501    1.550    0.000    1.550    0.000 {built-in method squeeze}
#     22511    0.883    0.000    0.883    0.000 {built-in method sum}
#       123    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        10    0.001    0.000    0.001    0.000 {built-in method torch._C._cuda_emptyCache}
#        15    0.003    0.000    0.003    0.000 {built-in method torch._C._nn.upsample_nearest2d}
#    187500    1.269    0.000    1.269    0.000 {built-in method unsqueeze}
#        11    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         9    0.002    0.000    0.002    0.000 {built-in method zeros}
#        78    0.000    0.000    0.000    0.000 {function Config.__contains__ at 0x7fb557204158}
#        93    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#        22    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        22    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 {method '__getitem__' of 'dict' objects}
#        31    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#       249    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#        19    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#        22    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       163    0.003    0.000    0.003    0.000 {method 'acquire' of '_thread.lock' objects}
#       485    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       974    0.001    0.000    0.009    0.000 {method 'all' of 'numpy.ndarray' objects}
#        74    0.000    0.000    0.016    0.000 {method 'any' of 'numpy.ndarray' objects}
#        78    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     13681    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#        80    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#       983    0.009    0.000    0.009    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        11    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       610    0.001    0.000    0.001    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#       168    0.201    0.001    0.201    0.001 {method 'clip' of 'numpy.ndarray' objects}
#        33    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        28    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        80    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#      8338    0.015    0.000    0.015    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    105000    1.405    0.000    1.405    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#       670    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#        33    0.538    0.016    0.538    0.016 {method 'cpu' of 'torch._C._TensorBase' objects}
#        62    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#        34    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        11    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#    105030    0.036    0.000    0.036    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        60    0.009    0.000    0.009    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#        62    0.008    0.000    0.014    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        22    0.001    0.000    0.001    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        60    0.002    0.000    0.002    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        55    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#      1386    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#    105000    1.822    0.000    1.822    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#       439    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#       245    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    230892    0.028    0.000    0.036    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        60    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       610    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#       550    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#        11    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        11    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        11    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        53    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       576    0.001    0.000    0.001    0.000 {method 'item' of 'numpy.generic' objects}
#        31    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     36693    0.006    0.000    0.006    0.000 {method 'items' of 'dict' objects}
#        92    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     18272    0.003    0.000    0.003    0.000 {method 'lower' of 'str' objects}
#      1302    0.001    0.000    0.001    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#      1142    0.001    0.000    0.110    0.000 {method 'max' of 'numpy.ndarray' objects}
#        10    0.012    0.001    0.012    0.001 {method 'mean' of 'torch._C._TensorBase' objects}
#       840    0.001    0.000    0.113    0.000 {method 'min' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#    375000    2.019    0.000    2.019    0.000 {method 'narrow' of 'torch._C._TensorBase' objects}
#    105000    1.432    0.000    1.432    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#       124    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        33    0.000    0.000    0.000    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#      5228    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#        22    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#      1490    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        10    0.000    0.000    0.000    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#     16731    0.354    0.000    0.354    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        22    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        21    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       479    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       243    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        11    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#      1537    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#      4045    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       368    0.002    0.000    0.002    0.000 {method 'round' of 'numpy.generic' objects}
#       324    0.002    0.000    0.002    0.000 {method 'round' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       610    0.001    0.000    0.001    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       610    0.071    0.000    0.071    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#       212    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#    795004    0.344    0.000    0.344    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#       143    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       277    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#     22495    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#        10    0.140    0.014    0.140    0.014 {method 'std' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       125    0.000    0.000    0.051    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        40    0.012    0.000    0.012    0.000 {method 'take' of 'numpy.ndarray' objects}
#    157510    0.767    0.000    0.767    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#        12    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        55    0.004    0.000    0.004    0.000 {method 'update' of '_hashlib.HASH' objects}
#      3927    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#        76    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#    210186    0.058    0.000    0.058    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     10545    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#   559/395    0.001    0.000    0.004    0.000 {method 'view' of 'numpy.generic' objects}
#       111    0.000    0.000    0.001    0.000 {method 'view' of 'numpy.ndarray' objects}
#     82500    0.609    0.000    0.609    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#        11    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
# CPU times: user 1min 5s, sys: 11.7 s, total: 1min 17s
# Wall time: 1min 11s

# %%
#Replaces the epitome (e,ev) of an image by another epitome image (emod)
#keeping the mapping intact. The routine can be used to edit images or to
#preprocess by coloring the image accoring to the image (see the segmentation
#part of the web page for more info). K specifies the patch size to use in 
#mapping inference and SPC defines the patch spacing.

def reconstruct(x,K,e,ev,emod,SPC):
    _,NoCh1,Ny,Nx = x.shape
    NoCh2 = emod.shape[0]
    if NoCh1 == 1:
        temp = x
        x = torch.stack((temp,temp,temp),dim=0)
        #x = torch.zeros((NoCh1,Nx,Ny))
        #x[:,:,0] = temp
        #x[:,:,1] = temp
        #x[:,:,2] = temp
    
    NoCh1,N,Ny = e.shape
    SY = x.shape[2]
    SX = x.shape[3]
    
    ewrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    evwrap = torch.zeros((NoCh1,N+K-1,N+K-1)).to(device)
    MINP = 1e-6
    MINV = 1e-2
    
    ewrap[:,:N,:N] = e
    ewrap[:,N:,:] = ewrap[:,:K-1,:]
    ewrap[:,:,N:] = ewrap[:,:,:K-1]
    evwrap[:,:N,:N] = ev
    evwrap[:,N:,:] = evwrap[:,:K-1,:]
    evwrap[:,:,N:] = evwrap[:,:,:K-1]
    logevwrap = torch.log(evwrap)
    evwrapi = 1./evwrap
    tmp3 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(ewrap**2*evwrapi,0),K)),dim=0)
    tmp4 = torch.sum(torch.squeeze(cum_sum(torch.unsqueeze(logevwrap,0),K)),dim=0)
    
    #tmp3 = torch.zeros((NoCh1,N,N))
    #tmp4 = torch.zeros((NoCh1,N,N))
    #onemat = np.ones((K,K))
    #for i in range(NoCh1):
        #tmp3[i,:,:] = fftconvolve(evwrap[:,:,i]**2*evwrapi[:,:,i],onemat,mode='valid')
        #tmp4[i,:,:] = fftconvolve(logevwrap[:,:,i],onemat,mode='valid')
        
    emodwrap = torch.zeros((NoCh2,N+K-1,N+K-1))
    emodwrap[:,:N,:N] = emod
    emodwrap[:,N:,:] = emodwrap[:,:K-1,:]
    emodwrap[:,:,N:] = emodwrap[:,:,:K-1]
    
    z = torch.zeros((NoCh2,SY,SX))
    cnt = torch.zeros((SY,SX))
    ixt = 0
    iyt = 0
    for iy in range(0,SY-K+1,SPC):
        for ix in range(0,SX-K+1,SPC):
            #watch for indexing errors
            #yc = x[iy:iy+K-1,ix:ix+K-1,:]
            #print(x.shape)
            yc = x[:,:,iy:iy+K,ix:ix+K]
            #print(x.shape,yc.shape)
            #yct = torch.flip(yc,[2,3])
            #yct = yc[::-1,::-1]
            yct = yc.to(device)
            #print(yc.shape)
            lP = torch.zeros(tmp4.shape).to(device)#[:,:] = 0
            #print(evwrapi.shape,ewrap.shape,evwrap.shape,yct.shape)
            tmp1 = torch.squeeze(F.conv2d(torch.unsqueeze(evwrapi,0),yct**2))
            tmp2 = torch.squeeze(F.conv2d(torch.unsqueeze(ewrap*evwrap,0),yct))
            lP += -.5*(tmp4+tmp1-2*tmp2+tmp3)
            #for i in range(NoCh1):
                #tmp1 = fftconvolve(evwrapi[:,:,i],yct[:,:,i]**2,mode='valid')
                #tmp2 = fftconvolve(ewrap[:,:,i]*evwrap[:,:,i],yct[:,:,i],mode='valid')
                #lP += -.5*(tmp4[:,:,i]+tmp1-2*tmp2+tmp3[:,:,i])
            mxlP = torch.max(lP)
            P = torch.exp(lP-mxlP)+MINP
            nrmP = torch.sum(P)
            P /= nrmP
            mxp,mxpj = torch.max(P,dim=1)#,torch.argmax(P,dim=1)
            mxp, mxpi = torch.max(mxp),torch.argmax(mxp)
            mxpj = mxpj[mxpi]
            #watch for indexing errors
            newp = emodwrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            oldp = ewrap[:,mxpi:mxpi+K-1,mxpj:mxpj+K-1]
            z[:,iy:iy+K-1,ix:ix+K-1] += newp 
            cnt[iy:iy+K-1,ix:ix+K-1] += 1
            
            ixt = ix
            iyt = iy
    z = z[:,:iyt+K-1,:ixt+K-1]
    cnt = cnt[:iyt+K-1,:ixt+K-1]
    for i in range(NoCh2):
        z[i,:,:] /= cnt
    
    return z

# %%
# %%time
z = reconstruct(tsIMtorch[:,:4,:,:],17,e[0,:4,:,:],ev[0,:4,:,:],e[0,4:10,:,:],3)
# Out:
# CPU times: user 1h 54min 10s, sys: 32min 1s, total: 2h 26min 12s
# Wall time: 2h 26min 9s

# %%
print(trIMtorch.shape)
temp = np.rollaxis(extract_patches_2d(torch.squeeze(trIMtorch).permute(1,2,0),(8,8),max_patches=1000),3,1)
pp = torch.from_numpy(temp).float().to(device)
print(pp.shape)
# Out:
# torch.Size([1, 10, 7662, 6185])
# torch.Size([1000, 10, 8, 8])
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/feature_extraction/image.py:287: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   indexing_strides = arr[slices].strides

# %%
tt = torch.Tensor([1e-30])

# %%
tt
# Out:
# tensor([1.0000e-30])
